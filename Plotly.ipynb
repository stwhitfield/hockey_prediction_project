# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/hp/Downloads/tidy1.csv")

# %%
data.head()
# Out:
#        gameId    season         teamHome             teamAway  eventType  \
# 0  2016020001  20162017  Ottawa Senators  Toronto Maple Leafs          0
# 1  2016020001  20162017  Ottawa Senators  Toronto Maple Leafs          0
# 2  2016020001  20162017  Ottawa Senators  Toronto Maple Leafs          0
# 3  2016020001  20162017  Ottawa Senators  Toronto Maple Leafs          0
# 4  2016020001  20162017  Ottawa Senators  Toronto Maple Leafs          0
#
#              eventTeam  period periodTime eventSide  coordinateX  coordinateY  \
# 0  Toronto Maple Leafs       1      01:11     right        -77.0          5.0
# 1      Ottawa Senators       1      02:53      left         86.0         13.0
# 2      Ottawa Senators       1      04:01      left         23.0        -38.0
# 3      Ottawa Senators       1      04:46      left         33.0        -15.0
# 4  Toronto Maple Leafs       1      06:46     right        -34.0         28.0
#
#        shooterName         goalieName    shotType emptyNet strength
# 0  Mitchell Marner     Craig Anderson  Wrist Shot      NaN      NaN
# 1      Chris Kelly  Frederik Andersen  Wrist Shot      NaN      NaN
# 2        Cody Ceci  Frederik Andersen  Wrist Shot      NaN      NaN
# 3    Erik Karlsson  Frederik Andersen   Slap Shot      NaN      NaN
# 4  Martin Marincin     Craig Anderson  Wrist Shot      NaN      NaN

# %%
#Filter by Season
df=data[data["season"]==20162017]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80399 entries, 0 to 80398
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gameId       80399 non-null  int64
#  1   season       80399 non-null  int64
#  2   teamHome     80399 non-null  object
#  3   teamAway     80399 non-null  object
#  4   eventType    80399 non-null  int64
#  5   eventTeam    80399 non-null  object
#  6   period       80399 non-null  int64
#  7   periodTime   80399 non-null  object
#  8   eventSide    80399 non-null  object
#  9   coordinateX  80395 non-null  float64
#  10  coordinateY  80395 non-null  float64
#  11  shooterName  80399 non-null  object
#  12  goalieName   80399 non-null  object
#  13  shotType     80378 non-null  object
#  14  emptyNet     7153 non-null   object
#  15  strength     7377 non-null   object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 10.4+ MB

# %%
df
# Out:
#            gameId    season             teamHome             teamAway  \
# 0      2016020001  20162017      Ottawa Senators  Toronto Maple Leafs
# 1      2016020001  20162017      Ottawa Senators  Toronto Maple Leafs
# 2      2016020001  20162017      Ottawa Senators  Toronto Maple Leafs
# 3      2016020001  20162017      Ottawa Senators  Toronto Maple Leafs
# 4      2016020001  20162017      Ottawa Senators  Toronto Maple Leafs
# ...           ...       ...                  ...                  ...
# 80394  2016030416  20162017  Nashville Predators  Pittsburgh Penguins
# 80395  2016030416  20162017  Nashville Predators  Pittsburgh Penguins
# 80396  2016030416  20162017  Nashville Predators  Pittsburgh Penguins
# 80397  2016030416  20162017  Nashville Predators  Pittsburgh Penguins
# 80398  2016030416  20162017  Nashville Predators  Pittsburgh Penguins
#
#        eventType            eventTeam  period periodTime eventSide  \
# 0              0  Toronto Maple Leafs       1      01:11     right
# 1              0      Ottawa Senators       1      02:53      left
# 2              0      Ottawa Senators       1      04:01      left
# 3              0      Ottawa Senators       1      04:46      left
# 4              0  Toronto Maple Leafs       1      06:46     right
# ...          ...                  ...     ...        ...       ...
# 80394          0  Pittsburgh Penguins       3      10:17     right
# 80395          0  Pittsburgh Penguins       3      11:34     right
# 80396          0  Nashville Predators       3      15:44      left
# 80397          1  Pittsburgh Penguins       3      18:25     right
# 80398          1  Pittsburgh Penguins       3      19:46     right
#
#        coordinateX  coordinateY       shooterName         goalieName  \
# 0            -77.0          5.0   Mitchell Marner     Craig Anderson
# 1             86.0         13.0       Chris Kelly  Frederik Andersen
# 2             23.0        -38.0         Cody Ceci  Frederik Andersen
# 3             33.0        -15.0     Erik Karlsson  Frederik Andersen
# 4            -34.0         28.0   Martin Marincin     Craig Anderson
# ...            ...          ...               ...                ...
# 80394         60.0          2.0          Ian Cole        Pekka Rinne
# 80395        -87.0        -12.0     Sidney Crosby        Pekka Rinne
# 80396         86.0          5.0  Viktor Arvidsson        Matt Murray
# 80397        -86.0          5.0  Patric Hornqvist        Pekka Rinne
# 80398        -78.0          0.0      Carl Hagelin     Brian Dumoulin
#
#          shotType emptyNet strength
# 0      Wrist Shot      NaN      NaN
# 1      Wrist Shot      NaN      NaN
# 2      Wrist Shot      NaN      NaN
# 3       Slap Shot      NaN      NaN
# 4      Wrist Shot      NaN      NaN
# ...           ...      ...      ...
# 80394  Wrist Shot      NaN      NaN
# 80395    Backhand      NaN      NaN
# 80396  Wrist Shot      NaN      NaN
# 80397  Wrist Shot    False     EVEN
# 80398  Wrist Shot     True     EVEN
#
# [80399 rows x 16 columns]

# %%
# Fix Coordinates
df.loc[df['coordinateX'] < 0, ['coordinateX', 'coordinateY']] *= -1

# %%
drop_list=[]
false_list=[True] * len(df["eventTeam"].unique().tolist())
ast=dict(label = 'All',
                  method = 'update',
                  args = [{'visible': false_list},
                          {'title': 'All',
                           'showlegend':True}])
drop_list.append(ast)
i=0
for team in df["eventTeam"].unique().tolist():
    false_list=[False] * len(df["eventTeam"].unique().tolist())
    false_list[i]=True
    i=i+1
    r=dict(label = team,
                      method = 'update',
                      args = [{'visible': false_list}, # the index of True aligns with the indices of plot traces
                              {'title': team,
                               'showlegend':True}])
    drop_list.append(r)

# %%
# How to change plot data using dropdowns
#
# This example shows how to manually add traces
# to the plot and configure the dropdown to only
# show the specific traces you allow.
import plotly.graph_objects as go
fig = go.Figure()

for team in df["eventTeam"].unique().tolist():
    fig.add_trace(go.Histogram2dContour(
            x=df[df["eventTeam"]==team]["coordinateX"], y=df[df["eventTeam"]==team]["coordinateY"],
            colorscale = 'blueredwhite')
                     )

fig.update_layout(
    updatemenus=[go.layout.Updatemenu(
        active=0,
        buttons=list(
            drop_list)
        )
    ])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [61], in <cell line: 9>()
#       7 fig = go.Figure()
#       9 for team in df["eventTeam"].unique().tolist():
# ---> 10     fig.add_trace(go.Histogram2dContour(
#      11             x=df[df["eventTeam"]==team]["coordinateX"], y=df[df["eventTeam"]==team]["coordinateY"],
#      12             colorscale = 'blueredwhite')
#      13                      )
#      15 fig.update_layout(
#      16     updatemenus=[go.layout.Updatemenu(
#      17         active=0,
#    (...)
#      20         )
#      21     ])
#      23 fig.show()
#
# File ~\anaconda3\lib\site-packages\plotly\graph_objs\_histogram2dcontour.py:2941, in Histogram2dContour.__init__(self, arg, autobinx, autobiny, autocolorscale, autocontour, bingroup, coloraxis, colorbar, colorscale, contours, customdata, customdatasrc, histfunc, histnorm, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, ids, idssrc, legendgroup, legendgrouptitle, legendrank, line, marker, meta, metasrc, name, nbinsx, nbinsy, ncontours, opacity, reversescale, showlegend, showscale, stream, textfont, texttemplate, uid, uirevision, visible, x, xaxis, xbingroup, xbins, xcalendar, xhoverformat, xsrc, y, yaxis, ybingroup, ybins, ycalendar, yhoverformat, ysrc, z, zauto, zhoverformat, zmax, zmid, zmin, zsrc, **kwargs)
#    2939 _v = colorscale if colorscale is not None else _v
#    2940 if _v is not None:
# -> 2941     self["colorscale"] = _v
#    2942 _v = arg.pop("contours", None)
#    2943 _v = contours if contours is not None else _v
#
# File ~\anaconda3\lib\site-packages\plotly\basedatatypes.py:4859, in BasePlotlyType.__setitem__(self, prop, value)
#    4855         self._set_array_prop(prop, value)
#    4857     # ### Handle simple property ###
#    4858     else:
# -> 4859         self._set_prop(prop, value)
#    4860 else:
#    4861     # Make sure properties dict is initialized
#    4862     self._init_props()
#
# File ~\anaconda3\lib\site-packages\plotly\basedatatypes.py:5203, in BasePlotlyType._set_prop(self, prop, val)
#    5201         return
#    5202     else:
# -> 5203         raise err
#    5205 # val is None
#    5206 # -----------
#    5207 if val is None:
#    5208     # Check if we should send null update
#
# File ~\anaconda3\lib\site-packages\plotly\basedatatypes.py:5198, in BasePlotlyType._set_prop(self, prop, val)
#    5195 validator = self._get_validator(prop)
#    5197 try:
# -> 5198     val = validator.validate_coerce(val)
#    5199 except ValueError as err:
#    5200     if self._skip_invalid:
#
# File ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py:1643, in ColorscaleValidator.validate_coerce(self, v)
#    1638             v = [
#    1639                 [e[0], ColorValidator.perform_validate_coerce(e[1])] for e in v
#    1640             ]
#    1642 if not v_valid:
# -> 1643     self.raise_invalid_val(v)
#    1645 return v
#
# File ~\anaconda3\lib\site-packages\_plotly_utils\basevalidators.py:288, in BaseValidator.raise_invalid_val(self, v, inds)
#     285             for i in inds:
#     286                 name += "[" + str(i) + "]"
# --> 288         raise ValueError(
#     289             """
#     290     Invalid value of type {typ} received for the '{name}' property of {pname}
#     291         Received value: {v}
#     292
#     293 {valid_clr_desc}""".format(
#     294                 name=name,
#     295                 pname=self.parent_name,
#     296                 typ=type_str(v),
#     297                 v=repr(v),
#     298                 valid_clr_desc=self.description(),
#     299             )
#     300         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'colorscale' property of histogram2dcontour
#         Received value: 'blueredwhite'
#
#     The 'colorscale' property is a colorscale and may be
#     specified as:
#       - A list of colors that will be spaced evenly to create the colorscale.
#         Many predefined colorscale lists are included in the sequential, diverging,
#         and cyclical modules in the plotly.colors package.
#       - A list of 2-element lists where the first element is the
#         normalized color level value (starting at 0 and ending at 1),
#         and the second item is a valid color string.
#         (e.g. [[0, 'green'], [0.5, 'red'], [1.0, 'rgb(0, 0, 255)']])
#       - One of the following named colorscales:
#             ['aggrnyl', 'agsunset', 'algae', 'amp', 'armyrose', 'balance',
#              'blackbody', 'bluered', 'blues', 'blugrn', 'bluyl', 'brbg',
#              'brwnyl', 'bugn', 'bupu', 'burg', 'burgyl', 'cividis', 'curl',
#              'darkmint', 'deep', 'delta', 'dense', 'earth', 'edge', 'electric',
#              'emrld', 'fall', 'geyser', 'gnbu', 'gray', 'greens', 'greys',
#              'haline', 'hot', 'hsv', 'ice', 'icefire', 'inferno', 'jet',
#              'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
#              'orrd', 'oryel', 'oxy', 'peach', 'phase', 'picnic', 'pinkyl',
#              'piyg', 'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn',
#              'puor', 'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu',
#              'rdgy', 'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar',
#              'spectral', 'speed', 'sunset', 'sunsetdark', 'teal', 'tealgrn',
#              'tealrose', 'tempo', 'temps', 'thermal', 'tropic', 'turbid',
#              'turbo', 'twilight', 'viridis', 'ylgn', 'ylgnbu', 'ylorbr',
#              'ylorrd'].
#         Appending '_r' to a named colorscale reverses it.

# %%
drop_list
# Out:
# [{'label': 'All',
#   'method': 'update',
#   'args': [{'visible': [True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True,
#      True]},
#    {'title': 'All', 'showlegend': True}]},
#  {'label': 'Toronto Maple Leafs',
#   'method': 'update',
#   'args': [{'visible': [True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Toronto Maple Leafs', 'showlegend': True}]},
#  {'label': 'Ottawa Senators',
#   'method': 'update',
#   'args': [{'visible': [False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Ottawa Senators', 'showlegend': True}]},
#  {'label': 'St. Louis Blues',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'St. Louis Blues', 'showlegend': True}]},
#  {'label': 'Chicago Blackhawks',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Chicago Blackhawks', 'showlegend': True}]},
#  {'label': 'Edmonton Oilers',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Edmonton Oilers', 'showlegend': True}]},
#  {'label': 'Calgary Flames',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Calgary Flames', 'showlegend': True}]},
#  {'label': 'Los Angeles Kings',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Los Angeles Kings', 'showlegend': True}]},
#  {'label': 'San Jose Sharks',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'San Jose Sharks', 'showlegend': True}]},
#  {'label': 'Montréal Canadiens',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Montréal Canadiens', 'showlegend': True}]},
#  {'label': 'Buffalo Sabres',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Buffalo Sabres', 'showlegend': True}]},
#  {'label': 'New York Rangers',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'New York Rangers', 'showlegend': True}]},
#  {'label': 'New York Islanders',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'New York Islanders', 'showlegend': True}]},
#  {'label': 'Washington Capitals',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Washington Capitals', 'showlegend': True}]},
#  {'label': 'Pittsburgh Penguins',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Pittsburgh Penguins', 'showlegend': True}]},
#  {'label': 'Boston Bruins',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Boston Bruins', 'showlegend': True}]},
#  {'label': 'Columbus Blue Jackets',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Columbus Blue Jackets', 'showlegend': True}]},
#  {'label': 'Detroit Red Wings',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Detroit Red Wings', 'showlegend': True}]},
#  {'label': 'Tampa Bay Lightning',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Tampa Bay Lightning', 'showlegend': True}]},
#  {'label': 'New Jersey Devils',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'New Jersey Devils', 'showlegend': True}]},
#  {'label': 'Florida Panthers',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Florida Panthers', 'showlegend': True}]},
#  {'label': 'Minnesota Wild',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Minnesota Wild', 'showlegend': True}]},
#  {'label': 'Carolina Hurricanes',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Carolina Hurricanes', 'showlegend': True}]},
#  {'label': 'Winnipeg Jets',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Winnipeg Jets', 'showlegend': True}]},
#  {'label': 'Anaheim Ducks',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Anaheim Ducks', 'showlegend': True}]},
#  {'label': 'Dallas Stars',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Dallas Stars', 'showlegend': True}]},
#  {'label': 'Nashville Predators',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Nashville Predators', 'showlegend': True}]},
#  {'label': 'Philadelphia Flyers',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False,
#      False]},
#    {'title': 'Philadelphia Flyers', 'showlegend': True}]},
#  {'label': 'Colorado Avalanche',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False,
#      False]},
#    {'title': 'Colorado Avalanche', 'showlegend': True}]},
#  {'label': 'Arizona Coyotes',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False,
#      False]},
#    {'title': 'Arizona Coyotes', 'showlegend': True}]},
#  {'label': 'Vancouver Canucks',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True,
#      False]},
#    {'title': 'Vancouver Canucks', 'showlegend': True}]},
#  {'label': 'Vegas Golden Knights',
#   'method': 'update',
#   'args': [{'visible': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      True]},
#    {'title': 'Vegas Golden Knights', 'showlegend': True}]}]

# %%
false_list

# %%
false_list=[False] * len(df["teamInfo"].unique().tolist())
df["teamInfo"].unique().tolist()
# Out:
# ['Toronto Maple Leafs',
#  'Ottawa Senators',
#  'St. Louis Blues',
#  'Chicago Blackhawks',
#  'Edmonton Oilers',
#  'Calgary Flames',
#  'Los Angeles Kings',
#  'San Jose Sharks',
#  'Montréal Canadiens',
#  'Buffalo Sabres',
#  'New York Rangers',
#  'New York Islanders',
#  'Washington Capitals',
#  'Pittsburgh Penguins',
#  'Boston Bruins',
#  'Columbus Blue Jackets',
#  'Detroit Red Wings',
#  'Tampa Bay Lightning',
#  'New Jersey Devils',
#  'Florida Panthers',
#  'Minnesota Wild',
#  'Carolina Hurricanes',
#  'Winnipeg Jets',
#  'Anaheim Ducks',
#  'Dallas Stars',
#  'Nashville Predators',
#  'Philadelphia Flyers',
#  'Colorado Avalanche',
#  'Arizona Coyotes',
#  'Vancouver Canucks',
#  'Vegas Golden Knights']
