# %% [markdown]
# Author: Shawn Whitfield <br>
# Version: 1 <br>
# Date: 2022-11-04 <br>

# %%
import DataScraping
from tidy2 import TidyData
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#acquire raw data
path = "raw_data/"
allseasons = ["20152016","20162017","20172018","20182019","20192020"]
DataScraping.download_season_jsons(allseasons, path)
# Out:
# Downloading regular season and playoff games for the following seasons: ['20152016', '20162017', '20172018', '20182019', '20192020']
# File 2015020001.json is already in directory raw_data/.
# File 2015020002.json is already in directory raw_data/.
# File 2015020003.json is already in directory raw_data/.
# File 2015020004.json is already in directory raw_data/.
# File 2015020005.json is already in directory raw_data/.
# File 2015020006.json is already in directory raw_data/.
# File 2015020007.json is already in directory raw_data/.
# File 2015020008.json is already in directory raw_data/.
# File 2015020009.json is already in directory raw_data/.
# File 2015020010.json is already in directory raw_data/.
# File 2015020011.json is already in directory raw_data/.
# File 2015020012.json is already in directory raw_data/.
# File 2015020013.json is already in directory raw_data/.
# File 2015020014.json is already in directory raw_data/.
# File 2015020015.json is already in directory raw_data/.
# File 2015020016.json is already in directory raw_data/.
# File 2015020017.json is already in directory raw_data/.
# File 2015020018.json is already in directory raw_data/.
# File 2015020019.json is already in directory raw_data/.
# File 2015020020.json is already in directory raw_data/.
# File 2015020021.json is already in directory raw_data/.
# File 2015020022.json is already in directory raw_data/.
# File 2015020023.json is already in directory raw_data/.
# File 2015020024.json is already in directory raw_data/.
# File 2015020025.json is already in directory raw_data/.
# File 2015020026.json is already in directory raw_data/.
# File 2015020027.json is already in directory raw_data/.
# File 2015020028.json is already in directory raw_data/.
# File 2015020029.json is already in directory raw_data/.
# File 2015020030.json is already in directory raw_data/.
# File 2015020031.json is already in directory raw_data/.
# File 2015020032.json is already in directory raw_data/.
# File 2015020033.json is already in directory raw_data/.
# File 2015020034.json is already in directory raw_data/.
# File 2015020035.json is already in directory raw_data/.
# File 2015020036.json is already in directory raw_data/.
# File 2015020037.json is already in directory raw_data/.
# File 2015020038.json is already in directory raw_data/.
# File 2015020039.json is already in directory raw_data/.
# File 2015020040.json is already in directory raw_data/.
# File 2015020041.json is already in directory raw_data/.
# File 2015020042.json is already in directory raw_data/.
# File 2015020043.json is already in directory raw_data/.
# File 2015020044.json is already in directory raw_data/.
# File 2015020045.json is already in directory raw_data/.
# File 2015020046.json is already in directory raw_data/.
# File 2015020047.json is already in directory raw_data/.
# File 2015020048.json is already in directory raw_data/.
# File 2015020049.json is already in directory raw_data/.
# File 2015020050.json is already in directory raw_data/.
# File 2015020051.json is already in directory raw_data/.
# File 2015020052.json is already in directory raw_data/.
# File 2015020053.json is already in directory raw_data/.
# File 2015020054.json is already in directory raw_data/.
# File 2015020055.json is already in directory raw_data/.
# File 2015020056.json is already in directory raw_data/.
# File 2015020057.json is already in directory raw_data/.
# File 2015020058.json is already in directory raw_data/.
# File 2015020059.json is already in directory raw_data/.
# File 2015020060.json is already in directory raw_data/.
# File 2015020061.json is already in directory raw_data/.
# File 2015020062.json is already in directory raw_data/.
# File 2015020063.json is already in directory raw_data/.
# File 2015020064.json is already in directory raw_data/.
# File 2015020065.json is already in directory raw_data/.
# File 2015020066.json is already in directory raw_data/.
# File 2015020067.json is already in directory raw_data/.
# File 2015020068.json is already in directory raw_data/.
# File 2015020069.json is already in directory raw_data/.
# File 2015020070.json is already in directory raw_data/.
# File 2015020071.json is already in directory raw_data/.
# File 2015020072.json is already in directory raw_data/.
# File 2015020073.json is already in directory raw_data/.
# File 2015020074.json is already in directory raw_data/.
# File 2015020075.json is already in directory raw_data/.
# File 2015020076.json is already in directory raw_data/.
# File 2015020077.json is already in directory raw_data/.
# File 2015020078.json is already in directory raw_data/.
# File 2015020079.json is already in directory raw_data/.
# File 2015020080.json is already in directory raw_data/.
# File 2015020081.json is already in directory raw_data/.
# File 2015020083.json is already in directory raw_data/.
# File 2015020084.json is already in directory raw_data/.
# File 2015020082.json is already in directory raw_data/.
# File 2015020085.json is already in directory raw_data/.
# File 2015020086.json is already in directory raw_data/.
# File 2015020087.json is already in directory raw_data/.
# File 2015020088.json is already in directory raw_data/.
# File 2015020089.json is already in directory raw_data/.
# File 2015020090.json is already in directory raw_data/.
# File 2015020091.json is already in directory raw_data/.
# File 2015020092.json is already in directory raw_data/.
# File 2015020093.json is already in directory raw_data/.
# File 2015020094.json is already in directory raw_data/.
# File 2015020095.json is already in directory raw_data/.
# File 2015020096.json is already in directory raw_data/.
# File 2015020097.json is already in directory raw_data/.
# File 2015020098.json is already in directory raw_data/.
# File 2015020099.json is already in directory raw_data/.
# File 2015020100.json is already in directory raw_data/.
# File 2015020101.json is already in directory raw_data/.
# File 2015020102.json is already in directory raw_data/.
# File 2015020103.json is already in directory raw_data/.
# File 2015020104.json is already in directory raw_data/.
# File 2015020105.json is already in directory raw_data/.
# File 2015020106.json is already in directory raw_data/.
# File 2015020107.json is already in directory raw_data/.
# File 2015020108.json is already in directory raw_data/.
# File 2015020109.json is already in directory raw_data/.
# File 2015020110.json is already in directory raw_data/.
# File 2015020111.json is already in directory raw_data/.
# File 2015020112.json is already in directory raw_data/.
# File 2015020113.json is already in directory raw_data/.
# File 2015020114.json is already in directory raw_data/.
# File 2015020115.json is already in directory raw_data/.
# File 2015020116.json is already in directory raw_data/.
# File 2015020117.json is already in directory raw_data/.
# File 2015020118.json is already in directory raw_data/.
# File 2015020119.json is already in directory raw_data/.
# File 2015020120.json is already in directory raw_data/.
# File 2015020121.json is already in directory raw_data/.
# File 2015020122.json is already in directory raw_data/.
# File 2015020123.json is already in directory raw_data/.
# File 2015020124.json is already in directory raw_data/.
# File 2015020125.json is already in directory raw_data/.
# File 2015020126.json is already in directory raw_data/.
# File 2015020127.json is already in directory raw_data/.
# File 2015020128.json is already in directory raw_data/.
# File 2015020129.json is already in directory raw_data/.
# File 2015020130.json is already in directory raw_data/.
# File 2015020131.json is already in directory raw_data/.
# File 2015020132.json is already in directory raw_data/.
# File 2015020133.json is already in directory raw_data/.
# File 2015020134.json is already in directory raw_data/.
# File 2015020135.json is already in directory raw_data/.
# File 2015020136.json is already in directory raw_data/.
# File 2015020137.json is already in directory raw_data/.
# File 2015020138.json is already in directory raw_data/.
# File 2015020139.json is already in directory raw_data/.
# File 2015020140.json is already in directory raw_data/.
# File 2015020141.json is already in directory raw_data/.
# File 2015020142.json is already in directory raw_data/.
# File 2015020143.json is already in directory raw_data/.
# File 2015020144.json is already in directory raw_data/.
# File 2015020145.json is already in directory raw_data/.
# File 2015020146.json is already in directory raw_data/.
# File 2015020147.json is already in directory raw_data/.
# File 2015020148.json is already in directory raw_data/.
# File 2015020149.json is already in directory raw_data/.
# File 2015020150.json is already in directory raw_data/.
# File 2015020151.json is already in directory raw_data/.
# File 2015020152.json is already in directory raw_data/.
# File 2015020153.json is already in directory raw_data/.
# File 2015020154.json is already in directory raw_data/.
# File 2015020155.json is already in directory raw_data/.
# File 2015020156.json is already in directory raw_data/.
# File 2015020157.json is already in directory raw_data/.
# File 2015020158.json is already in directory raw_data/.
# File 2015020159.json is already in directory raw_data/.
# File 2015020160.json is already in directory raw_data/.
# File 2015020161.json is already in directory raw_data/.
# File 2015020162.json is already in directory raw_data/.
# File 2015020163.json is already in directory raw_data/.
# File 2015020164.json is already in directory raw_data/.
# File 2015020165.json is already in directory raw_data/.
# File 2015020166.json is already in directory raw_data/.
# File 2015020167.json is already in directory raw_data/.
# File 2015020168.json is already in directory raw_data/.
# File 2015020169.json is already in directory raw_data/.
# File 2015020170.json is already in directory raw_data/.
# File 2015020171.json is already in directory raw_data/.
# File 2015020172.json is already in directory raw_data/.
# File 2015020173.json is already in directory raw_data/.
# File 2015020174.json is already in directory raw_data/.
# File 2015020175.json is already in directory raw_data/.
# File 2015020176.json is already in directory raw_data/.
# File 2015020177.json is already in directory raw_data/.
# File 2015020178.json is already in directory raw_data/.
# File 2015020179.json is already in directory raw_data/.
# File 2015020180.json is already in directory raw_data/.
# File 2015020181.json is already in directory raw_data/.
# File 2015020182.json is already in directory raw_data/.
# File 2015020183.json is already in directory raw_data/.
# File 2015020184.json is already in directory raw_data/.
# File 2015020185.json is already in directory raw_data/.
# File 2015020186.json is already in directory raw_data/.
# File 2015020187.json is already in directory raw_data/.
# File 2015020188.json is already in directory raw_data/.
# File 2015020189.json is already in directory raw_data/.
# File 2015020190.json is already in directory raw_data/.
# File 2015020191.json is already in directory raw_data/.
# File 2015020192.json is already in directory raw_data/.
# File 2015020193.json is already in directory raw_data/.
# File 2015020194.json is already in directory raw_data/.
# File 2015020195.json is already in directory raw_data/.
# File 2015020196.json is already in directory raw_data/.
# File 2015020197.json is already in directory raw_data/.
# File 2015020198.json is already in directory raw_data/.
# File 2015020199.json is already in directory raw_data/.
# File 2015020200.json is already in directory raw_data/.
# File 2015020201.json is already in directory raw_data/.
# File 2015020202.json is already in directory raw_data/.
# File 2015020203.json is already in directory raw_data/.
# File 2015020204.json is already in directory raw_data/.
# File 2015020205.json is already in directory raw_data/.
# File 2015020206.json is already in directory raw_data/.
# File 2015020207.json is already in directory raw_data/.
# File 2015020208.json is already in directory raw_data/.
# File 2015020209.json is already in directory raw_data/.
# File 2015020210.json is already in directory raw_data/.
# File 2015020211.json is already in directory raw_data/.
# File 2015020212.json is already in directory raw_data/.
# File 2015020213.json is already in directory raw_data/.
# File 2015020214.json is already in directory raw_data/.
# File 2015020215.json is already in directory raw_data/.
# File 2015020216.json is already in directory raw_data/.
# File 2015020217.json is already in directory raw_data/.
# File 2015020218.json is already in directory raw_data/.
# File 2015020219.json is already in directory raw_data/.
# File 2015020220.json is already in directory raw_data/.
# File 2015020221.json is already in directory raw_data/.
# File 2015020222.json is already in directory raw_data/.
# File 2015020223.json is already in directory raw_data/.
# File 2015020224.json is already in directory raw_data/.
# File 2015020225.json is already in directory raw_data/.
# File 2015020226.json is already in directory raw_data/.
# File 2015020227.json is already in directory raw_data/.
# File 2015020228.json is already in directory raw_data/.
# File 2015020229.json is already in directory raw_data/.
# File 2015020230.json is already in directory raw_data/.
# File 2015020231.json is already in directory raw_data/.
# File 2015020232.json is already in directory raw_data/.
# File 2015020233.json is already in directory raw_data/.
# File 2015020234.json is already in directory raw_data/.
# File 2015020235.json is already in directory raw_data/.
# File 2015020236.json is already in directory raw_data/.
# File 2015020237.json is already in directory raw_data/.
# File 2015020238.json is already in directory raw_data/.
# File 2015020239.json is already in directory raw_data/.
# File 2015020240.json is already in directory raw_data/.
# File 2015020241.json is already in directory raw_data/.
# File 2015020242.json is already in directory raw_data/.
# File 2015020243.json is already in directory raw_data/.
# File 2015020244.json is already in directory raw_data/.
# File 2015020245.json is already in directory raw_data/.
# File 2015020246.json is already in directory raw_data/.
# File 2015020247.json is already in directory raw_data/.
# File 2015020248.json is already in directory raw_data/.
# File 2015020249.json is already in directory raw_data/.
# File 2015020250.json is already in directory raw_data/.
# File 2015020251.json is already in directory raw_data/.
# File 2015020252.json is already in directory raw_data/.
# File 2015020253.json is already in directory raw_data/.
# File 2015020254.json is already in directory raw_data/.
# File 2015020255.json is already in directory raw_data/.
# File 2015020256.json is already in directory raw_data/.
# File 2015020257.json is already in directory raw_data/.
# File 2015020258.json is already in directory raw_data/.
# File 2015020259.json is already in directory raw_data/.
# File 2015020260.json is already in directory raw_data/.
# File 2015020261.json is already in directory raw_data/.
# File 2015020262.json is already in directory raw_data/.
# File 2015020263.json is already in directory raw_data/.
# File 2015020264.json is already in directory raw_data/.
# File 2015020265.json is already in directory raw_data/.
# File 2015020266.json is already in directory raw_data/.
# File 2015020267.json is already in directory raw_data/.
# File 2015020268.json is already in directory raw_data/.
# File 2015020269.json is already in directory raw_data/.
# File 2015020271.json is already in directory raw_data/.
# File 2015020270.json is already in directory raw_data/.
# File 2015020272.json is already in directory raw_data/.
# File 2015020273.json is already in directory raw_data/.
# File 2015020274.json is already in directory raw_data/.
# File 2015020275.json is already in directory raw_data/.
# File 2015020276.json is already in directory raw_data/.
# File 2015020277.json is already in directory raw_data/.
# File 2015020278.json is already in directory raw_data/.
# File 2015020279.json is already in directory raw_data/.
# File 2015020280.json is already in directory raw_data/.
# File 2015020281.json is already in directory raw_data/.
# File 2015020282.json is already in directory raw_data/.
# File 2015020283.json is already in directory raw_data/.
# File 2015020284.json is already in directory raw_data/.
# File 2015020285.json is already in directory raw_data/.
# File 2015020286.json is already in directory raw_data/.
# File 2015020287.json is already in directory raw_data/.
# File 2015020288.json is already in directory raw_data/.
# File 2015020289.json is already in directory raw_data/.
# File 2015020290.json is already in directory raw_data/.
# File 2015020291.json is already in directory raw_data/.
# File 2015020292.json is already in directory raw_data/.
# File 2015020293.json is already in directory raw_data/.
# File 2015020294.json is already in directory raw_data/.
# File 2015020295.json is already in directory raw_data/.
# File 2015020296.json is already in directory raw_data/.
# File 2015020297.json is already in directory raw_data/.
# File 2015020298.json is already in directory raw_data/.
# File 2015020299.json is already in directory raw_data/.
# File 2015020300.json is already in directory raw_data/.
# File 2015020301.json is already in directory raw_data/.
# File 2015020302.json is already in directory raw_data/.
# File 2015020303.json is already in directory raw_data/.
# File 2015020304.json is already in directory raw_data/.
# File 2015020305.json is already in directory raw_data/.
# File 2015020306.json is already in directory raw_data/.
# File 2015020307.json is already in directory raw_data/.
# File 2015020308.json is already in directory raw_data/.
# File 2015020309.json is already in directory raw_data/.
# File 2015020310.json is already in directory raw_data/.
# File 2015020311.json is already in directory raw_data/.
# File 2015020312.json is already in directory raw_data/.
# File 2015020313.json is already in directory raw_data/.
# File 2015020314.json is already in directory raw_data/.
# File 2015020315.json is already in directory raw_data/.
# File 2015020316.json is already in directory raw_data/.
# File 2015020317.json is already in directory raw_data/.
# File 2015020318.json is already in directory raw_data/.
# File 2015020320.json is already in directory raw_data/.
# File 2015020321.json is already in directory raw_data/.
# File 2015020322.json is already in directory raw_data/.
# File 2015020323.json is already in directory raw_data/.
# File 2015020324.json is already in directory raw_data/.
# File 2015020319.json is already in directory raw_data/.
# File 2015020325.json is already in directory raw_data/.
# File 2015020326.json is already in directory raw_data/.
# File 2015020327.json is already in directory raw_data/.
# File 2015020328.json is already in directory raw_data/.
# File 2015020329.json is already in directory raw_data/.
# File 2015020330.json is already in directory raw_data/.
# File 2015020331.json is already in directory raw_data/.
# File 2015020332.json is already in directory raw_data/.
# File 2015020333.json is already in directory raw_data/.
# File 2015020334.json is already in directory raw_data/.
# File 2015020335.json is already in directory raw_data/.
# File 2015020336.json is already in directory raw_data/.
# File 2015020337.json is already in directory raw_data/.
# File 2015020338.json is already in directory raw_data/.
# File 2015020339.json is already in directory raw_data/.
# File 2015020340.json is already in directory raw_data/.
# File 2015020341.json is already in directory raw_data/.
# File 2015020342.json is already in directory raw_data/.
# File 2015020343.json is already in directory raw_data/.
# File 2015020344.json is already in directory raw_data/.
# File 2015020345.json is already in directory raw_data/.
# File 2015020346.json is already in directory raw_data/.
# File 2015020347.json is already in directory raw_data/.
# File 2015020348.json is already in directory raw_data/.
# File 2015020349.json is already in directory raw_data/.
# File 2015020350.json is already in directory raw_data/.
# File 2015020351.json is already in directory raw_data/.
# File 2015020352.json is already in directory raw_data/.
# File 2015020353.json is already in directory raw_data/.
# File 2015020354.json is already in directory raw_data/.
# File 2015020355.json is already in directory raw_data/.
# File 2015020356.json is already in directory raw_data/.
# File 2015020357.json is already in directory raw_data/.
# File 2015020358.json is already in directory raw_data/.
# File 2015020359.json is already in directory raw_data/.
# File 2015020360.json is already in directory raw_data/.
# File 2015020361.json is already in directory raw_data/.
# File 2015020362.json is already in directory raw_data/.
# File 2015020363.json is already in directory raw_data/.
# File 2015020364.json is already in directory raw_data/.
# File 2015020365.json is already in directory raw_data/.
# File 2015020366.json is already in directory raw_data/.
# File 2015020367.json is already in directory raw_data/.
# File 2015020368.json is already in directory raw_data/.
# File 2015020369.json is already in directory raw_data/.
# File 2015020370.json is already in directory raw_data/.
# File 2015020371.json is already in directory raw_data/.
# File 2015020372.json is already in directory raw_data/.
# File 2015020373.json is already in directory raw_data/.
# File 2015020374.json is already in directory raw_data/.
# File 2015020375.json is already in directory raw_data/.
# File 2015020376.json is already in directory raw_data/.
# File 2015020377.json is already in directory raw_data/.
# File 2015020378.json is already in directory raw_data/.
# File 2015020379.json is already in directory raw_data/.
# File 2015020380.json is already in directory raw_data/.
# File 2015020381.json is already in directory raw_data/.
# File 2015020382.json is already in directory raw_data/.
# File 2015020383.json is already in directory raw_data/.
# File 2015020384.json is already in directory raw_data/.
# File 2015020385.json is already in directory raw_data/.
# File 2015020386.json is already in directory raw_data/.
# File 2015020387.json is already in directory raw_data/.
# File 2015020388.json is already in directory raw_data/.
# File 2015020389.json is already in directory raw_data/.
# File 2015020390.json is already in directory raw_data/.
# File 2015020391.json is already in directory raw_data/.
# File 2015020392.json is already in directory raw_data/.
# File 2015020393.json is already in directory raw_data/.
# File 2015020394.json is already in directory raw_data/.
# File 2015020395.json is already in directory raw_data/.
# File 2015020396.json is already in directory raw_data/.
# File 2015020397.json is already in directory raw_data/.
# File 2015020398.json is already in directory raw_data/.
# File 2015020399.json is already in directory raw_data/.
# File 2015020400.json is already in directory raw_data/.
# File 2015020401.json is already in directory raw_data/.
# File 2015020402.json is already in directory raw_data/.
# File 2015020403.json is already in directory raw_data/.
# File 2015020404.json is already in directory raw_data/.
# File 2015020405.json is already in directory raw_data/.
# File 2015020406.json is already in directory raw_data/.
# File 2015020407.json is already in directory raw_data/.
# File 2015020408.json is already in directory raw_data/.
# File 2015020410.json is already in directory raw_data/.
# File 2015020409.json is already in directory raw_data/.
# File 2015020411.json is already in directory raw_data/.
# File 2015020412.json is already in directory raw_data/.
# File 2015020413.json is already in directory raw_data/.
# File 2015020414.json is already in directory raw_data/.
# File 2015020415.json is already in directory raw_data/.
# File 2015020416.json is already in directory raw_data/.
# File 2015020417.json is already in directory raw_data/.
# File 2015020419.json is already in directory raw_data/.
# File 2015020418.json is already in directory raw_data/.
# File 2015020420.json is already in directory raw_data/.
# File 2015020421.json is already in directory raw_data/.
# File 2015020422.json is already in directory raw_data/.
# File 2015020423.json is already in directory raw_data/.
# File 2015020424.json is already in directory raw_data/.
# File 2015020425.json is already in directory raw_data/.
# File 2015020426.json is already in directory raw_data/.
# File 2015020427.json is already in directory raw_data/.
# File 2015020428.json is already in directory raw_data/.
# File 2015020429.json is already in directory raw_data/.
# File 2015020430.json is already in directory raw_data/.
# File 2015020431.json is already in directory raw_data/.
# File 2015020433.json is already in directory raw_data/.
# File 2015020432.json is already in directory raw_data/.
# File 2015020434.json is already in directory raw_data/.
# File 2015020435.json is already in directory raw_data/.
# File 2015020436.json is already in directory raw_data/.
# File 2015020437.json is already in directory raw_data/.
# File 2015020438.json is already in directory raw_data/.
# File 2015020439.json is already in directory raw_data/.
# File 2015020440.json is already in directory raw_data/.
# File 2015020441.json is already in directory raw_data/.
# File 2015020442.json is already in directory raw_data/.
# File 2015020443.json is already in directory raw_data/.
# File 2015020444.json is already in directory raw_data/.
# File 2015020445.json is already in directory raw_data/.
# File 2015020446.json is already in directory raw_data/.
# File 2015020447.json is already in directory raw_data/.
# File 2015020448.json is already in directory raw_data/.
# File 2015020449.json is already in directory raw_data/.
# File 2015020450.json is already in directory raw_data/.
# File 2015020451.json is already in directory raw_data/.
# File 2015020452.json is already in directory raw_data/.
# File 2015020453.json is already in directory raw_data/.
# File 2015020454.json is already in directory raw_data/.
# File 2015020455.json is already in directory raw_data/.
# File 2015020456.json is already in directory raw_data/.
# File 2015020457.json is already in directory raw_data/.
# File 2015020458.json is already in directory raw_data/.
# File 2015020459.json is already in directory raw_data/.
# File 2015020460.json is already in directory raw_data/.
# File 2015020461.json is already in directory raw_data/.
# File 2015020462.json is already in directory raw_data/.
# File 2015020463.json is already in directory raw_data/.
# File 2015020464.json is already in directory raw_data/.
# File 2015020465.json is already in directory raw_data/.
# File 2015020466.json is already in directory raw_data/.
# File 2015020467.json is already in directory raw_data/.
# File 2015020468.json is already in directory raw_data/.
# File 2015020469.json is already in directory raw_data/.
# File 2015020470.json is already in directory raw_data/.
# File 2015020471.json is already in directory raw_data/.
# File 2015020472.json is already in directory raw_data/.
# File 2015020473.json is already in directory raw_data/.
# File 2015020474.json is already in directory raw_data/.
# File 2015020475.json is already in directory raw_data/.
# File 2015020476.json is already in directory raw_data/.
# File 2015020477.json is already in directory raw_data/.
# File 2015020478.json is already in directory raw_data/.
# File 2015020479.json is already in directory raw_data/.
# File 2015020480.json is already in directory raw_data/.
# File 2015020481.json is already in directory raw_data/.
# File 2015020482.json is already in directory raw_data/.
# File 2015020483.json is already in directory raw_data/.
# File 2015020484.json is already in directory raw_data/.
# File 2015020485.json is already in directory raw_data/.
# File 2015020486.json is already in directory raw_data/.
# File 2015020487.json is already in directory raw_data/.
# File 2015020488.json is already in directory raw_data/.
# File 2015020489.json is already in directory raw_data/.
# File 2015020490.json is already in directory raw_data/.
# File 2015020491.json is already in directory raw_data/.
# File 2015020492.json is already in directory raw_data/.
# File 2015020493.json is already in directory raw_data/.
# File 2015020494.json is already in directory raw_data/.
# File 2015020495.json is already in directory raw_data/.
# File 2015020496.json is already in directory raw_data/.
# File 2015020497.json is already in directory raw_data/.
# File 2015020498.json is already in directory raw_data/.
# File 2015020499.json is already in directory raw_data/.
# File 2015020500.json is already in directory raw_data/.
# File 2015020501.json is already in directory raw_data/.
# File 2015020502.json is already in directory raw_data/.
# File 2015020503.json is already in directory raw_data/.
# File 2015020504.json is already in directory raw_data/.
# File 2015020505.json is already in directory raw_data/.
# File 2015020506.json is already in directory raw_data/.
# File 2015020507.json is already in directory raw_data/.
# File 2015020508.json is already in directory raw_data/.
# File 2015020509.json is already in directory raw_data/.
# File 2015020510.json is already in directory raw_data/.
# File 2015020511.json is already in directory raw_data/.
# File 2015020512.json is already in directory raw_data/.
# File 2015020513.json is already in directory raw_data/.
# File 2015020514.json is already in directory raw_data/.
# File 2015020515.json is already in directory raw_data/.
# File 2015020516.json is already in directory raw_data/.
# File 2015020517.json is already in directory raw_data/.
# File 2015020518.json is already in directory raw_data/.
# File 2015020519.json is already in directory raw_data/.
# File 2015020520.json is already in directory raw_data/.
# File 2015020521.json is already in directory raw_data/.
# File 2015020522.json is already in directory raw_data/.
# File 2015020523.json is already in directory raw_data/.
# File 2015020524.json is already in directory raw_data/.
# File 2015020525.json is already in directory raw_data/.
# File 2015020526.json is already in directory raw_data/.
# File 2015020527.json is already in directory raw_data/.
# File 2015020528.json is already in directory raw_data/.
# File 2015020529.json is already in directory raw_data/.
# File 2015020530.json is already in directory raw_data/.
# File 2015020531.json is already in directory raw_data/.
# File 2015020532.json is already in directory raw_data/.
# File 2015020533.json is already in directory raw_data/.
# File 2015020534.json is already in directory raw_data/.
# File 2015020535.json is already in directory raw_data/.
# File 2015020536.json is already in directory raw_data/.
# File 2015020537.json is already in directory raw_data/.
# File 2015020538.json is already in directory raw_data/.
# File 2015020539.json is already in directory raw_data/.
# File 2015020540.json is already in directory raw_data/.
# File 2015020541.json is already in directory raw_data/.
# File 2015020542.json is already in directory raw_data/.
# File 2015020543.json is already in directory raw_data/.
# File 2015020544.json is already in directory raw_data/.
# File 2015020545.json is already in directory raw_data/.
# File 2015020546.json is already in directory raw_data/.
# File 2015020547.json is already in directory raw_data/.
# File 2015020548.json is already in directory raw_data/.
# File 2015020549.json is already in directory raw_data/.
# File 2015020550.json is already in directory raw_data/.
# File 2015020551.json is already in directory raw_data/.
# File 2015020552.json is already in directory raw_data/.
# File 2015020553.json is already in directory raw_data/.
# File 2015020554.json is already in directory raw_data/.
# File 2015020555.json is already in directory raw_data/.
# File 2015020556.json is already in directory raw_data/.
# File 2015020557.json is already in directory raw_data/.
# File 2015020558.json is already in directory raw_data/.
# File 2015020559.json is already in directory raw_data/.
# File 2015020560.json is already in directory raw_data/.
# File 2015020561.json is already in directory raw_data/.
# File 2015020562.json is already in directory raw_data/.
# File 2015020563.json is already in directory raw_data/.
# File 2015020564.json is already in directory raw_data/.
# File 2015020565.json is already in directory raw_data/.
# File 2015020566.json is already in directory raw_data/.
# File 2015020567.json is already in directory raw_data/.
# File 2015020568.json is already in directory raw_data/.
# File 2015020569.json is already in directory raw_data/.
# File 2015020570.json is already in directory raw_data/.
# File 2015020571.json is already in directory raw_data/.
# File 2015020572.json is already in directory raw_data/.
# File 2015020573.json is already in directory raw_data/.
# File 2015020574.json is already in directory raw_data/.
# File 2015020575.json is already in directory raw_data/.
# File 2015020576.json is already in directory raw_data/.
# File 2015020577.json is already in directory raw_data/.
# File 2015020578.json is already in directory raw_data/.
# File 2015020579.json is already in directory raw_data/.
# File 2015020580.json is already in directory raw_data/.
# File 2015020581.json is already in directory raw_data/.
# File 2015020582.json is already in directory raw_data/.
# File 2015020583.json is already in directory raw_data/.
# File 2015020584.json is already in directory raw_data/.
# File 2015020585.json is already in directory raw_data/.
# File 2015020586.json is already in directory raw_data/.
# File 2015020587.json is already in directory raw_data/.
# File 2015020588.json is already in directory raw_data/.
# File 2015020589.json is already in directory raw_data/.
# File 2015020590.json is already in directory raw_data/.
# File 2015020592.json is already in directory raw_data/.
# File 2015020593.json is already in directory raw_data/.
# File 2015020591.json is already in directory raw_data/.
# File 2015020594.json is already in directory raw_data/.
# File 2015020595.json is already in directory raw_data/.
# File 2015020596.json is already in directory raw_data/.
# File 2015020597.json is already in directory raw_data/.
# File 2015020598.json is already in directory raw_data/.
# File 2015020599.json is already in directory raw_data/.
# File 2015020600.json is already in directory raw_data/.
# File 2015020601.json is already in directory raw_data/.
# File 2015020602.json is already in directory raw_data/.
# File 2015020603.json is already in directory raw_data/.
# File 2015020604.json is already in directory raw_data/.
# File 2015020605.json is already in directory raw_data/.
# File 2015020606.json is already in directory raw_data/.
# File 2015020607.json is already in directory raw_data/.
# File 2015020608.json is already in directory raw_data/.
# File 2015020609.json is already in directory raw_data/.
# File 2015020610.json is already in directory raw_data/.
# File 2015020611.json is already in directory raw_data/.
# File 2015020612.json is already in directory raw_data/.
# File 2015020613.json is already in directory raw_data/.
# File 2015020614.json is already in directory raw_data/.
# File 2015020615.json is already in directory raw_data/.
# File 2015020616.json is already in directory raw_data/.
# File 2015020617.json is already in directory raw_data/.
# File 2015020618.json is already in directory raw_data/.
# File 2015020619.json is already in directory raw_data/.
# File 2015020620.json is already in directory raw_data/.
# File 2015020621.json is already in directory raw_data/.
# File 2015020622.json is already in directory raw_data/.
# File 2015020623.json is already in directory raw_data/.
# File 2015020624.json is already in directory raw_data/.
# File 2015020625.json is already in directory raw_data/.
# File 2015020626.json is already in directory raw_data/.
# File 2015020627.json is already in directory raw_data/.
# File 2015020628.json is already in directory raw_data/.
# File 2015020629.json is already in directory raw_data/.
# File 2015020630.json is already in directory raw_data/.
# File 2015020631.json is already in directory raw_data/.
# File 2015020632.json is already in directory raw_data/.
# File 2015020633.json is already in directory raw_data/.
# File 2015020634.json is already in directory raw_data/.
# File 2015020635.json is already in directory raw_data/.
# File 2015020636.json is already in directory raw_data/.
# File 2015020637.json is already in directory raw_data/.
# File 2015020638.json is already in directory raw_data/.
# File 2015020639.json is already in directory raw_data/.
# File 2015020640.json is already in directory raw_data/.
# File 2015020641.json is already in directory raw_data/.
# File 2015020642.json is already in directory raw_data/.
# File 2015020643.json is already in directory raw_data/.
# File 2015020644.json is already in directory raw_data/.
# File 2015020645.json is already in directory raw_data/.
# File 2015020646.json is already in directory raw_data/.
# File 2015020647.json is already in directory raw_data/.
# File 2015020648.json is already in directory raw_data/.
# File 2015020649.json is already in directory raw_data/.
# File 2015020650.json is already in directory raw_data/.
# File 2015020651.json is already in directory raw_data/.
# File 2015020652.json is already in directory raw_data/.
# File 2015020653.json is already in directory raw_data/.
# File 2015020654.json is already in directory raw_data/.
# File 2015020655.json is already in directory raw_data/.
# File 2015020656.json is already in directory raw_data/.
# File 2015020657.json is already in directory raw_data/.
# File 2015020658.json is already in directory raw_data/.
# File 2015020659.json is already in directory raw_data/.
# File 2015020660.json is already in directory raw_data/.
# File 2015020667.json is already in directory raw_data/.
# File 2015020661.json is already in directory raw_data/.
# File 2015020662.json is already in directory raw_data/.
# File 2015020663.json is already in directory raw_data/.
# File 2015020664.json is already in directory raw_data/.
# File 2015020665.json is already in directory raw_data/.
# File 2015020666.json is already in directory raw_data/.
# File 2015020668.json is already in directory raw_data/.
# File 2015020669.json is already in directory raw_data/.
# File 2015020670.json is already in directory raw_data/.
# File 2015020671.json is already in directory raw_data/.
# File 2015020672.json is already in directory raw_data/.
# File 2015020673.json is already in directory raw_data/.
# File 2015020674.json is already in directory raw_data/.
# File 2015020675.json is already in directory raw_data/.
# File 2015020676.json is already in directory raw_data/.
# File 2015020677.json is already in directory raw_data/.
# File 2015020678.json is already in directory raw_data/.
# File 2015020679.json is already in directory raw_data/.
# File 2015020680.json is already in directory raw_data/.
# File 2015020681.json is already in directory raw_data/.
# File 2015020682.json is already in directory raw_data/.
# File 2015020683.json is already in directory raw_data/.
# File 2015020684.json is already in directory raw_data/.
# File 2015020685.json is already in directory raw_data/.
# File 2015020686.json is already in directory raw_data/.
# File 2015020687.json is already in directory raw_data/.
# File 2015020688.json is already in directory raw_data/.
# File 2015020689.json is already in directory raw_data/.
# File 2015020690.json is already in directory raw_data/.
# File 2015020691.json is already in directory raw_data/.
# File 2015020692.json is already in directory raw_data/.
# File 2015020693.json is already in directory raw_data/.
# File 2015020694.json is already in directory raw_data/.
# File 2015020695.json is already in directory raw_data/.
# File 2015020696.json is already in directory raw_data/.
# File 2015020697.json is already in directory raw_data/.
# File 2015020698.json is already in directory raw_data/.
# File 2015020699.json is already in directory raw_data/.
# File 2015020700.json is already in directory raw_data/.
# File 2015020701.json is already in directory raw_data/.
# File 2015020702.json is already in directory raw_data/.
# File 2015020703.json is already in directory raw_data/.
# File 2015020705.json is already in directory raw_data/.
# File 2015020706.json is already in directory raw_data/.
# File 2015020707.json is already in directory raw_data/.
# File 2015020708.json is already in directory raw_data/.
# File 2015020709.json is already in directory raw_data/.
# File 2015020710.json is already in directory raw_data/.
# File 2015020711.json is already in directory raw_data/.
# File 2015020712.json is already in directory raw_data/.
# File 2015020713.json is already in directory raw_data/.
# File 2015020714.json is already in directory raw_data/.
# File 2015020715.json is already in directory raw_data/.
# File 2015020717.json is already in directory raw_data/.
# File 2015020718.json is already in directory raw_data/.
# File 2015020719.json is already in directory raw_data/.
# File 2015020721.json is already in directory raw_data/.
# File 2015020722.json is already in directory raw_data/.
# File 2015020723.json is already in directory raw_data/.
# File 2015020724.json is already in directory raw_data/.
# File 2015020725.json is already in directory raw_data/.
# File 2015020727.json is already in directory raw_data/.
# File 2015020728.json is already in directory raw_data/.
# File 2015020726.json is already in directory raw_data/.
# File 2015020729.json is already in directory raw_data/.
# File 2015020730.json is already in directory raw_data/.
# File 2015020731.json is already in directory raw_data/.
# File 2015020732.json is already in directory raw_data/.
# File 2015020733.json is already in directory raw_data/.
# File 2015020734.json is already in directory raw_data/.
# File 2015020735.json is already in directory raw_data/.
# File 2015020736.json is already in directory raw_data/.
# File 2015020737.json is already in directory raw_data/.
# File 2015020738.json is already in directory raw_data/.
# File 2015020739.json is already in directory raw_data/.
# File 2015020740.json is already in directory raw_data/.
# File 2015020741.json is already in directory raw_data/.
# File 2015020742.json is already in directory raw_data/.
# File 2015020743.json is already in directory raw_data/.
# File 2015020744.json is already in directory raw_data/.
# File 2015020745.json is already in directory raw_data/.
# File 2015020746.json is already in directory raw_data/.
# File 2015020747.json is already in directory raw_data/.
# File 2015020748.json is already in directory raw_data/.
# File 2015020749.json is already in directory raw_data/.
# File 2015020750.json is already in directory raw_data/.
# File 2015020751.json is already in directory raw_data/.
# File 2015020752.json is already in directory raw_data/.
# File 2015020753.json is already in directory raw_data/.
# File 2015020754.json is already in directory raw_data/.
# File 2015020755.json is already in directory raw_data/.
# File 2015020756.json is already in directory raw_data/.
# File 2015020757.json is already in directory raw_data/.
# File 2015020758.json is already in directory raw_data/.
# File 2015020759.json is already in directory raw_data/.
# File 2015020760.json is already in directory raw_data/.
# File 2015020761.json is already in directory raw_data/.
# File 2015020762.json is already in directory raw_data/.
# File 2015020763.json is already in directory raw_data/.
# File 2015020764.json is already in directory raw_data/.
# File 2015020765.json is already in directory raw_data/.
# File 2015020766.json is already in directory raw_data/.
# File 2015020767.json is already in directory raw_data/.
# File 2015020768.json is already in directory raw_data/.
# File 2015020769.json is already in directory raw_data/.
# File 2015020770.json is already in directory raw_data/.
# File 2015020771.json is already in directory raw_data/.
# File 2015020772.json is already in directory raw_data/.
# File 2015020773.json is already in directory raw_data/.
# File 2015020774.json is already in directory raw_data/.
# File 2015020775.json is already in directory raw_data/.
# File 2015020776.json is already in directory raw_data/.
# File 2015020777.json is already in directory raw_data/.
# File 2015020778.json is already in directory raw_data/.
# File 2015020779.json is already in directory raw_data/.
# File 2015020780.json is already in directory raw_data/.
# File 2015020781.json is already in directory raw_data/.
# File 2015020782.json is already in directory raw_data/.
# File 2015020783.json is already in directory raw_data/.
# File 2015020784.json is already in directory raw_data/.
# File 2015020785.json is already in directory raw_data/.
# File 2015020786.json is already in directory raw_data/.
# File 2015020787.json is already in directory raw_data/.
# File 2015020788.json is already in directory raw_data/.
# File 2015020789.json is already in directory raw_data/.
# File 2015020790.json is already in directory raw_data/.
# File 2015020791.json is already in directory raw_data/.
# File 2015020792.json is already in directory raw_data/.
# File 2015020793.json is already in directory raw_data/.
# File 2015020794.json is already in directory raw_data/.
# File 2015020795.json is already in directory raw_data/.
# File 2015020797.json is already in directory raw_data/.
# File 2015020798.json is already in directory raw_data/.
# File 2015020799.json is already in directory raw_data/.
# File 2015020796.json is already in directory raw_data/.
# File 2015020800.json is already in directory raw_data/.
# File 2015020801.json is already in directory raw_data/.
# File 2015020802.json is already in directory raw_data/.
# File 2015020803.json is already in directory raw_data/.
# File 2015020804.json is already in directory raw_data/.
# File 2015020805.json is already in directory raw_data/.
# File 2015020806.json is already in directory raw_data/.
# File 2015020807.json is already in directory raw_data/.
# File 2015020808.json is already in directory raw_data/.
# File 2015020809.json is already in directory raw_data/.
# File 2015020810.json is already in directory raw_data/.
# File 2015020811.json is already in directory raw_data/.
# File 2015020812.json is already in directory raw_data/.
# File 2015020813.json is already in directory raw_data/.
# File 2015020814.json is already in directory raw_data/.
# File 2015020815.json is already in directory raw_data/.
# File 2015020816.json is already in directory raw_data/.
# File 2015020817.json is already in directory raw_data/.
# File 2015020818.json is already in directory raw_data/.
# File 2015020819.json is already in directory raw_data/.
# File 2015020820.json is already in directory raw_data/.
# File 2015020821.json is already in directory raw_data/.
# File 2015020822.json is already in directory raw_data/.
# File 2015020823.json is already in directory raw_data/.
# File 2015020824.json is already in directory raw_data/.
# File 2015020825.json is already in directory raw_data/.
# File 2015020826.json is already in directory raw_data/.
# File 2015020827.json is already in directory raw_data/.
# File 2015020828.json is already in directory raw_data/.
# File 2015020829.json is already in directory raw_data/.
# File 2015020830.json is already in directory raw_data/.
# File 2015020831.json is already in directory raw_data/.
# File 2015020832.json is already in directory raw_data/.
# File 2015020833.json is already in directory raw_data/.
# File 2015020834.json is already in directory raw_data/.
# File 2015020835.json is already in directory raw_data/.
# File 2015020836.json is already in directory raw_data/.
# File 2015020837.json is already in directory raw_data/.
# File 2015020838.json is already in directory raw_data/.
# File 2015020839.json is already in directory raw_data/.
# File 2015020840.json is already in directory raw_data/.
# File 2015020841.json is already in directory raw_data/.
# File 2015020842.json is already in directory raw_data/.
# File 2015020843.json is already in directory raw_data/.
# File 2015020844.json is already in directory raw_data/.
# File 2015020845.json is already in directory raw_data/.
# File 2015020846.json is already in directory raw_data/.
# File 2015020847.json is already in directory raw_data/.
# File 2015020848.json is already in directory raw_data/.
# File 2015020849.json is already in directory raw_data/.
# File 2015020850.json is already in directory raw_data/.
# File 2015020851.json is already in directory raw_data/.
# File 2015020852.json is already in directory raw_data/.
# File 2015020853.json is already in directory raw_data/.
# File 2015020854.json is already in directory raw_data/.
# File 2015020855.json is already in directory raw_data/.
# File 2015020856.json is already in directory raw_data/.
# File 2015020857.json is already in directory raw_data/.
# ...
# File 2019020929.json is already in directory raw_data/.
# File 2019020930.json is already in directory raw_data/.
# File 2019020931.json is already in directory raw_data/.
# File 2019020932.json is already in directory raw_data/.
# File 2019020933.json is already in directory raw_data/.
# File 2019020934.json is already in directory raw_data/.
# File 2019020935.json is already in directory raw_data/.
# File 2019020936.json is already in directory raw_data/.
# File 2019020937.json is already in directory raw_data/.
# File 2019020938.json is already in directory raw_data/.
# File 2019020939.json is already in directory raw_data/.
# File 2019020940.json is already in directory raw_data/.
# File 2019020942.json is already in directory raw_data/.
# File 2019020941.json is already in directory raw_data/.
# File 2019020943.json is already in directory raw_data/.
# File 2019020944.json is already in directory raw_data/.
# File 2019020945.json is already in directory raw_data/.
# File 2019020946.json is already in directory raw_data/.
# File 2019020947.json is already in directory raw_data/.
# File 2019020948.json is already in directory raw_data/.
# File 2019020949.json is already in directory raw_data/.
# File 2019020950.json is already in directory raw_data/.
# File 2019020951.json is already in directory raw_data/.
# File 2019020952.json is already in directory raw_data/.
# File 2019020953.json is already in directory raw_data/.
# File 2019020954.json is already in directory raw_data/.
# File 2019020955.json is already in directory raw_data/.
# File 2019020956.json is already in directory raw_data/.
# File 2019020957.json is already in directory raw_data/.
# File 2019020958.json is already in directory raw_data/.
# File 2019020959.json is already in directory raw_data/.
# File 2019020960.json is already in directory raw_data/.
# File 2019020961.json is already in directory raw_data/.
# File 2019020962.json is already in directory raw_data/.
# File 2019020963.json is already in directory raw_data/.
# File 2019020964.json is already in directory raw_data/.
# File 2019020965.json is already in directory raw_data/.
# File 2019020966.json is already in directory raw_data/.
# File 2019020967.json is already in directory raw_data/.
# File 2019020968.json is already in directory raw_data/.
# File 2019020969.json is already in directory raw_data/.
# File 2019020970.json is already in directory raw_data/.
# File 2019020971.json is already in directory raw_data/.
# File 2019020972.json is already in directory raw_data/.
# File 2019020973.json is already in directory raw_data/.
# File 2019020974.json is already in directory raw_data/.
# File 2019020975.json is already in directory raw_data/.
# File 2019020976.json is already in directory raw_data/.
# File 2019020977.json is already in directory raw_data/.
# File 2019020978.json is already in directory raw_data/.
# File 2019020979.json is already in directory raw_data/.
# File 2019020980.json is already in directory raw_data/.
# File 2019020981.json is already in directory raw_data/.
# File 2019020982.json is already in directory raw_data/.
# File 2019020983.json is already in directory raw_data/.
# File 2019020985.json is already in directory raw_data/.
# File 2019020986.json is already in directory raw_data/.
# File 2019020987.json is already in directory raw_data/.
# File 2019020984.json is already in directory raw_data/.
# File 2019020988.json is already in directory raw_data/.
# File 2019020989.json is already in directory raw_data/.
# File 2019020990.json is already in directory raw_data/.
# File 2019020991.json is already in directory raw_data/.
# File 2019020992.json is already in directory raw_data/.
# File 2019020993.json is already in directory raw_data/.
# File 2019020994.json is already in directory raw_data/.
# File 2019020995.json is already in directory raw_data/.
# File 2019020996.json is already in directory raw_data/.
# File 2019020997.json is already in directory raw_data/.
# File 2019020998.json is already in directory raw_data/.
# File 2019020999.json is already in directory raw_data/.
# File 2019021000.json is already in directory raw_data/.
# File 2019021001.json is already in directory raw_data/.
# File 2019021002.json is already in directory raw_data/.
# File 2019021003.json is already in directory raw_data/.
# File 2019021004.json is already in directory raw_data/.
# File 2019021005.json is already in directory raw_data/.
# File 2019021007.json is already in directory raw_data/.
# File 2019021006.json is already in directory raw_data/.
# File 2019021008.json is already in directory raw_data/.
# File 2019021009.json is already in directory raw_data/.
# File 2019021010.json is already in directory raw_data/.
# File 2019021011.json is already in directory raw_data/.
# File 2019021012.json is already in directory raw_data/.
# File 2019021013.json is already in directory raw_data/.
# File 2019021014.json is already in directory raw_data/.
# File 2019021015.json is already in directory raw_data/.
# File 2019021016.json is already in directory raw_data/.
# File 2019021017.json is already in directory raw_data/.
# File 2019021018.json is already in directory raw_data/.
# File 2019021020.json is already in directory raw_data/.
# File 2019021021.json is already in directory raw_data/.
# File 2019021022.json is already in directory raw_data/.
# File 2019021019.json is already in directory raw_data/.
# File 2019021023.json is already in directory raw_data/.
# File 2019021024.json is already in directory raw_data/.
# File 2019021025.json is already in directory raw_data/.
# File 2019021026.json is already in directory raw_data/.
# File 2019021027.json is already in directory raw_data/.
# File 2019021028.json is already in directory raw_data/.
# File 2019021029.json is already in directory raw_data/.
# File 2019021030.json is already in directory raw_data/.
# File 2019021031.json is already in directory raw_data/.
# File 2019021032.json is already in directory raw_data/.
# File 2019021033.json is already in directory raw_data/.
# File 2019021034.json is already in directory raw_data/.
# File 2019021035.json is already in directory raw_data/.
# File 2019021036.json is already in directory raw_data/.
# File 2019021037.json is already in directory raw_data/.
# File 2019021038.json is already in directory raw_data/.
# File 2019021039.json is already in directory raw_data/.
# File 2019021040.json is already in directory raw_data/.
# File 2019021041.json is already in directory raw_data/.
# File 2019021042.json is already in directory raw_data/.
# File 2019021043.json is already in directory raw_data/.
# File 2019021044.json is already in directory raw_data/.
# File 2019021045.json is already in directory raw_data/.
# File 2019021046.json is already in directory raw_data/.
# File 2019021047.json is already in directory raw_data/.
# File 2019021048.json is already in directory raw_data/.
# File 2019021049.json is already in directory raw_data/.
# File 2019021050.json is already in directory raw_data/.
# File 2019021051.json is already in directory raw_data/.
# File 2019021052.json is already in directory raw_data/.
# File 2019021053.json is already in directory raw_data/.
# File 2019021054.json is already in directory raw_data/.
# File 2019021055.json is already in directory raw_data/.
# File 2019021056.json is already in directory raw_data/.
# File 2019021057.json is already in directory raw_data/.
# File 2019021058.json is already in directory raw_data/.
# File 2019021059.json is already in directory raw_data/.
# File 2019021060.json is already in directory raw_data/.
# File 2019021062.json is already in directory raw_data/.
# File 2019021061.json is already in directory raw_data/.
# File 2019021063.json is already in directory raw_data/.
# File 2019021064.json is already in directory raw_data/.
# File 2019021065.json is already in directory raw_data/.
# File 2019021066.json is already in directory raw_data/.
# File 2019021067.json is already in directory raw_data/.
# File 2019021075.json is already in directory raw_data/.
# File 2019021068.json is already in directory raw_data/.
# File 2019021069.json is already in directory raw_data/.
# File 2019021070.json is already in directory raw_data/.
# File 2019021071.json is already in directory raw_data/.
# File 2019021072.json is already in directory raw_data/.
# File 2019021073.json is already in directory raw_data/.
# File 2019021074.json is already in directory raw_data/.
# File 2019021076.json is already in directory raw_data/.
# File 2019021077.json is already in directory raw_data/.
# File 2019021078.json is already in directory raw_data/.
# File 2019021079.json is already in directory raw_data/.
# File 2019021080.json is already in directory raw_data/.
# File 2019020876.json is already in directory raw_data/.
# File 2019021081.json is already in directory raw_data/.
# File 2019021082.json is already in directory raw_data/.
# File 2019030031.json is already in directory raw_data/.
# File 2019030061.json is already in directory raw_data/.
# File 2019030041.json is already in directory raw_data/.
# File 2019030021.json is already in directory raw_data/.
# File 2019030091.json is already in directory raw_data/.
# File 2019030071.json is already in directory raw_data/.
# File 2019030001.json is already in directory raw_data/.
# File 2019030011.json is already in directory raw_data/.
# File 2019030051.json is already in directory raw_data/.
# File 2019030081.json is already in directory raw_data/.
# File 2019030032.json is already in directory raw_data/.
# File 2019030092.json is already in directory raw_data/.
# File 2019030002.json is already in directory raw_data/.
# File 2019030012.json is already in directory raw_data/.
# File 2019030022.json is already in directory raw_data/.
# File 2019030062.json is already in directory raw_data/.
# File 2019030042.json is already in directory raw_data/.
# File 2019030072.json is already in directory raw_data/.
# File 2019030052.json is already in directory raw_data/.
# File 2019030093.json is already in directory raw_data/.
# File 2019030033.json is already in directory raw_data/.
# File 2019030082.json is already in directory raw_data/.
# File 2019030043.json is already in directory raw_data/.
# File 2019030073.json is already in directory raw_data/.
# File 2019030003.json is already in directory raw_data/.
# File 2019030013.json is already in directory raw_data/.
# File 2019030023.json is already in directory raw_data/.
# File 2019030063.json is already in directory raw_data/.
# File 2019030083.json is already in directory raw_data/.
# File 2019030004.json is already in directory raw_data/.
# File 2019030014.json is already in directory raw_data/.
# File 2019030053.json is already in directory raw_data/.
# File 2019030094.json is already in directory raw_data/.
# File 2019030044.json is already in directory raw_data/.
# File 2019030074.json is already in directory raw_data/.
# File 2019030024.json is already in directory raw_data/.
# File 2019030064.json is already in directory raw_data/.
# File 2019030054.json is already in directory raw_data/.
# File 2019030084.json is already in directory raw_data/.
# File 2019030015.json is already in directory raw_data/.
# File 2019030006.json is already in directory raw_data/.
# File 2019030005.json is already in directory raw_data/.
# File 2019030016.json is already in directory raw_data/.
# File 2019030055.json is already in directory raw_data/.
# File 2019030121.json is already in directory raw_data/.
# File 2019030171.json is already in directory raw_data/.
# File 2019030151.json is already in directory raw_data/.
# File 2019030141.json is already in directory raw_data/.
# File 2019030131.json is already in directory raw_data/.
# File 2019030161.json is already in directory raw_data/.
# File 2019030111.json is already in directory raw_data/.
# File 2019030181.json is already in directory raw_data/.
# File 2019030122.json is already in directory raw_data/.
# File 2019030152.json is already in directory raw_data/.
# File 2019030142.json is already in directory raw_data/.
# File 2019030172.json is already in directory raw_data/.
# File 2019030162.json is already in directory raw_data/.
# File 2019030112.json is already in directory raw_data/.
# File 2019030182.json is already in directory raw_data/.
# File 2019030132.json is already in directory raw_data/.
# File 2019030173.json is already in directory raw_data/.
# File 2019030143.json is already in directory raw_data/.
# File 2019030163.json is already in directory raw_data/.
# File 2019030123.json is already in directory raw_data/.
# File 2019030153.json is already in directory raw_data/.
# File 2019030133.json is already in directory raw_data/.
# File 2019030174.json is already in directory raw_data/.
# File 2019030154.json is already in directory raw_data/.
# File 2019030113.json is already in directory raw_data/.
# File 2019030183.json is already in directory raw_data/.
# File 2019030124.json is already in directory raw_data/.
# File 2019030164.json is already in directory raw_data/.
# File 2019030144.json is already in directory raw_data/.
# File 2019030184.json is already in directory raw_data/.
# File 2019030114.json is already in directory raw_data/.
# File 2019030175.json is already in directory raw_data/.
# File 2019030134.json is already in directory raw_data/.
# File 2019030155.json is already in directory raw_data/.
# File 2019030125.json is already in directory raw_data/.
# File 2019030145.json is already in directory raw_data/.
# File 2019030165.json is already in directory raw_data/.
# File 2019030115.json is already in directory raw_data/.
# File 2019030185.json is already in directory raw_data/.
# File 2019030135.json is already in directory raw_data/.
# File 2019030176.json is already in directory raw_data/.
# File 2019030116.json is already in directory raw_data/.
# File 2019030186.json is already in directory raw_data/.
# File 2019030241.json is already in directory raw_data/.
# File 2019030221.json is already in directory raw_data/.
# File 2019030231.json is already in directory raw_data/.
# File 2019030211.json is already in directory raw_data/.
# File 2019030242.json is already in directory raw_data/.
# File 2019030222.json is already in directory raw_data/.
# File 2019030232.json is already in directory raw_data/.
# File 2019030212.json is already in directory raw_data/.
# File 2019030223.json is already in directory raw_data/.
# File 2019030243.json is already in directory raw_data/.
# File 2019030224.json is already in directory raw_data/.
# File 2019030213.json is already in directory raw_data/.
# File 2019030233.json is already in directory raw_data/.
# File 2019030244.json is already in directory raw_data/.
# File 2019030214.json is already in directory raw_data/.
# File 2019030234.json is already in directory raw_data/.
# File 2019030225.json is already in directory raw_data/.
# File 2019030245.json is already in directory raw_data/.
# File 2019030215.json is already in directory raw_data/.
# File 2019030235.json is already in directory raw_data/.
# File 2019030246.json is already in directory raw_data/.
# File 2019030216.json is already in directory raw_data/.
# File 2019030236.json is already in directory raw_data/.
# File 2019030247.json is already in directory raw_data/.
# File 2019030237.json is already in directory raw_data/.
# File 2019030217.json is already in directory raw_data/.
# File 2019030321.json is already in directory raw_data/.
# File 2019030311.json is already in directory raw_data/.
# File 2019030322.json is already in directory raw_data/.
# File 2019030312.json is already in directory raw_data/.
# File 2019030323.json is already in directory raw_data/.
# File 2019030313.json is already in directory raw_data/.
# File 2019030324.json is already in directory raw_data/.
# File 2019030314.json is already in directory raw_data/.
# File 2019030325.json is already in directory raw_data/.
# File 2019030315.json is already in directory raw_data/.
# File 2019030316.json is already in directory raw_data/.
# File 2019030411.json is already in directory raw_data/.
# File 2019030412.json is already in directory raw_data/.
# File 2019030413.json is already in directory raw_data/.
# File 2019030414.json is already in directory raw_data/.
# File 2019030415.json is already in directory raw_data/.
# File 2019030416.json is already in directory raw_data/.
# Downloading complete

# %%
# Tidy the data to an initial file
TidyData.append_header(TidyData.tidy_file)
TidyData.cleanData(TidyData.data_dir)

# %%
# Read the tidied file into a dataframe
df = pd.read_csv('tidy2.csv')

# %%
df
# Out:
#             gameId    season             teamHome            teamAway  \
# 0       2019030013  20192020         Dallas Stars  Colorado Avalanche
# 1       2019030013  20192020         Dallas Stars  Colorado Avalanche
# 2       2019030013  20192020         Dallas Stars  Colorado Avalanche
# 3       2019030013  20192020         Dallas Stars  Colorado Avalanche
# 4       2019030013  20192020         Dallas Stars  Colorado Avalanche
# ...            ...       ...                  ...                 ...
# 467091  2015020035  20152016  Philadelphia Flyers    Florida Panthers
# 467092  2015020035  20152016  Philadelphia Flyers    Florida Panthers
# 467093  2015020035  20152016  Philadelphia Flyers    Florida Panthers
# 467094  2015020035  20152016  Philadelphia Flyers    Florida Panthers
# 467095  2015020035  20152016  Philadelphia Flyers    Florida Panthers
#
#         eventType            eventTeam  period periodTime eventSide  \
# 0               0   Colorado Avalanche       1      00:28      left
# 1               0   Colorado Avalanche       1      00:37      left
# 2               0         Dallas Stars       1      02:29     right
# 3               0   Colorado Avalanche       1      02:44      left
# 4               0         Dallas Stars       1      03:10     right
# ...           ...                  ...     ...        ...       ...
# 467091          0  Philadelphia Flyers       3      15:31     right
# 467092          0  Philadelphia Flyers       3      15:35     right
# 467093          0  Philadelphia Flyers       3      18:12     right
# 467094          0     Florida Panthers       3      18:59      left
# 467095          0     Florida Panthers       3      19:48      left
#
#         coordinateX  coordinateY        shooterName       goalieName  \
# 0             -73.0         10.0   Nathan MacKinnon   Anton Khudobin
# 1             -54.0         34.0  Valeri Nichushkin   Anton Khudobin
# 2              62.0        -28.0    Jason Dickinson   Pavel Francouz
# 3             -74.0         12.0       Matt Calvert   Anton Khudobin
# 4             -84.0         34.0     Jamie Oleksiak   Pavel Francouz
# ...             ...          ...                ...              ...
# 467091        -52.0        -18.0         Ryan White   Roberto Luongo
# 467092        -33.0          0.0  Michael Del Zotto   Roberto Luongo
# 467093        -52.0         17.0      Michael Raffl   Roberto Luongo
# 467094         79.0         15.0       Jaromir Jagr  Michal Neuvirth
# 467095         65.0        -30.0      Brandon Pirri  Michal Neuvirth
#
#           shotType emptyNet strength
# 0         Backhand      NaN      NaN
# 1        Snap Shot      NaN      NaN
# 2       Wrist Shot      NaN      NaN
# 3        Snap Shot      NaN      NaN
# 4        Snap Shot      NaN      NaN
# ...            ...      ...      ...
# 467091   Snap Shot      NaN      NaN
# 467092   Slap Shot      NaN      NaN
# 467093  Wrist Shot      NaN      NaN
# 467094    Backhand      NaN      NaN
# 467095   Snap Shot      NaN      NaN
#
# [467096 rows x 16 columns]

# %%
# Clean the file of NA in coordinateX or coordinateY
df = df.dropna(axis=0, subset=['eventSide','coordinateX','coordinateY'])

# %%
sns.displot(df,x='coordinateX',y='coordinateY')

# %%
sns.displot(df[df['eventSide'] == 'left'],x='coordinateX',y='coordinateY')

# %%
sns.displot(df[df['eventSide'] == 'right'],x='coordinateX',y='coordinateY')

# %%
def get_distance(eventSide,x,y):
    """
    Calculates the euclidean distance from the event coordinates (x,y) to the goal, 
    based on what side of the rink (Eventside) the event is.
    Returns the euclidean distance rounded to 4 decimal places.
    """
    event_pos = np.array([x,y])
    
    # Set the goal position based on the event side (the eventSide marks the team making the shot, the goal is on other side)
    if eventSide == 'right':
        goal_pos = np.array([-89.0,0.0])
    else:
        goal_pos = np.array([89.0,0.0])
    
    # Distance is the norm of a-b
    distance = np.linalg.norm(event_pos - goal_pos)
    
    return round(distance,4)

def get_angle(eventSide,x,y):
    """
    Calculates the angle between the goal (treated as the origin) and the event coordinates (x,y).
    Returns the angle in degrees, rounded to 4 decimal places.
    """
    # Set the goal position as (0,0)
    goal_pos = np.array([0.0,0.0])
    
    # Adjust the event coordinates to account for the goal being at position (0,0)
    # x is moved left or right by 89 depending on eventSide, y is unchanged.
    if eventSide == 'right':
        event_pos = np.array([x+89.0,y])
    else:
        # if eventSide team is on the left, flip it so it's on the right and then adjust
        # This is done so the angle is correct with relation to the net
        event_pos = np.array([(-x)+89.0,y])
        
    # Angle from origin to point (x,y) is np.arctan2()
    angle = np.arctan2(event_pos[1],event_pos[0])
    
    # Convert the angle to degrees and return
    return round(np.rad2deg(angle),4)

def bool_to_digit(x):
    """
    Turns a True to 1 and anything else to 0.
    """
    if x == True:
        return 1
    else:
        return 0

# %%
# Use clunky list comprehensions to get lists that apply functions that use different dataframe columns 
distanceFromNet = [get_distance(df['eventSide'][i],df['coordinateX'][i],df['coordinateY'][i]) for i,r, in df.iterrows()]
angleFromNet = [get_angle(df['eventSide'][i],df['coordinateX'][i],df['coordinateY'][i]) for i,r, in df.iterrows()] 
isGoal = df['eventType']
emptyNet = [bool_to_digit(df['emptyNet'][i]) for i,r in df.iterrows()]

# Save the lists into a new dataframe
data = pd.DataFrame({'gameID': df['gameId'].astype(str),
                    'distanceFromNet': distanceFromNet ,
                     'angleFromNet': angleFromNet,
                     'isGoal': isGoal,
                     'emptyNet': emptyNet
                    })

# %%
data['emptyNet'].isna().any()
# Out:
# False

# %%
# Now that data are treated the same, divide into train,test datasets
train_data = data[(data['gameID'].str[:4] == '2015') | (data['gameID'].str[:4] == '2016') | (data['gameID'].str[:4] == '2017') | (data['gameID'].str[:4] == '2018')]
test_data = data[data['gameID'].str[:4] == '2019']

# %%
# Export train_data and test_data as csv
train_data.to_csv('fe_train_data.csv')
test_data.to_csv('fe_test_data.csv')

# %%
train_data
# Out:
#             gameID  distanceFromNet  angleFromNet  isGoal  emptyNet
# 67      2015020364          43.8292       27.1497       0         0
# 68      2015020364          13.4164       26.5651       0         0
# 69      2015020364          12.3693      -75.9638       0         0
# 70      2015020364           9.8995       45.0000       0         0
# 71      2015020364          42.2019      -13.7070       0         0
# ...            ...              ...           ...     ...       ...
# 467091  2015020035          41.1461      -25.9423       0         0
# 467092  2015020035          56.0000        0.0000       0         0
# 467093  2015020035          40.7185       24.6769       0         0
# 467094  2015020035          18.0278       56.3099       0         0
# 467095  2015020035          38.4187      -51.3402       0         0
#
# [326669 rows x 5 columns]

# %%
train_data['gameID'].str[:4].unique()
# Out:
# array(['2015', '2018', '2017', '2016'], dtype=object)

# %%
test_data
# Out:
#             gameID  distanceFromNet  angleFromNet  isGoal  emptyNet
# 0       2019030013         162.3083        3.5323       0         0
# 1       2019030013         146.9864       13.3744       0         0
# 2       2019030013         153.5741      -10.5051       0         0
# 3       2019030013         163.4411        4.2105       0         0
# 4       2019030013          34.3657       81.6341       0         0
# ...            ...              ...           ...     ...       ...
# 466774  2019020342          51.5461      -18.0834       0         0
# 466775  2019020342          24.7588      -46.6366       0         0
# 466776  2019020342          12.2066      -55.0080       0         0
# 466777  2019020342          17.4642      -13.2405       1         1
# 466778  2019020342           5.0000       90.0000       0         0
#
# [73528 rows x 5 columns]

# %%
test_data['gameID'].str[:4].unique()
# Out:
# array(['2019'], dtype=object)

# %%
# A histogram of shot counts (goals and no-goals separated), binned by distance
# A histogram of shot counts (goals and no-goals separated), binned by angle
# A 2D histogram where one axis is the distance and the other is the angle. You do not need to separate goals and no-goals.
# Hint: check out jointplots.

# %%
sns.histplot(data=train_data[train_data['isGoal'] ==0], x='distanceFromNet', color = 'grey', label = 'shots').set(xlabel='distance from net (ft)', ylabel='count')
sns.histplot(data=train_data[train_data['isGoal'] ==1], x='distanceFromNet', color = 'black', label = 'goals')
plt.legend()
plt.tight_layout()
# plt.savefig('2-1a_dist_from_net.png')

# %%
sns.histplot(data=train_data[train_data['isGoal'] ==0], x='angleFromNet', color = 'grey', label = 'shots').set(xlabel='angle from net (degrees)', ylabel='count')
sns.histplot(data=train_data[train_data['isGoal'] ==1], x='angleFromNet', color = 'black', label = 'goals')
plt.legend()
plt.tight_layout()
# plt.savefig('2-1b_angle_from_net.png')

# %%
sns.displot(train_data,x='distanceFromNet',y='angleFromNet', color = 'grey').set(xlabel='distance from net (ft)', ylabel='angle from net (degrees)')
plt.tight_layout()
# plt.savefig('2-1c_2D_hist.png')

# %%
# sns.jointplot(train_data,x='distanceFromNet',y='angleFromNet').set(xlabel='distance (ft)', ylabel='angle (degrees)')

# %%
#Now, create two more figures relating the goal rate, 
# i.e. #goals / (#no_goals + #goals), to the distance, and 
# goal rate to the angle of the shot. Include these figures 
# in your blogpost and briefly discuss your observations. 

bin_num = 200

goal_hist, goal_bins = np.histogram(train_data[train_data['isGoal'] == 1]['distanceFromNet'], bins = bin_num, range = (0,200))
all_hist, all_bins = np.histogram(train_data['distanceFromNet'], bins = bin_num, range = (0,200))

goal_rate_hist = np.nan_to_num(goal_hist/all_hist)

plt.hist(goal_bins[:-1], goal_bins, weights=goal_rate_hist, color = 'grey')
plt.xlabel('distance from net (ft)')
plt.ylabel('goal rate (goals / all shots)')
plt.tight_layout()
# plt.savefig('2-2a_goal_rate_dist.png')
# Out:
# /var/folders/vx/1wy54f8x20s07hcdxdylwr980000gn/T/ipykernel_8544/1937490195.py:11: RuntimeWarning: invalid value encountered in divide
#   goal_rate_hist = np.nan_to_num(goal_hist/all_hist)

# %%
bin_num = 180

goal_hist, goal_bins = np.histogram(train_data[train_data['isGoal'] == 1]['angleFromNet'], bins = bin_num, range = (-180.0,180.0))
all_hist, all_bins = np.histogram(train_data['angleFromNet'], bins = bin_num, range = (-180.0,180.0))

goal_rate_hist = np.nan_to_num(goal_hist/all_hist)

plt.hist(goal_bins[:-1], goal_bins, weights=goal_rate_hist, color = 'grey')
plt.xlabel('angle from net (ft)')
plt.ylabel('goal rate (goals / all shots)')
plt.tight_layout()
# plt.savefig('2-2b_goal_rate_angle.png')
# Out:
# /var/folders/vx/1wy54f8x20s07hcdxdylwr980000gn/T/ipykernel_8544/4041362597.py:6: RuntimeWarning: invalid value encountered in divide
#   goal_rate_hist = np.nan_to_num(goal_hist/all_hist)

# %%
# Finally, let’s do some quick checks to see if our data makes sense. 
# Unfortunately we don’t have time to do automated anomaly detection, 
# but we can use our “domain knowledge” for some quick sanity checks! 
# The domain knowledge is that “it is incredibly rare to score a non-empty 
# net goal on the opposing team from within your defensive zone”. Knowing 
# this, create another histogram, this time of goals only, binned by distance, 
# and separate empty net and non-empty net events. Include this figure in your 
# blogpost and discuss your observations. Can you find any events that have 
# incorrect features (e.g. wrong x/y coordinates)? If yes, prove that one 
# event has incorrect features.

sns.histplot(data = train_data[train_data['isGoal'] == 1], x='distanceFromNet', hue = 'emptyNet').set(xlabel='distance from net (ft)', ylabel='count')
plt.yscale('log')
plt.tight_layout()
# plt.savefig('2-3a_goals_emptyNet.png')

# %%
#Statement: “it is incredibly rare to score a non-empty net goal on the opposing team from within your defensive zone”
# define: defensive zone is 60 ft from the closest goal (team's goal) or 75 ft from the boards
unlikely = train_data[(train_data['distanceFromNet'] > 125) & (train_data['emptyNet'] == 0) & (train_data['isGoal'] == 1)]
unlikely.tail(20)
# Out:
#             gameID  distanceFromNet  angleFromNet  isGoal  emptyNet
# 462711  2017020269         163.0276        1.0544       1         0
# 462714  2017020269         166.0753        1.7253       1         0
# 462716  2017020269         165.0273        1.0416       1         0
# 463169  2017020639         160.0000        0.0000       1         0
# 463287  2015021223         144.1839       -9.9850       1         0
# 463298  2015021223         157.9905        9.1046       1         0
# 463300  2015021223         159.7060       -5.3893       1         0
# 463309  2015021223         177.0028       -0.3237       1         0
# 463313  2015021223         169.0266        1.0170       1         0
# 463316  2015021223         161.0031       -0.3559       1         0
# 463318  2015021223         167.0030       -0.3431       1         0
# 463325  2015021223         161.3103       -3.5542       1         0
# 463337  2015021223         173.0260       -0.9935       1         0
# 463503  2016020368         170.0265        1.0110       1         0
# 463505  2016020368         167.0000        0.0000       1         0
# 464352  2018020886         168.0476        1.3639       1         0
# 466814  2015020936         158.0000        0.0000       1         0
# 466825  2015020936         146.8741        6.2540       1         0
# 466828  2015020936         177.0254        0.9710       1         0
# 466837  2015020936         148.8624        6.1702       1         0

# %%
# go back to original dataframe and look up the event associated with the row
df.loc[464352]
# Out:
# gameId                2018020886
# season                  20182019
# teamHome       Los Angeles Kings
# teamAway       Vancouver Canucks
# eventType                      1
# eventTeam      Los Angeles Kings
# period                         5
# periodTime                 00:00
# eventSide               shootout
# coordinateX                -79.0
# coordinateY                  4.0
# shooterName       Ilya Kovalchuk
# goalieName       Jacob Markstrom
# shotType              Wrist Shot
# emptyNet                     NaN
# strength                    EVEN
# Name: 464352, dtype: object
