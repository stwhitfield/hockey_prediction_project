# %% [markdown]
# Changelog <br>
# 2022-10-11 Anuj <br>
# >    Initial writing of download_json and load_play_by_play functions <br>
#
# 2022-10-11 Shawn <br>
#
# > Added 2020-2021 season to allseasons download list. <br>
# > Added a filter to only download games for regular reason and playoffs <br>
# > Changed filename to save as "2016020001" since all necessary information is contained in game id <br>
#
#
# 2022-10-13 Luis
# >  Finished the actual data acquisition requirements of the project
#
# 2022-10-16 Shawn
# > Added a filter that checks if the file (as "game_id.json") is present in the target directory and only downloads the file if it isn't.

# %%
import requests
import json
import os

# %% [markdown]
# ## Get games data

# %%
#Function to download files
def download_json(allseasons, path):
    #Traverse through all seasons
    for season in allseasons:
        season = "https://statsapi.web.nhl.com/api/v1/schedule?season="+str(season)
        season_response = requests.get(season)
        season_json = json.loads(season_response.content)

        for item in season_json["dates"]:
                games_id = map(lambda game: game["gamePk"], item["games"])

                for game_id in games_id:
                    # If the file has already been downloaded:
                    if f"{game_id}.json" in os.listdir(path):
                        #Print a message that the file is already there.
                        print(f"File {game_id}.json is already in directory {path}.")
                    else:
                        # Filter to be able to only select regular season (02) or playoff (03) games
                        game_type = str(game_id)[4:6]
                        # Go through and download all games from regular season or playoffs 
                        if game_type == '02' or game_type == '03':
                            #Traverse through all games
                            url="https://statsapi.web.nhl.com/api/v1/game/"+str(game_id)+"/feed/live/"
                            response = requests.get(url)
                            game = json.loads(response.content)
                            with open(path+str(game_id)+'.json', 'w', encoding='utf-8') as f:
                                json.dump(game, f, ensure_ascii=False, indent=4)
                                f.close()

path = "raw_data/"
allseasons = ["20162017","20172018","20182019","20192020","20202021"]

download_json(allseasons, path)
# Out:
# File 2016020001.json already in dir raw_data/
# File 2016020005.json already in dir raw_data/
# File 2016020014.json already in dir raw_data/
# File 2016020017.json already in dir raw_data/
# File 2016020030.json already in dir raw_data/
# File 2016020033.json already in dir raw_data/
# File 2016020037.json already in dir raw_data/
# File 2016020049.json already in dir raw_data/
# File 2016020051.json already in dir raw_data/
# File 2016020062.json already in dir raw_data/
# File 2016020065.json already in dir raw_data/
# File 2016020077.json already in dir raw_data/
# File 2016020081.json already in dir raw_data/
# File 2016020083.json already in dir raw_data/
# File 2016020094.json already in dir raw_data/
# File 2016020098.json already in dir raw_data/
# File 2016020107.json already in dir raw_data/
# File 2016020113.json already in dir raw_data/
# File 2016020123.json already in dir raw_data/
# File 2016020132.json already in dir raw_data/
# File 2016020143.json already in dir raw_data/
# File 2016020146.json already in dir raw_data/
# File 2016020158.json already in dir raw_data/
# File 2016020161.json already in dir raw_data/
# File 2016020174.json already in dir raw_data/
# File 2016020180.json already in dir raw_data/
# File 2016020183.json already in dir raw_data/
# File 2016020193.json already in dir raw_data/
# File 2016020196.json already in dir raw_data/
# File 2016020206.json already in dir raw_data/
# File 2016020212.json already in dir raw_data/
# File 2016020223.json already in dir raw_data/
# File 2016020229.json already in dir raw_data/
# File 2016020230.json already in dir raw_data/
# File 2016020243.json already in dir raw_data/
# File 2016020245.json already in dir raw_data/
# File 2016020255.json already in dir raw_data/
# File 2016020260.json already in dir raw_data/
# File 2016020271.json already in dir raw_data/
# File 2016020276.json already in dir raw_data/
# File 2016020283.json already in dir raw_data/
# File 2016020288.json already in dir raw_data/
# File 2016020300.json already in dir raw_data/
# File 2016020302.json already in dir raw_data/
# File 2016020313.json already in dir raw_data/
# File 2016020322.json already in dir raw_data/
# File 2016020328.json already in dir raw_data/
# File 2016020330.json already in dir raw_data/
# File 2016020342.json already in dir raw_data/
# File 2016020345.json already in dir raw_data/
# File 2016020357.json already in dir raw_data/
# File 2016020359.json already in dir raw_data/
# File 2016020377.json already in dir raw_data/
# File 2016020378.json already in dir raw_data/
# File 2016020382.json already in dir raw_data/
# File 2016020391.json already in dir raw_data/
# File 2016020395.json already in dir raw_data/
# File 2016020405.json already in dir raw_data/
# File 2016020411.json already in dir raw_data/
# File 2016020421.json already in dir raw_data/
# File 2016020429.json already in dir raw_data/
# File 2016020431.json already in dir raw_data/
# File 2016020441.json already in dir raw_data/
# File 2016020445.json already in dir raw_data/
# File 2016020453.json already in dir raw_data/
# File 2016020460.json already in dir raw_data/
# File 2016020470.json already in dir raw_data/
# File 2016020476.json already in dir raw_data/
# File 2016020481.json already in dir raw_data/
# File 2016020493.json already in dir raw_data/
# File 2016020495.json already in dir raw_data/
# File 2016020505.json already in dir raw_data/
# File 2016020517.json already in dir raw_data/
# File 2016020527.json already in dir raw_data/
# File 2016020532.json already in dir raw_data/
# File 2016020544.json already in dir raw_data/
# File 2016020548.json already in dir raw_data/
# File 2016020559.json already in dir raw_data/
# File 2016020562.json already in dir raw_data/
# File 2016020565.json already in dir raw_data/
# File 2016020572.json already in dir raw_data/
# File 2016020578.json already in dir raw_data/
# File 2016020585.json already in dir raw_data/
# File 2016020591.json already in dir raw_data/
# File 2016020603.json already in dir raw_data/
# File 2016020609.json already in dir raw_data/
# File 2016020613.json already in dir raw_data/
# File 2016020620.json already in dir raw_data/
# File 2016020624.json already in dir raw_data/
# File 2016020633.json already in dir raw_data/
# File 2016020640.json already in dir raw_data/
# File 2016020652.json already in dir raw_data/
# File 2016020656.json already in dir raw_data/
# File 2016020663.json already in dir raw_data/
# File 2016020672.json already in dir raw_data/
# File 2016020677.json already in dir raw_data/
# File 2016020685.json already in dir raw_data/
# File 2016020691.json already in dir raw_data/
# File 2016020703.json already in dir raw_data/
# File 2016020708.json already in dir raw_data/
# File 2016020714.json already in dir raw_data/
# File 2016020724.json already in dir raw_data/
# File 2016020728.json already in dir raw_data/
# File 2016020741.json already in dir raw_data/
# File 2016020755.json already in dir raw_data/
# File 2016020759.json already in dir raw_data/
# File 2016020766.json already in dir raw_data/
# File 2016020771.json already in dir raw_data/
# File 2016020784.json already in dir raw_data/
# File 2016020787.json already in dir raw_data/
# File 2016020790.json already in dir raw_data/
# File 2016020801.json already in dir raw_data/
# File 2016020802.json already in dir raw_data/
# File 2016020813.json already in dir raw_data/
# File 2016020815.json already in dir raw_data/
# File 2016020828.json already in dir raw_data/
# File 2016020834.json already in dir raw_data/
# File 2016020836.json already in dir raw_data/
# File 2016020843.json already in dir raw_data/
# File 2016020848.json already in dir raw_data/
# File 2016020855.json already in dir raw_data/
# File 2016020858.json already in dir raw_data/
# File 2016020869.json already in dir raw_data/
# File 2016020880.json already in dir raw_data/
# File 2016020882.json already in dir raw_data/
# File 2016020891.json already in dir raw_data/
# File 2016020894.json already in dir raw_data/
# File 2016020900.json already in dir raw_data/
# File 2016020904.json already in dir raw_data/
# File 2016020912.json already in dir raw_data/
# File 2016020919.json already in dir raw_data/
# File 2016020922.json already in dir raw_data/
# File 2016020934.json already in dir raw_data/
# File 2016020936.json already in dir raw_data/
# File 2016020946.json already in dir raw_data/
# File 2016020952.json already in dir raw_data/
# File 2016020962.json already in dir raw_data/
# File 2016020969.json already in dir raw_data/
# File 2016020974.json already in dir raw_data/
# File 2016020982.json already in dir raw_data/
# File 2016020985.json already in dir raw_data/
# File 2016020995.json already in dir raw_data/
# File 2016021000.json already in dir raw_data/
# File 2016021012.json already in dir raw_data/
# File 2016021017.json already in dir raw_data/
# File 2016021025.json already in dir raw_data/
# File 2016021033.json already in dir raw_data/
# File 2016021037.json already in dir raw_data/
# File 2016021049.json already in dir raw_data/
# File 2016021053.json already in dir raw_data/
# File 2016021063.json already in dir raw_data/
# File 2016021070.json already in dir raw_data/
# File 2016021075.json already in dir raw_data/
# File 2016021086.json already in dir raw_data/
# File 2016021089.json already in dir raw_data/
# File 2016021101.json already in dir raw_data/
# File 2016021105.json already in dir raw_data/
# File 2016021119.json already in dir raw_data/
# File 2016020477.json already in dir raw_data/
# File 2016021024.json already in dir raw_data/
# File 2016021137.json already in dir raw_data/
# File 2016021142.json already in dir raw_data/
# File 2016021150.json already in dir raw_data/
# File 2016021157.json already in dir raw_data/
# File 2016021165.json already in dir raw_data/
# File 2016021176.json already in dir raw_data/
# File 2016021179.json already in dir raw_data/
# File 2016021192.json already in dir raw_data/
# File 2016021194.json already in dir raw_data/
# File 2016021206.json already in dir raw_data/
# File 2016021207.json already in dir raw_data/
# File 2016021221.json already in dir raw_data/
# File 2016030111.json already in dir raw_data/
# File 2016030131.json already in dir raw_data/
# File 2016030112.json already in dir raw_data/
# File 2016030122.json already in dir raw_data/
# File 2016030163.json already in dir raw_data/
# File 2016030123.json already in dir raw_data/
# File 2016030114.json already in dir raw_data/
# File 2016030134.json already in dir raw_data/
# File 2016030115.json already in dir raw_data/
# File 2016030135.json already in dir raw_data/
# File 2016030165.json already in dir raw_data/
# File 2016030126.json already in dir raw_data/
# File 2016030231.json already in dir raw_data/
# File 2016030211.json already in dir raw_data/
# File 2016030232.json already in dir raw_data/
# File 2016030212.json already in dir raw_data/
# File 2016030233.json already in dir raw_data/
# File 2016030223.json already in dir raw_data/
# File 2016030213.json already in dir raw_data/
# File 2016030224.json already in dir raw_data/
# File 2016030214.json already in dir raw_data/
# File 2016030235.json already in dir raw_data/
# File 2016030215.json already in dir raw_data/
# File 2016030236.json already in dir raw_data/
# File 2016030226.json already in dir raw_data/
# File 2016030216.json already in dir raw_data/
# File 2016030227.json already in dir raw_data/
# File 2016030321.json already in dir raw_data/
# File 2016030311.json already in dir raw_data/
# File 2016030322.json already in dir raw_data/
# File 2016030312.json already in dir raw_data/
# File 2016030323.json already in dir raw_data/
# File 2016030313.json already in dir raw_data/
# File 2016030324.json already in dir raw_data/
# File 2016030314.json already in dir raw_data/
# File 2016030325.json already in dir raw_data/
# File 2016030315.json already in dir raw_data/
# File 2016030326.json already in dir raw_data/
# File 2016030316.json already in dir raw_data/
# File 2016030317.json already in dir raw_data/
# File 2016030411.json already in dir raw_data/
# File 2016030412.json already in dir raw_data/
# File 2016030413.json already in dir raw_data/
# File 2016030414.json already in dir raw_data/
# File 2016030415.json already in dir raw_data/
# File 2016030416.json already in dir raw_data/
# File 2017020001.json already in dir raw_data/
# File 2017020005.json already in dir raw_data/
# File 2017020013.json already in dir raw_data/
# File 2017020019.json already in dir raw_data/
# File 2017020031.json already in dir raw_data/
# File 2017020032.json already in dir raw_data/
# File 2017020039.json already in dir raw_data/
# File 2017020046.json already in dir raw_data/
# File 2017020051.json already in dir raw_data/
# File 2017020058.json already in dir raw_data/
# File 2017020063.json already in dir raw_data/
# File 2017020077.json already in dir raw_data/
# File 2017020080.json already in dir raw_data/
# File 2017020082.json already in dir raw_data/
# File 2017020092.json already in dir raw_data/
# File 2017020095.json already in dir raw_data/
# File 2017020104.json already in dir raw_data/
# File 2017020110.json already in dir raw_data/
# File 2017020122.json already in dir raw_data/
# File 2017020123.json already in dir raw_data/
# File 2017020126.json already in dir raw_data/
# File 2017020136.json already in dir raw_data/
# File 2017020138.json already in dir raw_data/
# File 2017020149.json already in dir raw_data/
# File 2017020155.json already in dir raw_data/
# File 2017020167.json already in dir raw_data/
# File 2017020170.json already in dir raw_data/
# File 2017020178.json already in dir raw_data/
# File 2017020181.json already in dir raw_data/
# File 2017020186.json already in dir raw_data/
# File 2017020198.json already in dir raw_data/
# File 2017020200.json already in dir raw_data/
# File 2017020213.json already in dir raw_data/
# File 2017020217.json already in dir raw_data/
# File 2017020223.json already in dir raw_data/
# File 2017020232.json already in dir raw_data/
# File 2017020235.json already in dir raw_data/
# File 2017020247.json already in dir raw_data/
# File 2017020249.json already in dir raw_data/
# File 2017020261.json already in dir raw_data/
# File 2017020265.json already in dir raw_data/
# File 2017020267.json already in dir raw_data/
# File 2017020275.json already in dir raw_data/
# File 2017020278.json already in dir raw_data/
# File 2017020290.json already in dir raw_data/
# File 2017020292.json already in dir raw_data/
# File 2017020305.json already in dir raw_data/
# File 2017020310.json already in dir raw_data/
# File 2017020316.json already in dir raw_data/
# File 2017020319.json already in dir raw_data/
# File 2017020334.json already in dir raw_data/
# File 2017020348.json already in dir raw_data/
# File 2017020359.json already in dir raw_data/
# File 2017020362.json already in dir raw_data/
# File 2017020367.json already in dir raw_data/
# File 2017020377.json already in dir raw_data/
# File 2017020381.json already in dir raw_data/
# File 2017020388.json already in dir raw_data/
# File 2017020396.json already in dir raw_data/
# File 2017020408.json already in dir raw_data/
# File 2017020412.json already in dir raw_data/
# File 2017020417.json already in dir raw_data/
# File 2017020426.json already in dir raw_data/
# File 2017020430.json already in dir raw_data/
# File 2017020439.json already in dir raw_data/
# File 2017020446.json already in dir raw_data/
# File 2017020456.json already in dir raw_data/
# File 2017020460.json already in dir raw_data/
# File 2017020466.json already in dir raw_data/
# File 2017020475.json already in dir raw_data/
# File 2017020479.json already in dir raw_data/
# File 2017020491.json already in dir raw_data/
# File 2017020496.json already in dir raw_data/
# File 2017020507.json already in dir raw_data/
# File 2017020511.json already in dir raw_data/
# File 2017020516.json already in dir raw_data/
# File 2017020526.json already in dir raw_data/
# File 2017020529.json already in dir raw_data/
# File 2017020539.json already in dir raw_data/
# File 2017020543.json already in dir raw_data/
# File 2017020558.json already in dir raw_data/
# File 2017020569.json already in dir raw_data/
# File 2017020576.json already in dir raw_data/
# File 2017020587.json already in dir raw_data/
# File 2017020593.json already in dir raw_data/
# File 2017020601.json already in dir raw_data/
# File 2017020602.json already in dir raw_data/
# File 2017020614.json already in dir raw_data/
# File 2017020617.json already in dir raw_data/
# File 2017020628.json already in dir raw_data/
# File 2017020633.json already in dir raw_data/
# File 2017020642.json already in dir raw_data/
# File 2017020652.json already in dir raw_data/
# File 2017020653.json already in dir raw_data/
# File 2017020660.json already in dir raw_data/
# File 2017020662.json already in dir raw_data/
# File 2017020665.json already in dir raw_data/
# File 2017020670.json already in dir raw_data/
# File 2017020681.json already in dir raw_data/
# File 2017020683.json already in dir raw_data/
# File 2017020687.json already in dir raw_data/
# File 2017020693.json already in dir raw_data/
# File 2017020695.json already in dir raw_data/
# File 2017020705.json already in dir raw_data/
# File 2017020708.json already in dir raw_data/
# File 2017020721.json already in dir raw_data/
# File 2017020726.json already in dir raw_data/
# File 2017020732.json already in dir raw_data/
# File 2017020744.json already in dir raw_data/
# File 2017020746.json already in dir raw_data/
# File 2017020761.json already in dir raw_data/
# File 2017020773.json already in dir raw_data/
# File 2017020776.json already in dir raw_data/
# File 2017020788.json already in dir raw_data/
# File 2017020792.json already in dir raw_data/
# File 2017020805.json already in dir raw_data/
# File 2017020808.json already in dir raw_data/
# File 2017020812.json already in dir raw_data/
# File 2017020823.json already in dir raw_data/
# File 2017020826.json already in dir raw_data/
# File 2017020835.json already in dir raw_data/
# File 2017020843.json already in dir raw_data/
# File 2017020853.json already in dir raw_data/
# File 2017020861.json already in dir raw_data/
# File 2017020864.json already in dir raw_data/
# File 2017020876.json already in dir raw_data/
# File 2017020879.json already in dir raw_data/
# File 2017020890.json already in dir raw_data/
# File 2017020894.json already in dir raw_data/
# File 2017020905.json already in dir raw_data/
# File 2017020912.json already in dir raw_data/
# File 2017020918.json already in dir raw_data/
# File 2017020927.json already in dir raw_data/
# File 2017020930.json already in dir raw_data/
# File 2017020941.json already in dir raw_data/
# File 2017020946.json already in dir raw_data/
# File 2017020959.json already in dir raw_data/
# File 2017020964.json already in dir raw_data/
# File 2017020969.json already in dir raw_data/
# File 2017020978.json already in dir raw_data/
# File 2017020983.json already in dir raw_data/
# File 2017020991.json already in dir raw_data/
# File 2017021000.json already in dir raw_data/
# File 2017021008.json already in dir raw_data/
# File 2017021016.json already in dir raw_data/
# File 2017021020.json already in dir raw_data/
# File 2017021029.json already in dir raw_data/
# File 2017021032.json already in dir raw_data/
# File 2017021044.json already in dir raw_data/
# File 2017021048.json already in dir raw_data/
# File 2017021059.json already in dir raw_data/
# File 2017021063.json already in dir raw_data/
# File 2017021071.json already in dir raw_data/
# File 2017021078.json already in dir raw_data/
# File 2017021083.json already in dir raw_data/
# File 2017021092.json already in dir raw_data/
# File 2017021098.json already in dir raw_data/
# File 2017021108.json already in dir raw_data/
# File 2017021116.json already in dir raw_data/
# File 2017021121.json already in dir raw_data/
# File 2017021132.json already in dir raw_data/
# File 2017021136.json already in dir raw_data/
# File 2017021146.json already in dir raw_data/
# File 2017021151.json already in dir raw_data/
# File 2017021163.json already in dir raw_data/
# File 2017021168.json already in dir raw_data/
# File 2017021177.json already in dir raw_data/
# File 2017021186.json already in dir raw_data/
# File 2017021190.json already in dir raw_data/
# File 2017021200.json already in dir raw_data/
# File 2017021206.json already in dir raw_data/
# File 2017021218.json already in dir raw_data/
# File 2017021223.json already in dir raw_data/
# File 2017021229.json already in dir raw_data/
# File 2017021238.json already in dir raw_data/
# File 2017021241.json already in dir raw_data/
# File 2017021253.json already in dir raw_data/
# File 2017021257.json already in dir raw_data/
# File 2017020616.json already in dir raw_data/
# File 2017030141.json already in dir raw_data/
# File 2017030111.json already in dir raw_data/
# File 2017030142.json already in dir raw_data/
# File 2017030112.json already in dir raw_data/
# File 2017030143.json already in dir raw_data/
# File 2017030123.json already in dir raw_data/
# File 2017030133.json already in dir raw_data/
# File 2017030144.json already in dir raw_data/
# File 2017030124.json already in dir raw_data/
# File 2017030145.json already in dir raw_data/
# File 2017030115.json already in dir raw_data/
# File 2017030146.json already in dir raw_data/
# File 2017030126.json already in dir raw_data/
# File 2017030127.json already in dir raw_data/
# File 2017030221.json already in dir raw_data/
# File 2017030231.json already in dir raw_data/
# File 2017030211.json already in dir raw_data/
# File 2017030222.json already in dir raw_data/
# File 2017030212.json already in dir raw_data/
# File 2017030223.json already in dir raw_data/
# File 2017030213.json already in dir raw_data/
# File 2017030224.json already in dir raw_data/
# File 2017030214.json already in dir raw_data/
# File 2017030225.json already in dir raw_data/
# File 2017030215.json already in dir raw_data/
# File 2017030226.json already in dir raw_data/
# File 2017030237.json already in dir raw_data/
# File 2017030311.json already in dir raw_data/
# File 2017030321.json already in dir raw_data/
# File 2017030312.json already in dir raw_data/
# File 2017030322.json already in dir raw_data/
# File 2017030313.json already in dir raw_data/
# File 2017030323.json already in dir raw_data/
# File 2017030314.json already in dir raw_data/
# File 2017030324.json already in dir raw_data/
# File 2017030315.json already in dir raw_data/
# File 2017030325.json already in dir raw_data/
# File 2017030316.json already in dir raw_data/
# File 2017030317.json already in dir raw_data/
# File 2017030411.json already in dir raw_data/
# File 2017030412.json already in dir raw_data/
# File 2017030413.json already in dir raw_data/
# File 2017030414.json already in dir raw_data/
# File 2017030415.json already in dir raw_data/
# File 2018020005.json already in dir raw_data/
# File 2018020015.json already in dir raw_data/
# File 2018020020.json already in dir raw_data/
# File 2018020029.json already in dir raw_data/
# File 2018020032.json already in dir raw_data/
# File 2018020036.json already in dir raw_data/
# File 2018020042.json already in dir raw_data/
# File 2018020045.json already in dir raw_data/
# File 2018020057.json already in dir raw_data/
# File 2018020071.json already in dir raw_data/
# File 2018020074.json already in dir raw_data/
# File 2018020078.json already in dir raw_data/
# File 2018020086.json already in dir raw_data/
# File 2018020090.json already in dir raw_data/
# File 2018020099.json already in dir raw_data/
# File 2018020102.json already in dir raw_data/
# File 2018020115.json already in dir raw_data/
# File 2018020118.json already in dir raw_data/
# File 2018020122.json already in dir raw_data/
# File 2018020130.json already in dir raw_data/
# File 2018020134.json already in dir raw_data/
# File 2018020144.json already in dir raw_data/
# File 2018020148.json already in dir raw_data/
# File 2018020159.json already in dir raw_data/
# File 2018020165.json already in dir raw_data/
# File 2018020167.json already in dir raw_data/
# File 2018020178.json already in dir raw_data/
# File 2018020180.json already in dir raw_data/
# File 2018020192.json already in dir raw_data/
# File 2018020195.json already in dir raw_data/
# File 2018020207.json already in dir raw_data/
# File 2018020210.json already in dir raw_data/
# File 2018020215.json already in dir raw_data/
# File 2018020224.json already in dir raw_data/
# File 2018020227.json already in dir raw_data/
# File 2018020236.json already in dir raw_data/
# File 2018020242.json already in dir raw_data/
# File 2018020253.json already in dir raw_data/
# File 2018020260.json already in dir raw_data/
# File 2018020265.json already in dir raw_data/
# File 2018020273.json already in dir raw_data/
# File 2018020277.json already in dir raw_data/
# File 2018020286.json already in dir raw_data/
# File 2018020292.json already in dir raw_data/
# File 2018020303.json already in dir raw_data/
# File 2018020308.json already in dir raw_data/
# File 2018020317.json already in dir raw_data/
# File 2018020319.json already in dir raw_data/
# File 2018020332.json already in dir raw_data/
# File 2018020347.json already in dir raw_data/
# File 2018020358.json already in dir raw_data/
# File 2018020362.json already in dir raw_data/
# File 2018020367.json already in dir raw_data/
# File 2018020377.json already in dir raw_data/
# File 2018020382.json already in dir raw_data/
# File 2018020390.json already in dir raw_data/
# File 2018020395.json already in dir raw_data/
# File 2018020407.json already in dir raw_data/
# File 2018020413.json already in dir raw_data/
# File 2018020417.json already in dir raw_data/
# File 2018020426.json already in dir raw_data/
# File 2018020429.json already in dir raw_data/
# File 2018020440.json already in dir raw_data/
# File 2018020444.json already in dir raw_data/
# File 2018020454.json already in dir raw_data/
# File 2018020461.json already in dir raw_data/
# File 2018020465.json already in dir raw_data/
# File 2018020475.json already in dir raw_data/
# File 2018020479.json already in dir raw_data/
# File 2018020487.json already in dir raw_data/
# File 2018020495.json already in dir raw_data/
# File 2018020505.json already in dir raw_data/
# File 2018020512.json already in dir raw_data/
# File 2018020517.json already in dir raw_data/
# File 2018020528.json already in dir raw_data/
# File 2018020530.json already in dir raw_data/
# File 2018020542.json already in dir raw_data/
# File 2018020545.json already in dir raw_data/
# File 2018020559.json already in dir raw_data/
# File 2018020567.json already in dir raw_data/
# File 2018020580.json already in dir raw_data/
# File 2018020583.json already in dir raw_data/
# File 2018020598.json already in dir raw_data/
# File 2018020599.json already in dir raw_data/
# File 2018020612.json already in dir raw_data/
# File 2018020615.json already in dir raw_data/
# File 2018020621.json already in dir raw_data/
# File 2018020629.json already in dir raw_data/
# File 2018020636.json already in dir raw_data/
# File 2018020647.json already in dir raw_data/
# File 2018020652.json already in dir raw_data/
# File 2018020657.json already in dir raw_data/
# File 2018020668.json already in dir raw_data/
# File 2018020671.json already in dir raw_data/
# File 2018020683.json already in dir raw_data/
# File 2018020687.json already in dir raw_data/
# File 2018020699.json already in dir raw_data/
# File 2018020706.json already in dir raw_data/
# File 2018020711.json already in dir raw_data/
# File 2018020721.json already in dir raw_data/
# File 2018020726.json already in dir raw_data/
# File 2018020733.json already in dir raw_data/
# File 2018020740.json already in dir raw_data/
# File 2018020751.json already in dir raw_data/
# File 2018020756.json already in dir raw_data/
# File 2018020760.json already in dir raw_data/
# File 2018020765.json already in dir raw_data/
# File 2018020771.json already in dir raw_data/
# File 2018020773.json already in dir raw_data/
# File 2018020776.json already in dir raw_data/
# File 2018020778.json already in dir raw_data/
# File 2018020781.json already in dir raw_data/
# File 2018020789.json already in dir raw_data/
# File 2018020802.json already in dir raw_data/
# File 2018020805.json already in dir raw_data/
# File 2018020809.json already in dir raw_data/
# File 2018020821.json already in dir raw_data/
# File 2018020823.json already in dir raw_data/
# File 2018020837.json already in dir raw_data/
# File 2018020838.json already in dir raw_data/
# File 2018020852.json already in dir raw_data/
# File 2018020860.json already in dir raw_data/
# File 2018020863.json already in dir raw_data/
# File 2018020875.json already in dir raw_data/
# File 2018020877.json already in dir raw_data/
# File 2018020888.json already in dir raw_data/
# File 2018020892.json already in dir raw_data/
# File 2018020904.json already in dir raw_data/
# File 2018020910.json already in dir raw_data/
# File 2018020916.json already in dir raw_data/
# File 2018020925.json already in dir raw_data/
# File 2018020929.json already in dir raw_data/
# File 2018020940.json already in dir raw_data/
# File 2018020945.json already in dir raw_data/
# File 2018020956.json already in dir raw_data/
# File 2018020962.json already in dir raw_data/
# File 2018020968.json already in dir raw_data/
# File 2018020979.json already in dir raw_data/
# File 2018020985.json already in dir raw_data/
# File 2018020991.json already in dir raw_data/
# File 2018020999.json already in dir raw_data/
# File 2018021009.json already in dir raw_data/
# File 2018021017.json already in dir raw_data/
# File 2018021019.json already in dir raw_data/
# File 2018021029.json already in dir raw_data/
# File 2018021033.json already in dir raw_data/
# File 2018021044.json already in dir raw_data/
# File 2018021048.json already in dir raw_data/
# File 2018021060.json already in dir raw_data/
# File 2018021065.json already in dir raw_data/
# File 2018021072.json already in dir raw_data/
# File 2018021080.json already in dir raw_data/
# File 2018021083.json already in dir raw_data/
# File 2018021093.json already in dir raw_data/
# File 2018021099.json already in dir raw_data/
# File 2018021111.json already in dir raw_data/
# File 2018021118.json already in dir raw_data/
# File 2018021123.json already in dir raw_data/
# File 2018021132.json already in dir raw_data/
# File 2018021136.json already in dir raw_data/
# File 2018021148.json already in dir raw_data/
# File 2018021150.json already in dir raw_data/
# File 2018021164.json already in dir raw_data/
# File 2018021169.json already in dir raw_data/
# File 2018021178.json already in dir raw_data/
# File 2018021185.json already in dir raw_data/
# File 2018021189.json already in dir raw_data/
# File 2018021197.json already in dir raw_data/
# File 2018021204.json already in dir raw_data/
# File 2018021215.json already in dir raw_data/
# File 2018021221.json already in dir raw_data/
# File 2018021229.json already in dir raw_data/
# File 2018021239.json already in dir raw_data/
# File 2018021242.json already in dir raw_data/
# File 2018021254.json already in dir raw_data/
# File 2018021257.json already in dir raw_data/
# File 2018030111.json already in dir raw_data/
# File 2018030121.json already in dir raw_data/
# File 2018030112.json already in dir raw_data/
# File 2018030132.json already in dir raw_data/
# File 2018030143.json already in dir raw_data/
# File 2018030123.json already in dir raw_data/
# File 2018030114.json already in dir raw_data/
# File 2018030124.json already in dir raw_data/
# File 2018030134.json already in dir raw_data/
# File 2018030125.json already in dir raw_data/
# File 2018030155.json already in dir raw_data/
# File 2018030126.json already in dir raw_data/
# File 2018030136.json already in dir raw_data/
# File 2018030127.json already in dir raw_data/
# File 2018030137.json already in dir raw_data/
# File 2018030211.json already in dir raw_data/
# File 2018030221.json already in dir raw_data/
# File 2018030232.json already in dir raw_data/
# File 2018030222.json already in dir raw_data/
# File 2018030233.json already in dir raw_data/
# File 2018030213.json already in dir raw_data/
# File 2018030223.json already in dir raw_data/
# File 2018030214.json already in dir raw_data/
# File 2018030224.json already in dir raw_data/
# File 2018030215.json already in dir raw_data/
# File 2018030236.json already in dir raw_data/
# File 2018030216.json already in dir raw_data/
# File 2018030237.json already in dir raw_data/
# File 2018030247.json already in dir raw_data/
# File 2018030311.json already in dir raw_data/
# File 2018030321.json already in dir raw_data/
# File 2018030312.json already in dir raw_data/
# File 2018030322.json already in dir raw_data/
# File 2018030313.json already in dir raw_data/
# File 2018030323.json already in dir raw_data/
# File 2018030314.json already in dir raw_data/
# File 2018030324.json already in dir raw_data/
# File 2018030325.json already in dir raw_data/
# File 2018030326.json already in dir raw_data/
# File 2018030411.json already in dir raw_data/
# File 2018030412.json already in dir raw_data/
# File 2018030413.json already in dir raw_data/
# File 2018030414.json already in dir raw_data/
# File 2018030415.json already in dir raw_data/
# File 2018030416.json already in dir raw_data/
# File 2018030417.json already in dir raw_data/
# File 2019020001.json already in dir raw_data/
# File 2019020005.json already in dir raw_data/
# File 2019020016.json already in dir raw_data/
# File 2019020018.json already in dir raw_data/
# File 2019020031.json already in dir raw_data/
# File 2019020034.json already in dir raw_data/
# File 2019020036.json already in dir raw_data/
# File 2019020044.json already in dir raw_data/
# File 2019020047.json already in dir raw_data/
# File 2019020058.json already in dir raw_data/
# File 2019020061.json already in dir raw_data/
# File 2019020075.json already in dir raw_data/
# File 2019020078.json already in dir raw_data/
# File 2019020085.json already in dir raw_data/
# File 2019020092.json already in dir raw_data/
# File 2019020098.json already in dir raw_data/
# File 2019020107.json already in dir raw_data/
# File 2019020113.json already in dir raw_data/
# File 2019020124.json already in dir raw_data/
# File 2019020129.json already in dir raw_data/
# File 2019020133.json already in dir raw_data/
# File 2019020143.json already in dir raw_data/
# File 2019020145.json already in dir raw_data/
# File 2019020155.json already in dir raw_data/
# File 2019020161.json already in dir raw_data/
# File 2019020170.json already in dir raw_data/
# File 2019020177.json already in dir raw_data/
# File 2019020179.json already in dir raw_data/
# File 2019020188.json already in dir raw_data/
# File 2019020194.json already in dir raw_data/
# File 2019020196.json already in dir raw_data/
# File 2019020204.json already in dir raw_data/
# File 2019020218.json already in dir raw_data/
# File 2019020220.json already in dir raw_data/
# File 2019020225.json already in dir raw_data/
# File 2019020235.json already in dir raw_data/
# File 2019020237.json already in dir raw_data/
# File 2019020249.json already in dir raw_data/
# File 2019020252.json already in dir raw_data/
# File 2019020263.json already in dir raw_data/
# File 2019020270.json already in dir raw_data/
# File 2019020272.json already in dir raw_data/
# File 2019020281.json already in dir raw_data/
# File 2019020286.json already in dir raw_data/
# File 2019020294.json already in dir raw_data/
# File 2019020299.json already in dir raw_data/
# File 2019020314.json already in dir raw_data/
# File 2019020316.json already in dir raw_data/
# File 2019020318.json already in dir raw_data/
# File 2019020331.json already in dir raw_data/
# File 2019020333.json already in dir raw_data/
# File 2019020346.json already in dir raw_data/
# File 2019020348.json already in dir raw_data/
# File 2019020362.json already in dir raw_data/
# File 2019020365.json already in dir raw_data/
# File 2019020374.json already in dir raw_data/
# File 2019020377.json already in dir raw_data/
# File 2019020390.json already in dir raw_data/
# File 2019020391.json already in dir raw_data/
# File 2019020403.json already in dir raw_data/
# File 2019020416.json already in dir raw_data/
# File 2019020419.json already in dir raw_data/
# File 2019020424.json already in dir raw_data/
# File 2019020434.json already in dir raw_data/
# File 2019020438.json already in dir raw_data/
# File 2019020447.json already in dir raw_data/
# File 2019020452.json already in dir raw_data/
# File 2019020463.json already in dir raw_data/
# File 2019020468.json already in dir raw_data/
# File 2019020473.json already in dir raw_data/
# File 2019020484.json already in dir raw_data/
# File 2019020487.json already in dir raw_data/
# File 2019020499.json already in dir raw_data/
# File 2019020501.json already in dir raw_data/
# File 2019020515.json already in dir raw_data/
# File 2019020519.json already in dir raw_data/
# File 2019020524.json already in dir raw_data/
# File 2019020535.json already in dir raw_data/
# File 2019020538.json already in dir raw_data/
# File 2019020548.json already in dir raw_data/
# File 2019020552.json already in dir raw_data/
# File 2019020565.json already in dir raw_data/
# File 2019020569.json already in dir raw_data/
# File 2019020582.json already in dir raw_data/
# File 2019020593.json already in dir raw_data/
# File 2019020602.json already in dir raw_data/
# File 2019020612.json already in dir raw_data/
# File 2019020613.json already in dir raw_data/
# File 2019020626.json already in dir raw_data/
# File 2019020627.json already in dir raw_data/
# File 2019020639.json already in dir raw_data/
# File 2019020641.json already in dir raw_data/
# File 2019020653.json already in dir raw_data/
# File 2019020659.json already in dir raw_data/
# File 2019020663.json already in dir raw_data/
# File 2019020675.json already in dir raw_data/
# File 2019020678.json already in dir raw_data/
# File 2019020689.json already in dir raw_data/
# File 2019020692.json already in dir raw_data/
# File 2019020703.json already in dir raw_data/
# File 2019020709.json already in dir raw_data/
# File 2019020714.json already in dir raw_data/
# File 2019020725.json already in dir raw_data/
# File 2019020727.json already in dir raw_data/
# File 2019020740.json already in dir raw_data/
# File 2019020743.json already in dir raw_data/
# File 2019020755.json already in dir raw_data/
# File 2019020759.json already in dir raw_data/
# File 2019020761.json already in dir raw_data/
# File 2019020766.json already in dir raw_data/
# File 2019020768.json already in dir raw_data/
# File 2019020774.json already in dir raw_data/
# File 2019020776.json already in dir raw_data/
# File 2019020782.json already in dir raw_data/
# File 2019020785.json already in dir raw_data/
# File 2019020792.json already in dir raw_data/
# File 2019020806.json already in dir raw_data/
# File 2019020809.json already in dir raw_data/
# File 2019020812.json already in dir raw_data/
# File 2019020825.json already in dir raw_data/
# File 2019020827.json already in dir raw_data/
# File 2019020839.json already in dir raw_data/
# File 2019020843.json already in dir raw_data/
# File 2019020855.json already in dir raw_data/
# File 2019020860.json already in dir raw_data/
# File 2019020866.json already in dir raw_data/
# File 2019020877.json already in dir raw_data/
# File 2019020880.json already in dir raw_data/
# File 2019020891.json already in dir raw_data/
# File 2019020895.json already in dir raw_data/
# File 2019020906.json already in dir raw_data/
# File 2019020915.json already in dir raw_data/
# File 2019020920.json already in dir raw_data/
# File 2019020927.json already in dir raw_data/
# File 2019020933.json already in dir raw_data/
# File 2019020942.json already in dir raw_data/
# File 2019020948.json already in dir raw_data/
# File 2019020959.json already in dir raw_data/
# File 2019020967.json already in dir raw_data/
# File 2019020968.json already in dir raw_data/
# File 2019020981.json already in dir raw_data/
# File 2019020985.json already in dir raw_data/
# File 2019020994.json already in dir raw_data/
# File 2019020999.json already in dir raw_data/
# File 2019021011.json already in dir raw_data/
# File 2019021017.json already in dir raw_data/
# File 2019021020.json already in dir raw_data/
# File 2019021029.json already in dir raw_data/
# File 2019021033.json already in dir raw_data/
# File 2019021043.json already in dir raw_data/
# File 2019021049.json already in dir raw_data/
# File 2019021059.json already in dir raw_data/
# File 2019021066.json already in dir raw_data/
# File 2019021070.json already in dir raw_data/
# File 2019021079.json already in dir raw_data/
# File 2019030031.json already in dir raw_data/
# File 2019030071.json already in dir raw_data/
# File 2019030032.json already in dir raw_data/
# File 2019030042.json already in dir raw_data/
# File 2019030043.json already in dir raw_data/
# File 2019030083.json already in dir raw_data/
# File 2019030044.json already in dir raw_data/
# File 2019030015.json already in dir raw_data/
# File 2019030005.json already in dir raw_data/
# File 2019030121.json already in dir raw_data/
# File 2019030141.json already in dir raw_data/
# File 2019030122.json already in dir raw_data/
# File 2019030162.json already in dir raw_data/
# File 2019030143.json already in dir raw_data/
# File 2019030133.json already in dir raw_data/
# File 2019030124.json already in dir raw_data/
# File 2019030114.json already in dir raw_data/
# File 2019030125.json already in dir raw_data/
# File 2019030135.json already in dir raw_data/
# File 2019030116.json already in dir raw_data/
# File 2019030241.json already in dir raw_data/
# File 2019030221.json already in dir raw_data/
# File 2019030211.json already in dir raw_data/
# File 2019030222.json already in dir raw_data/
# File 2019030212.json already in dir raw_data/
# File 2019030224.json already in dir raw_data/
# File 2019030244.json already in dir raw_data/
# File 2019030225.json already in dir raw_data/
# File 2019030215.json already in dir raw_data/
# File 2019030246.json already in dir raw_data/
# File 2019030216.json already in dir raw_data/
# File 2019030247.json already in dir raw_data/
# File 2019030217.json already in dir raw_data/
# File 2019030321.json already in dir raw_data/
# File 2019030311.json already in dir raw_data/
# File 2019030322.json already in dir raw_data/
# File 2019030312.json already in dir raw_data/
# File 2019030323.json already in dir raw_data/
# File 2019030313.json already in dir raw_data/
# File 2019030324.json already in dir raw_data/
# File 2019030314.json already in dir raw_data/
# File 2019030325.json already in dir raw_data/
# File 2019030315.json already in dir raw_data/
# File 2019030316.json already in dir raw_data/
# File 2019030411.json already in dir raw_data/
# File 2019030412.json already in dir raw_data/
# File 2019030413.json already in dir raw_data/
# File 2019030414.json already in dir raw_data/
# File 2019030415.json already in dir raw_data/
# File 2019030416.json already in dir raw_data/
# File 2020020001.json already in dir raw_data/
# File 2020020006.json already in dir raw_data/
# File 2020020017.json already in dir raw_data/
# File 2020020023.json already in dir raw_data/
# File 2020020035.json already in dir raw_data/
# File 2020020038.json already in dir raw_data/
# File 2020020046.json already in dir raw_data/
# File 2020020056.json already in dir raw_data/
# File 2020020060.json already in dir raw_data/
# File 2020020067.json already in dir raw_data/
# File 2020020077.json already in dir raw_data/
# File 2020020084.json already in dir raw_data/
# File 2020020092.json already in dir raw_data/
# File 2020020093.json already in dir raw_data/
# File 2020020107.json already in dir raw_data/
# File 2020020109.json already in dir raw_data/
# File 2020020123.json already in dir raw_data/
# File 2020020124.json already in dir raw_data/
# File 2020020136.json already in dir raw_data/
# File 2020020144.json already in dir raw_data/
# File 2020020152.json already in dir raw_data/
# File 2020020160.json already in dir raw_data/
# File 2020020164.json already in dir raw_data/
# File 2020020174.json already in dir raw_data/
# File 2020020183.json already in dir raw_data/
# File 2020020188.json already in dir raw_data/
# File 2020020196.json already in dir raw_data/
# File 2020020203.json already in dir raw_data/
# File 2020020212.json already in dir raw_data/
# File 2020020215.json already in dir raw_data/
# File 2020020228.json already in dir raw_data/
# File 2020020236.json already in dir raw_data/
# File 2020020242.json already in dir raw_data/
# File 2020020251.json already in dir raw_data/
# File 2020020253.json already in dir raw_data/
# File 2020020062.json already in dir raw_data/
# File 2020020265.json already in dir raw_data/
# File 2020020274.json already in dir raw_data/
# File 2020020278.json already in dir raw_data/
# File 2020020392.json already in dir raw_data/
# File 2020020009.json already in dir raw_data/
# File 2020020295.json already in dir raw_data/
# File 2020020296.json already in dir raw_data/
# File 2020020312.json already in dir raw_data/
# File 2020020323.json already in dir raw_data/
# File 2020020322.json already in dir raw_data/
# File 2020020342.json already in dir raw_data/
# File 2020020348.json already in dir raw_data/
# File 2020020301.json already in dir raw_data/
# File 2020020359.json already in dir raw_data/
# File 2020020163.json already in dir raw_data/
# File 2020020373.json already in dir raw_data/
# File 2020020374.json already in dir raw_data/
# File 2020020391.json already in dir raw_data/
# File 2020020398.json already in dir raw_data/
# File 2020020405.json already in dir raw_data/
# File 2020020412.json already in dir raw_data/
# File 2020020415.json already in dir raw_data/
# File 2020020425.json already in dir raw_data/
# File 2020020430.json already in dir raw_data/
# File 2020020444.json already in dir raw_data/
# File 2020020448.json already in dir raw_data/
# File 2020020457.json already in dir raw_data/
# File 2020020463.json already in dir raw_data/
# File 2020020201.json already in dir raw_data/
# File 2020020478.json already in dir raw_data/
# File 2020020477.json already in dir raw_data/
# File 2020020151.json already in dir raw_data/
# File 2020020496.json already in dir raw_data/
# File 2020020504.json already in dir raw_data/
# File 2020020511.json already in dir raw_data/
# File 2020020515.json already in dir raw_data/
# File 2020020524.json already in dir raw_data/
# File 2020020179.json already in dir raw_data/
# File 2020020542.json already in dir raw_data/
# File 2020020548.json already in dir raw_data/
# File 2020020498.json already in dir raw_data/
# File 2020020557.json already in dir raw_data/
# File 2020020571.json already in dir raw_data/
# File 2020020580.json already in dir raw_data/
# File 2020020585.json already in dir raw_data/
# File 2020020599.json already in dir raw_data/
# File 2020020390.json already in dir raw_data/
# File 2020020611.json already in dir raw_data/
# File 2020020621.json already in dir raw_data/
# File 2020020625.json already in dir raw_data/
# File 2020020229.json already in dir raw_data/
# File 2020020605.json already in dir raw_data/
# File 2020020652.json already in dir raw_data/
# File 2020020657.json already in dir raw_data/
# File 2020020195.json already in dir raw_data/
# File 2020020192.json already in dir raw_data/
# File 2020020665.json already in dir raw_data/
# File 2020020686.json already in dir raw_data/
# File 2020020691.json already in dir raw_data/
# File 2020020701.json already in dir raw_data/
# File 2020020706.json already in dir raw_data/
# File 2020020483.json already in dir raw_data/
# File 2020020725.json already in dir raw_data/
# File 2020020254.json already in dir raw_data/
# File 2020020738.json already in dir raw_data/
# File 2020020746.json already in dir raw_data/
# File 2020020757.json already in dir raw_data/
# File 2020020761.json already in dir raw_data/
# File 2020020447.json already in dir raw_data/
# File 2020020776.json already in dir raw_data/
# File 2020020347.json already in dir raw_data/
# File 2020020791.json already in dir raw_data/
# File 2020020796.json already in dir raw_data/
# File 2020020811.json already in dir raw_data/
# File 2020020020.json already in dir raw_data/
# File 2020020824.json already in dir raw_data/
# File 2020020033.json already in dir raw_data/
# File 2020020280.json already in dir raw_data/
# File 2020020048.json already in dir raw_data/
# File 2020020854.json already in dir raw_data/
# File 2020020843.json already in dir raw_data/
# File 2020020231.json already in dir raw_data/
# File 2020020653.json already in dir raw_data/
# File 2020020526.json already in dir raw_data/
# File 2020020803.json already in dir raw_data/
# File 2020020741.json already in dir raw_data/
# File 2020020673.json already in dir raw_data/
# File 2020030111.json already in dir raw_data/
# File 2020030122.json already in dir raw_data/
# File 2020020864.json already in dir raw_data/
# File 2020020634.json already in dir raw_data/
# File 2020030143.json already in dir raw_data/
# File 2020030124.json already in dir raw_data/
# File 2020030144.json already in dir raw_data/
# File 2020030134.json already in dir raw_data/
# File 2020030115.json already in dir raw_data/
# File 2020030174.json already in dir raw_data/
# File 2020030116.json already in dir raw_data/
# File 2020030175.json already in dir raw_data/
# File 2020030167.json already in dir raw_data/
# File 2020030176.json already in dir raw_data/
# File 2020030221.json already in dir raw_data/
# File 2020030177.json already in dir raw_data/
# File 2020030222.json already in dir raw_data/
# File 2020030241.json already in dir raw_data/
# File 2020030213.json already in dir raw_data/
# File 2020030242.json already in dir raw_data/
# File 2020030224.json already in dir raw_data/
# File 2020030243.json already in dir raw_data/
# File 2020030215.json already in dir raw_data/
# File 2020030225.json already in dir raw_data/
# File 2020030216.json already in dir raw_data/
# File 2020030236.json already in dir raw_data/
# File 2020030321.json already in dir raw_data/
# File 2020030311.json already in dir raw_data/
# File 2020030322.json already in dir raw_data/
# File 2020030312.json already in dir raw_data/
# File 2020030323.json already in dir raw_data/
# File 2020030313.json already in dir raw_data/
# File 2020030324.json already in dir raw_data/
# File 2020030314.json already in dir raw_data/
# File 2020030325.json already in dir raw_data/
# File 2020030315.json already in dir raw_data/
# File 2020030326.json already in dir raw_data/
# File 2020030316.json already in dir raw_data/
# File 2020030327.json already in dir raw_data/
# File 2020030411.json already in dir raw_data/
# File 2020030412.json already in dir raw_data/
# File 2020030413.json already in dir raw_data/
# File 2020030414.json already in dir raw_data/
# File 2020030415.json already in dir raw_data/

# %%
path = "raw_data/"
allseasons = ["20162017","20172018","20182019","20192020","20202021"]

download_json(allseasons, path)
# Out:
# File 2016020001.json already in dir raw_data/
# File 2016020005.json already in dir raw_data/
# File 2016020014.json already in dir raw_data/
# File 2016020017.json already in dir raw_data/
# File 2016020030.json already in dir raw_data/
# File 2016020033.json already in dir raw_data/
# File 2016020037.json already in dir raw_data/
# File 2016020049.json already in dir raw_data/
# File 2016020051.json already in dir raw_data/
# File 2016020062.json already in dir raw_data/
# File 2016020065.json already in dir raw_data/
# File 2016020077.json already in dir raw_data/
# File 2016020081.json already in dir raw_data/
# File 2016020083.json already in dir raw_data/
# File 2016020094.json already in dir raw_data/
# File 2016020098.json already in dir raw_data/
# File 2016020107.json already in dir raw_data/
# File 2016020113.json already in dir raw_data/
# File 2016020123.json already in dir raw_data/
# File 2016020132.json already in dir raw_data/
# File 2016020143.json already in dir raw_data/
# File 2016020146.json already in dir raw_data/
# File 2016020158.json already in dir raw_data/
# File 2016020161.json already in dir raw_data/
# File 2016020174.json already in dir raw_data/
# File 2016020180.json already in dir raw_data/
# File 2016020183.json already in dir raw_data/
# File 2016020193.json already in dir raw_data/
# File 2016020196.json already in dir raw_data/
# File 2016020206.json already in dir raw_data/
# File 2016020212.json already in dir raw_data/
# File 2016020223.json already in dir raw_data/
# File 2016020229.json already in dir raw_data/
# File 2016020230.json already in dir raw_data/
# File 2016020243.json already in dir raw_data/
# File 2016020245.json already in dir raw_data/
# File 2016020255.json already in dir raw_data/
# File 2016020260.json already in dir raw_data/
# File 2016020271.json already in dir raw_data/
# File 2016020276.json already in dir raw_data/
# File 2016020283.json already in dir raw_data/
# File 2016020288.json already in dir raw_data/
# File 2016020300.json already in dir raw_data/
# File 2016020302.json already in dir raw_data/
# File 2016020313.json already in dir raw_data/
# File 2016020322.json already in dir raw_data/
# File 2016020328.json already in dir raw_data/
# File 2016020330.json already in dir raw_data/
# File 2016020342.json already in dir raw_data/
# File 2016020345.json already in dir raw_data/
# File 2016020357.json already in dir raw_data/
# File 2016020359.json already in dir raw_data/
# File 2016020377.json already in dir raw_data/
# File 2016020378.json already in dir raw_data/
# File 2016020382.json already in dir raw_data/
# File 2016020391.json already in dir raw_data/
# File 2016020395.json already in dir raw_data/
# File 2016020405.json already in dir raw_data/
# File 2016020411.json already in dir raw_data/
# File 2016020421.json already in dir raw_data/
# File 2016020429.json already in dir raw_data/
# File 2016020431.json already in dir raw_data/
# File 2016020441.json already in dir raw_data/
# File 2016020445.json already in dir raw_data/
# File 2016020453.json already in dir raw_data/
# File 2016020460.json already in dir raw_data/
# File 2016020470.json already in dir raw_data/
# File 2016020476.json already in dir raw_data/
# File 2016020481.json already in dir raw_data/
# File 2016020493.json already in dir raw_data/
# File 2016020495.json already in dir raw_data/
# File 2016020505.json already in dir raw_data/
# File 2016020517.json already in dir raw_data/
# File 2016020527.json already in dir raw_data/
# File 2016020532.json already in dir raw_data/
# File 2016020544.json already in dir raw_data/
# File 2016020548.json already in dir raw_data/
# File 2016020559.json already in dir raw_data/
# File 2016020562.json already in dir raw_data/
# File 2016020565.json already in dir raw_data/
# File 2016020572.json already in dir raw_data/
# File 2016020578.json already in dir raw_data/
# File 2016020585.json already in dir raw_data/
# File 2016020591.json already in dir raw_data/
# File 2016020603.json already in dir raw_data/
# File 2016020609.json already in dir raw_data/
# File 2016020613.json already in dir raw_data/
# File 2016020620.json already in dir raw_data/
# File 2016020624.json already in dir raw_data/
# File 2016020633.json already in dir raw_data/
# File 2016020640.json already in dir raw_data/
# File 2016020652.json already in dir raw_data/
# File 2016020656.json already in dir raw_data/
# File 2016020663.json already in dir raw_data/
# File 2016020672.json already in dir raw_data/
# File 2016020677.json already in dir raw_data/
# File 2016020685.json already in dir raw_data/
# File 2016020691.json already in dir raw_data/
# File 2016020703.json already in dir raw_data/
# File 2016020708.json already in dir raw_data/
# File 2016020714.json already in dir raw_data/
# File 2016020724.json already in dir raw_data/
# File 2016020728.json already in dir raw_data/
# File 2016020741.json already in dir raw_data/
# File 2016020755.json already in dir raw_data/
# File 2016020759.json already in dir raw_data/
# File 2016020766.json already in dir raw_data/
# File 2016020771.json already in dir raw_data/
# File 2016020784.json already in dir raw_data/
# File 2016020787.json already in dir raw_data/
# File 2016020790.json already in dir raw_data/
# File 2016020801.json already in dir raw_data/
# File 2016020802.json already in dir raw_data/
# File 2016020813.json already in dir raw_data/
# File 2016020815.json already in dir raw_data/
# File 2016020828.json already in dir raw_data/
# File 2016020834.json already in dir raw_data/
# File 2016020836.json already in dir raw_data/
# File 2016020843.json already in dir raw_data/
# File 2016020848.json already in dir raw_data/
# File 2016020855.json already in dir raw_data/
# File 2016020858.json already in dir raw_data/
# File 2016020869.json already in dir raw_data/
# File 2016020880.json already in dir raw_data/
# File 2016020882.json already in dir raw_data/
# File 2016020891.json already in dir raw_data/
# File 2016020894.json already in dir raw_data/
# File 2016020900.json already in dir raw_data/
# File 2016020904.json already in dir raw_data/
# File 2016020912.json already in dir raw_data/
# File 2016020919.json already in dir raw_data/
# File 2016020922.json already in dir raw_data/
# File 2016020934.json already in dir raw_data/
# File 2016020936.json already in dir raw_data/
# File 2016020946.json already in dir raw_data/
# File 2016020952.json already in dir raw_data/
# File 2016020962.json already in dir raw_data/
# File 2016020969.json already in dir raw_data/
# File 2016020974.json already in dir raw_data/
# File 2016020982.json already in dir raw_data/
# File 2016020985.json already in dir raw_data/
# File 2016020995.json already in dir raw_data/
# File 2016021000.json already in dir raw_data/
# File 2016021012.json already in dir raw_data/
# File 2016021017.json already in dir raw_data/
# File 2016021025.json already in dir raw_data/
# File 2016021033.json already in dir raw_data/
# File 2016021037.json already in dir raw_data/
# File 2016021049.json already in dir raw_data/
# File 2016021053.json already in dir raw_data/
# File 2016021063.json already in dir raw_data/
# File 2016021070.json already in dir raw_data/
# File 2016021075.json already in dir raw_data/
# File 2016021086.json already in dir raw_data/
# File 2016021089.json already in dir raw_data/
# File 2016021101.json already in dir raw_data/
# File 2016021105.json already in dir raw_data/
# File 2016021119.json already in dir raw_data/
# File 2016020477.json already in dir raw_data/
# File 2016021024.json already in dir raw_data/
# File 2016021137.json already in dir raw_data/
# File 2016021142.json already in dir raw_data/
# File 2016021150.json already in dir raw_data/
# File 2016021157.json already in dir raw_data/
# File 2016021165.json already in dir raw_data/
# File 2016021176.json already in dir raw_data/
# File 2016021179.json already in dir raw_data/
# File 2016021192.json already in dir raw_data/
# File 2016021194.json already in dir raw_data/
# File 2016021206.json already in dir raw_data/
# File 2016021207.json already in dir raw_data/
# File 2016021221.json already in dir raw_data/
# File 2016030111.json already in dir raw_data/
# File 2016030131.json already in dir raw_data/
# File 2016030112.json already in dir raw_data/
# File 2016030122.json already in dir raw_data/
# File 2016030163.json already in dir raw_data/
# File 2016030123.json already in dir raw_data/
# File 2016030114.json already in dir raw_data/
# File 2016030134.json already in dir raw_data/
# File 2016030115.json already in dir raw_data/
# File 2016030135.json already in dir raw_data/
# File 2016030165.json already in dir raw_data/
# File 2016030126.json already in dir raw_data/
# File 2016030231.json already in dir raw_data/
# File 2016030211.json already in dir raw_data/
# File 2016030232.json already in dir raw_data/
# File 2016030212.json already in dir raw_data/
# File 2016030233.json already in dir raw_data/
# File 2016030223.json already in dir raw_data/
# File 2016030213.json already in dir raw_data/
# File 2016030224.json already in dir raw_data/
# File 2016030214.json already in dir raw_data/
# File 2016030235.json already in dir raw_data/
# File 2016030215.json already in dir raw_data/
# File 2016030236.json already in dir raw_data/
# File 2016030226.json already in dir raw_data/
# File 2016030216.json already in dir raw_data/
# File 2016030227.json already in dir raw_data/
# File 2016030321.json already in dir raw_data/
# File 2016030311.json already in dir raw_data/
# File 2016030322.json already in dir raw_data/
# File 2016030312.json already in dir raw_data/
# File 2016030323.json already in dir raw_data/
# File 2016030313.json already in dir raw_data/
# File 2016030324.json already in dir raw_data/
# File 2016030314.json already in dir raw_data/
# File 2016030325.json already in dir raw_data/
# File 2016030315.json already in dir raw_data/
# File 2016030326.json already in dir raw_data/
# File 2016030316.json already in dir raw_data/
# File 2016030317.json already in dir raw_data/
# File 2016030411.json already in dir raw_data/
# File 2016030412.json already in dir raw_data/
# File 2016030413.json already in dir raw_data/
# File 2016030414.json already in dir raw_data/
# File 2016030415.json already in dir raw_data/
# File 2016030416.json already in dir raw_data/
# File 2017020001.json already in dir raw_data/
# File 2017020005.json already in dir raw_data/
# File 2017020013.json already in dir raw_data/
# File 2017020019.json already in dir raw_data/
# File 2017020031.json already in dir raw_data/
# File 2017020032.json already in dir raw_data/
# File 2017020039.json already in dir raw_data/
# File 2017020046.json already in dir raw_data/
# File 2017020051.json already in dir raw_data/
# File 2017020058.json already in dir raw_data/
# File 2017020063.json already in dir raw_data/
# File 2017020077.json already in dir raw_data/
# File 2017020080.json already in dir raw_data/
# File 2017020082.json already in dir raw_data/
# File 2017020092.json already in dir raw_data/
# File 2017020095.json already in dir raw_data/
# File 2017020104.json already in dir raw_data/
# File 2017020110.json already in dir raw_data/
# File 2017020122.json already in dir raw_data/
# File 2017020123.json already in dir raw_data/
# File 2017020126.json already in dir raw_data/
# File 2017020136.json already in dir raw_data/
# File 2017020138.json already in dir raw_data/
# File 2017020149.json already in dir raw_data/
# File 2017020155.json already in dir raw_data/
# File 2017020167.json already in dir raw_data/
# File 2017020170.json already in dir raw_data/
# File 2017020178.json already in dir raw_data/
# File 2017020181.json already in dir raw_data/
# File 2017020186.json already in dir raw_data/
# File 2017020198.json already in dir raw_data/
# File 2017020200.json already in dir raw_data/
# File 2017020213.json already in dir raw_data/
# File 2017020217.json already in dir raw_data/
# File 2017020223.json already in dir raw_data/
# File 2017020232.json already in dir raw_data/
# File 2017020235.json already in dir raw_data/
# File 2017020247.json already in dir raw_data/
# File 2017020249.json already in dir raw_data/
# File 2017020261.json already in dir raw_data/
# File 2017020265.json already in dir raw_data/
# File 2017020267.json already in dir raw_data/
# File 2017020275.json already in dir raw_data/
# File 2017020278.json already in dir raw_data/
# File 2017020290.json already in dir raw_data/
# File 2017020292.json already in dir raw_data/
# File 2017020305.json already in dir raw_data/
# File 2017020310.json already in dir raw_data/
# File 2017020316.json already in dir raw_data/
# File 2017020319.json already in dir raw_data/
# File 2017020334.json already in dir raw_data/
# File 2017020348.json already in dir raw_data/
# File 2017020359.json already in dir raw_data/
# File 2017020362.json already in dir raw_data/
# File 2017020367.json already in dir raw_data/
# File 2017020377.json already in dir raw_data/
# File 2017020381.json already in dir raw_data/
# File 2017020388.json already in dir raw_data/
# File 2017020396.json already in dir raw_data/
# File 2017020408.json already in dir raw_data/
# File 2017020412.json already in dir raw_data/
# File 2017020417.json already in dir raw_data/
# File 2017020426.json already in dir raw_data/
# File 2017020430.json already in dir raw_data/
# File 2017020439.json already in dir raw_data/
# File 2017020446.json already in dir raw_data/
# File 2017020456.json already in dir raw_data/
# File 2017020460.json already in dir raw_data/
# File 2017020466.json already in dir raw_data/
# File 2017020475.json already in dir raw_data/
# File 2017020479.json already in dir raw_data/
# File 2017020491.json already in dir raw_data/
# File 2017020496.json already in dir raw_data/
# File 2017020507.json already in dir raw_data/
# File 2017020511.json already in dir raw_data/
# File 2017020516.json already in dir raw_data/
# File 2017020526.json already in dir raw_data/
# File 2017020529.json already in dir raw_data/
# File 2017020539.json already in dir raw_data/
# File 2017020543.json already in dir raw_data/
# File 2017020558.json already in dir raw_data/
# File 2017020569.json already in dir raw_data/
# File 2017020576.json already in dir raw_data/
# File 2017020587.json already in dir raw_data/
# File 2017020593.json already in dir raw_data/
# File 2017020601.json already in dir raw_data/
# File 2017020602.json already in dir raw_data/
# File 2017020614.json already in dir raw_data/
# File 2017020617.json already in dir raw_data/
# File 2017020628.json already in dir raw_data/
# File 2017020633.json already in dir raw_data/
# File 2017020642.json already in dir raw_data/
# File 2017020652.json already in dir raw_data/
# File 2017020653.json already in dir raw_data/
# File 2017020660.json already in dir raw_data/
# File 2017020662.json already in dir raw_data/
# File 2017020665.json already in dir raw_data/
# File 2017020670.json already in dir raw_data/
# File 2017020681.json already in dir raw_data/
# File 2017020683.json already in dir raw_data/
# File 2017020687.json already in dir raw_data/
# File 2017020693.json already in dir raw_data/
# File 2017020695.json already in dir raw_data/
# File 2017020705.json already in dir raw_data/
# File 2017020708.json already in dir raw_data/
# File 2017020721.json already in dir raw_data/
# File 2017020726.json already in dir raw_data/
# File 2017020732.json already in dir raw_data/
# File 2017020744.json already in dir raw_data/
# File 2017020746.json already in dir raw_data/
# File 2017020761.json already in dir raw_data/
# File 2017020773.json already in dir raw_data/
# File 2017020776.json already in dir raw_data/
# File 2017020788.json already in dir raw_data/
# File 2017020792.json already in dir raw_data/
# File 2017020805.json already in dir raw_data/
# File 2017020808.json already in dir raw_data/
# File 2017020812.json already in dir raw_data/
# File 2017020823.json already in dir raw_data/
# File 2017020826.json already in dir raw_data/
# File 2017020835.json already in dir raw_data/
# File 2017020843.json already in dir raw_data/
# File 2017020853.json already in dir raw_data/
# File 2017020861.json already in dir raw_data/
# File 2017020864.json already in dir raw_data/
# File 2017020876.json already in dir raw_data/
# File 2017020879.json already in dir raw_data/
# File 2017020890.json already in dir raw_data/
# File 2017020894.json already in dir raw_data/
# File 2017020905.json already in dir raw_data/
# File 2017020912.json already in dir raw_data/
# File 2017020918.json already in dir raw_data/
# File 2017020927.json already in dir raw_data/
# File 2017020930.json already in dir raw_data/
# File 2017020941.json already in dir raw_data/
# File 2017020946.json already in dir raw_data/
# File 2017020959.json already in dir raw_data/
# File 2017020964.json already in dir raw_data/
# File 2017020969.json already in dir raw_data/
# File 2017020978.json already in dir raw_data/
# File 2017020983.json already in dir raw_data/
# File 2017020991.json already in dir raw_data/
# File 2017021000.json already in dir raw_data/
# File 2017021008.json already in dir raw_data/
# File 2017021016.json already in dir raw_data/
# File 2017021020.json already in dir raw_data/
# File 2017021029.json already in dir raw_data/
# File 2017021032.json already in dir raw_data/
# File 2017021044.json already in dir raw_data/
# File 2017021048.json already in dir raw_data/
# File 2017021059.json already in dir raw_data/
# File 2017021063.json already in dir raw_data/
# File 2017021071.json already in dir raw_data/
# File 2017021078.json already in dir raw_data/
# File 2017021083.json already in dir raw_data/
# File 2017021092.json already in dir raw_data/
# File 2017021098.json already in dir raw_data/
# File 2017021108.json already in dir raw_data/
# File 2017021116.json already in dir raw_data/
# File 2017021121.json already in dir raw_data/
# File 2017021132.json already in dir raw_data/
# File 2017021136.json already in dir raw_data/
# File 2017021146.json already in dir raw_data/
# File 2017021151.json already in dir raw_data/
# File 2017021163.json already in dir raw_data/
# File 2017021168.json already in dir raw_data/
# File 2017021177.json already in dir raw_data/
# File 2017021186.json already in dir raw_data/
# File 2017021190.json already in dir raw_data/
# File 2017021200.json already in dir raw_data/
# File 2017021206.json already in dir raw_data/
# File 2017021218.json already in dir raw_data/
# File 2017021223.json already in dir raw_data/
# File 2017021229.json already in dir raw_data/
# File 2017021238.json already in dir raw_data/
# File 2017021241.json already in dir raw_data/
# File 2017021253.json already in dir raw_data/
# File 2017021257.json already in dir raw_data/
# File 2017020616.json already in dir raw_data/
# File 2017030141.json already in dir raw_data/
# File 2017030111.json already in dir raw_data/
# File 2017030142.json already in dir raw_data/
# File 2017030112.json already in dir raw_data/
# File 2017030143.json already in dir raw_data/
# File 2017030123.json already in dir raw_data/
# File 2017030133.json already in dir raw_data/
# File 2017030144.json already in dir raw_data/
# File 2017030124.json already in dir raw_data/
# File 2017030145.json already in dir raw_data/
# File 2017030115.json already in dir raw_data/
# File 2017030146.json already in dir raw_data/
# File 2017030126.json already in dir raw_data/
# File 2017030127.json already in dir raw_data/
# File 2017030221.json already in dir raw_data/
# File 2017030231.json already in dir raw_data/
# File 2017030211.json already in dir raw_data/
# File 2017030222.json already in dir raw_data/
# File 2017030212.json already in dir raw_data/
# File 2017030223.json already in dir raw_data/
# File 2017030213.json already in dir raw_data/
# File 2017030224.json already in dir raw_data/
# File 2017030214.json already in dir raw_data/
# File 2017030225.json already in dir raw_data/
# File 2017030215.json already in dir raw_data/
# File 2017030226.json already in dir raw_data/
# File 2017030237.json already in dir raw_data/
# File 2017030311.json already in dir raw_data/
# File 2017030321.json already in dir raw_data/
# File 2017030312.json already in dir raw_data/
# File 2017030322.json already in dir raw_data/
# File 2017030313.json already in dir raw_data/
# File 2017030323.json already in dir raw_data/
# File 2017030314.json already in dir raw_data/
# File 2017030324.json already in dir raw_data/
# File 2017030315.json already in dir raw_data/
# File 2017030325.json already in dir raw_data/
# File 2017030316.json already in dir raw_data/
# File 2017030317.json already in dir raw_data/
# File 2017030411.json already in dir raw_data/
# File 2017030412.json already in dir raw_data/
# File 2017030413.json already in dir raw_data/
# File 2017030414.json already in dir raw_data/
# File 2017030415.json already in dir raw_data/
# File 2018020005.json already in dir raw_data/
# File 2018020015.json already in dir raw_data/
# File 2018020020.json already in dir raw_data/
# File 2018020029.json already in dir raw_data/
# File 2018020032.json already in dir raw_data/
# File 2018020036.json already in dir raw_data/
# File 2018020042.json already in dir raw_data/
# File 2018020045.json already in dir raw_data/
# File 2018020057.json already in dir raw_data/
# File 2018020071.json already in dir raw_data/
# File 2018020074.json already in dir raw_data/
# File 2018020078.json already in dir raw_data/
# File 2018020086.json already in dir raw_data/
# File 2018020090.json already in dir raw_data/
# File 2018020099.json already in dir raw_data/
# File 2018020102.json already in dir raw_data/
# File 2018020115.json already in dir raw_data/
# File 2018020118.json already in dir raw_data/
# File 2018020122.json already in dir raw_data/
# File 2018020130.json already in dir raw_data/
# File 2018020134.json already in dir raw_data/
# File 2018020144.json already in dir raw_data/
# File 2018020148.json already in dir raw_data/
# File 2018020159.json already in dir raw_data/
# File 2018020165.json already in dir raw_data/
# File 2018020167.json already in dir raw_data/
# File 2018020178.json already in dir raw_data/
# File 2018020180.json already in dir raw_data/
# File 2018020192.json already in dir raw_data/
# File 2018020195.json already in dir raw_data/
# File 2018020207.json already in dir raw_data/
# File 2018020210.json already in dir raw_data/
# File 2018020215.json already in dir raw_data/
# File 2018020224.json already in dir raw_data/
# File 2018020227.json already in dir raw_data/
# File 2018020236.json already in dir raw_data/
# File 2018020242.json already in dir raw_data/
# File 2018020253.json already in dir raw_data/
# File 2018020260.json already in dir raw_data/
# File 2018020265.json already in dir raw_data/
# File 2018020273.json already in dir raw_data/
# File 2018020277.json already in dir raw_data/
# File 2018020286.json already in dir raw_data/
# File 2018020292.json already in dir raw_data/
# File 2018020303.json already in dir raw_data/
# File 2018020308.json already in dir raw_data/
# File 2018020317.json already in dir raw_data/
# File 2018020319.json already in dir raw_data/
# File 2018020332.json already in dir raw_data/
# File 2018020347.json already in dir raw_data/
# File 2018020358.json already in dir raw_data/
# File 2018020362.json already in dir raw_data/
# File 2018020367.json already in dir raw_data/
# File 2018020377.json already in dir raw_data/
# File 2018020382.json already in dir raw_data/
# File 2018020390.json already in dir raw_data/
# File 2018020395.json already in dir raw_data/
# File 2018020407.json already in dir raw_data/
# File 2018020413.json already in dir raw_data/
# File 2018020417.json already in dir raw_data/
# File 2018020426.json already in dir raw_data/
# File 2018020429.json already in dir raw_data/
# File 2018020440.json already in dir raw_data/
# File 2018020444.json already in dir raw_data/
# File 2018020454.json already in dir raw_data/
# File 2018020461.json already in dir raw_data/
# File 2018020465.json already in dir raw_data/
# File 2018020475.json already in dir raw_data/
# File 2018020479.json already in dir raw_data/
# File 2018020487.json already in dir raw_data/
# File 2018020495.json already in dir raw_data/
# File 2018020505.json already in dir raw_data/
# File 2018020512.json already in dir raw_data/
# File 2018020517.json already in dir raw_data/
# File 2018020528.json already in dir raw_data/
# File 2018020530.json already in dir raw_data/
# File 2018020542.json already in dir raw_data/
# File 2018020545.json already in dir raw_data/
# File 2018020559.json already in dir raw_data/
# File 2018020567.json already in dir raw_data/
# File 2018020580.json already in dir raw_data/
# File 2018020583.json already in dir raw_data/
# File 2018020598.json already in dir raw_data/
# File 2018020599.json already in dir raw_data/
# File 2018020612.json already in dir raw_data/
# File 2018020615.json already in dir raw_data/
# File 2018020621.json already in dir raw_data/
# File 2018020629.json already in dir raw_data/
# File 2018020636.json already in dir raw_data/
# File 2018020647.json already in dir raw_data/
# File 2018020652.json already in dir raw_data/
# File 2018020657.json already in dir raw_data/
# File 2018020668.json already in dir raw_data/
# File 2018020671.json already in dir raw_data/
# File 2018020683.json already in dir raw_data/
# File 2018020687.json already in dir raw_data/
# File 2018020699.json already in dir raw_data/
# File 2018020706.json already in dir raw_data/
# File 2018020711.json already in dir raw_data/
# File 2018020721.json already in dir raw_data/
# File 2018020726.json already in dir raw_data/
# File 2018020733.json already in dir raw_data/
# File 2018020740.json already in dir raw_data/
# File 2018020751.json already in dir raw_data/
# File 2018020756.json already in dir raw_data/
# File 2018020760.json already in dir raw_data/
# File 2018020765.json already in dir raw_data/
# File 2018020771.json already in dir raw_data/
# File 2018020773.json already in dir raw_data/
# File 2018020776.json already in dir raw_data/
# File 2018020778.json already in dir raw_data/
# File 2018020781.json already in dir raw_data/
# File 2018020789.json already in dir raw_data/
# File 2018020802.json already in dir raw_data/
# File 2018020805.json already in dir raw_data/
# File 2018020809.json already in dir raw_data/
# File 2018020821.json already in dir raw_data/
# File 2018020823.json already in dir raw_data/
# File 2018020837.json already in dir raw_data/
# File 2018020838.json already in dir raw_data/
# File 2018020852.json already in dir raw_data/
# File 2018020860.json already in dir raw_data/
# File 2018020863.json already in dir raw_data/
# File 2018020875.json already in dir raw_data/
# File 2018020877.json already in dir raw_data/
# File 2018020888.json already in dir raw_data/
# File 2018020892.json already in dir raw_data/
# File 2018020904.json already in dir raw_data/
# File 2018020910.json already in dir raw_data/
# File 2018020916.json already in dir raw_data/
# File 2018020925.json already in dir raw_data/
# File 2018020929.json already in dir raw_data/
# File 2018020940.json already in dir raw_data/
# File 2018020945.json already in dir raw_data/
# File 2018020956.json already in dir raw_data/
# File 2018020962.json already in dir raw_data/
# File 2018020968.json already in dir raw_data/
# File 2018020979.json already in dir raw_data/
# File 2018020985.json already in dir raw_data/
# File 2018020991.json already in dir raw_data/
# File 2018020999.json already in dir raw_data/
# File 2018021009.json already in dir raw_data/
# File 2018021017.json already in dir raw_data/
# File 2018021019.json already in dir raw_data/
# File 2018021029.json already in dir raw_data/
# File 2018021033.json already in dir raw_data/
# File 2018021044.json already in dir raw_data/
# File 2018021048.json already in dir raw_data/
# File 2018021060.json already in dir raw_data/
# File 2018021065.json already in dir raw_data/
# File 2018021072.json already in dir raw_data/
# File 2018021080.json already in dir raw_data/
# File 2018021083.json already in dir raw_data/
# File 2018021093.json already in dir raw_data/
# File 2018021099.json already in dir raw_data/
# File 2018021111.json already in dir raw_data/
# File 2018021118.json already in dir raw_data/
# File 2018021123.json already in dir raw_data/
# File 2018021132.json already in dir raw_data/
# File 2018021136.json already in dir raw_data/
# File 2018021148.json already in dir raw_data/
# File 2018021150.json already in dir raw_data/
# File 2018021164.json already in dir raw_data/
# File 2018021169.json already in dir raw_data/
# File 2018021178.json already in dir raw_data/
# File 2018021185.json already in dir raw_data/
# File 2018021189.json already in dir raw_data/
# File 2018021197.json already in dir raw_data/
# File 2018021204.json already in dir raw_data/
# File 2018021215.json already in dir raw_data/
# File 2018021221.json already in dir raw_data/
# File 2018021229.json already in dir raw_data/
# File 2018021239.json already in dir raw_data/
# File 2018021242.json already in dir raw_data/
# File 2018021254.json already in dir raw_data/
# File 2018021257.json already in dir raw_data/
# File 2018030111.json already in dir raw_data/
# File 2018030121.json already in dir raw_data/
# File 2018030112.json already in dir raw_data/
# File 2018030132.json already in dir raw_data/
# File 2018030143.json already in dir raw_data/
# File 2018030123.json already in dir raw_data/
# File 2018030114.json already in dir raw_data/
# File 2018030124.json already in dir raw_data/
# File 2018030134.json already in dir raw_data/
# File 2018030125.json already in dir raw_data/
# File 2018030155.json already in dir raw_data/
# File 2018030126.json already in dir raw_data/
# File 2018030136.json already in dir raw_data/
# File 2018030127.json already in dir raw_data/
# File 2018030137.json already in dir raw_data/
# File 2018030211.json already in dir raw_data/
# File 2018030221.json already in dir raw_data/
# File 2018030232.json already in dir raw_data/
# File 2018030222.json already in dir raw_data/
# File 2018030233.json already in dir raw_data/
# File 2018030213.json already in dir raw_data/
# File 2018030223.json already in dir raw_data/
# File 2018030214.json already in dir raw_data/
# File 2018030224.json already in dir raw_data/
# File 2018030215.json already in dir raw_data/
# File 2018030236.json already in dir raw_data/
# File 2018030216.json already in dir raw_data/
# File 2018030237.json already in dir raw_data/
# File 2018030247.json already in dir raw_data/
# File 2018030311.json already in dir raw_data/
# File 2018030321.json already in dir raw_data/
# File 2018030312.json already in dir raw_data/
# File 2018030322.json already in dir raw_data/
# File 2018030313.json already in dir raw_data/
# File 2018030323.json already in dir raw_data/
# File 2018030314.json already in dir raw_data/
# File 2018030324.json already in dir raw_data/
# File 2018030325.json already in dir raw_data/
# File 2018030326.json already in dir raw_data/
# File 2018030411.json already in dir raw_data/
# File 2018030412.json already in dir raw_data/
# File 2018030413.json already in dir raw_data/
# File 2018030414.json already in dir raw_data/
# File 2018030415.json already in dir raw_data/
# File 2018030416.json already in dir raw_data/
# File 2018030417.json already in dir raw_data/
# File 2019020001.json already in dir raw_data/
# File 2019020005.json already in dir raw_data/
# File 2019020016.json already in dir raw_data/
# File 2019020018.json already in dir raw_data/
# File 2019020031.json already in dir raw_data/
# File 2019020034.json already in dir raw_data/
# File 2019020036.json already in dir raw_data/
# File 2019020044.json already in dir raw_data/
# File 2019020047.json already in dir raw_data/
# File 2019020058.json already in dir raw_data/
# File 2019020061.json already in dir raw_data/
# File 2019020075.json already in dir raw_data/
# File 2019020078.json already in dir raw_data/
# File 2019020085.json already in dir raw_data/
# File 2019020092.json already in dir raw_data/
# File 2019020098.json already in dir raw_data/
# File 2019020107.json already in dir raw_data/
# File 2019020113.json already in dir raw_data/
# File 2019020124.json already in dir raw_data/
# File 2019020129.json already in dir raw_data/
# File 2019020133.json already in dir raw_data/
# File 2019020143.json already in dir raw_data/
# File 2019020145.json already in dir raw_data/
# File 2019020155.json already in dir raw_data/
# File 2019020161.json already in dir raw_data/
# File 2019020170.json already in dir raw_data/
# File 2019020177.json already in dir raw_data/
# File 2019020179.json already in dir raw_data/
# File 2019020188.json already in dir raw_data/
# File 2019020194.json already in dir raw_data/
# File 2019020196.json already in dir raw_data/
# File 2019020204.json already in dir raw_data/
# File 2019020218.json already in dir raw_data/
# File 2019020220.json already in dir raw_data/
# File 2019020225.json already in dir raw_data/
# File 2019020235.json already in dir raw_data/
# File 2019020237.json already in dir raw_data/
# File 2019020249.json already in dir raw_data/
# File 2019020252.json already in dir raw_data/
# File 2019020263.json already in dir raw_data/
# File 2019020270.json already in dir raw_data/
# File 2019020272.json already in dir raw_data/
# File 2019020281.json already in dir raw_data/
# File 2019020286.json already in dir raw_data/
# File 2019020294.json already in dir raw_data/
# File 2019020299.json already in dir raw_data/
# File 2019020314.json already in dir raw_data/
# File 2019020316.json already in dir raw_data/
# File 2019020318.json already in dir raw_data/
# File 2019020331.json already in dir raw_data/
# File 2019020333.json already in dir raw_data/
# File 2019020346.json already in dir raw_data/
# File 2019020348.json already in dir raw_data/
# File 2019020362.json already in dir raw_data/
# File 2019020365.json already in dir raw_data/
# File 2019020374.json already in dir raw_data/
# File 2019020377.json already in dir raw_data/
# File 2019020390.json already in dir raw_data/
# File 2019020391.json already in dir raw_data/
# File 2019020403.json already in dir raw_data/
# File 2019020416.json already in dir raw_data/
# File 2019020419.json already in dir raw_data/
# File 2019020424.json already in dir raw_data/
# File 2019020434.json already in dir raw_data/
# File 2019020438.json already in dir raw_data/
# File 2019020447.json already in dir raw_data/
# File 2019020452.json already in dir raw_data/
# File 2019020463.json already in dir raw_data/
# File 2019020468.json already in dir raw_data/
# File 2019020473.json already in dir raw_data/
# File 2019020484.json already in dir raw_data/
# File 2019020487.json already in dir raw_data/
# File 2019020499.json already in dir raw_data/
# File 2019020501.json already in dir raw_data/
# File 2019020515.json already in dir raw_data/
# File 2019020519.json already in dir raw_data/
# File 2019020524.json already in dir raw_data/
# File 2019020535.json already in dir raw_data/
# File 2019020538.json already in dir raw_data/
# File 2019020548.json already in dir raw_data/
# File 2019020552.json already in dir raw_data/
# File 2019020565.json already in dir raw_data/
# File 2019020569.json already in dir raw_data/
# File 2019020582.json already in dir raw_data/
# File 2019020593.json already in dir raw_data/
# File 2019020602.json already in dir raw_data/
# File 2019020612.json already in dir raw_data/
# File 2019020613.json already in dir raw_data/
# File 2019020626.json already in dir raw_data/
# File 2019020627.json already in dir raw_data/
# File 2019020639.json already in dir raw_data/
# File 2019020641.json already in dir raw_data/
# File 2019020653.json already in dir raw_data/
# File 2019020659.json already in dir raw_data/
# File 2019020663.json already in dir raw_data/
# File 2019020675.json already in dir raw_data/
# File 2019020678.json already in dir raw_data/
# File 2019020689.json already in dir raw_data/
# File 2019020692.json already in dir raw_data/
# File 2019020703.json already in dir raw_data/
# File 2019020709.json already in dir raw_data/
# File 2019020714.json already in dir raw_data/
# File 2019020725.json already in dir raw_data/
# File 2019020727.json already in dir raw_data/
# File 2019020740.json already in dir raw_data/
# File 2019020743.json already in dir raw_data/
# File 2019020755.json already in dir raw_data/
# File 2019020759.json already in dir raw_data/
# File 2019020761.json already in dir raw_data/
# File 2019020766.json already in dir raw_data/
# File 2019020768.json already in dir raw_data/
# File 2019020774.json already in dir raw_data/
# File 2019020776.json already in dir raw_data/
# File 2019020782.json already in dir raw_data/
# File 2019020785.json already in dir raw_data/
# File 2019020792.json already in dir raw_data/
# File 2019020806.json already in dir raw_data/
# File 2019020809.json already in dir raw_data/
# File 2019020812.json already in dir raw_data/
# File 2019020825.json already in dir raw_data/
# File 2019020827.json already in dir raw_data/
# File 2019020839.json already in dir raw_data/
# File 2019020843.json already in dir raw_data/
# File 2019020855.json already in dir raw_data/
# File 2019020860.json already in dir raw_data/
# File 2019020866.json already in dir raw_data/
# File 2019020877.json already in dir raw_data/
# File 2019020880.json already in dir raw_data/
# File 2019020891.json already in dir raw_data/
# File 2019020895.json already in dir raw_data/
# File 2019020906.json already in dir raw_data/
# File 2019020915.json already in dir raw_data/
# File 2019020920.json already in dir raw_data/
# File 2019020927.json already in dir raw_data/
# File 2019020933.json already in dir raw_data/
# File 2019020942.json already in dir raw_data/
# File 2019020948.json already in dir raw_data/
# File 2019020959.json already in dir raw_data/
# File 2019020967.json already in dir raw_data/
# File 2019020968.json already in dir raw_data/
# File 2019020981.json already in dir raw_data/
# File 2019020985.json already in dir raw_data/
# File 2019020994.json already in dir raw_data/
# File 2019020999.json already in dir raw_data/
# File 2019021011.json already in dir raw_data/
# File 2019021017.json already in dir raw_data/
# File 2019021020.json already in dir raw_data/
# File 2019021029.json already in dir raw_data/
# File 2019021033.json already in dir raw_data/
# File 2019021043.json already in dir raw_data/
# File 2019021049.json already in dir raw_data/
# File 2019021059.json already in dir raw_data/
# File 2019021066.json already in dir raw_data/
# File 2019021070.json already in dir raw_data/
# File 2019021079.json already in dir raw_data/
# File 2019030031.json already in dir raw_data/
# File 2019030071.json already in dir raw_data/
# File 2019030032.json already in dir raw_data/
# File 2019030042.json already in dir raw_data/
# File 2019030043.json already in dir raw_data/
# File 2019030083.json already in dir raw_data/
# File 2019030044.json already in dir raw_data/
# File 2019030015.json already in dir raw_data/
# File 2019030005.json already in dir raw_data/
# File 2019030121.json already in dir raw_data/
# File 2019030141.json already in dir raw_data/
# File 2019030122.json already in dir raw_data/
# File 2019030162.json already in dir raw_data/
# File 2019030143.json already in dir raw_data/
# File 2019030133.json already in dir raw_data/
# File 2019030124.json already in dir raw_data/
# File 2019030114.json already in dir raw_data/
# File 2019030125.json already in dir raw_data/
# File 2019030135.json already in dir raw_data/
# File 2019030116.json already in dir raw_data/
# File 2019030241.json already in dir raw_data/
# File 2019030221.json already in dir raw_data/
# File 2019030211.json already in dir raw_data/
# File 2019030222.json already in dir raw_data/
# File 2019030212.json already in dir raw_data/
# File 2019030224.json already in dir raw_data/
# File 2019030244.json already in dir raw_data/
# File 2019030225.json already in dir raw_data/
# File 2019030215.json already in dir raw_data/
# File 2019030246.json already in dir raw_data/
# File 2019030216.json already in dir raw_data/
# File 2019030247.json already in dir raw_data/
# File 2019030217.json already in dir raw_data/
# File 2019030321.json already in dir raw_data/
# File 2019030311.json already in dir raw_data/
# File 2019030322.json already in dir raw_data/
# File 2019030312.json already in dir raw_data/
# File 2019030323.json already in dir raw_data/
# File 2019030313.json already in dir raw_data/
# File 2019030324.json already in dir raw_data/
# File 2019030314.json already in dir raw_data/
# File 2019030325.json already in dir raw_data/
# File 2019030315.json already in dir raw_data/
# File 2019030316.json already in dir raw_data/
# File 2019030411.json already in dir raw_data/
# File 2019030412.json already in dir raw_data/
# File 2019030413.json already in dir raw_data/
# File 2019030414.json already in dir raw_data/
# File 2019030415.json already in dir raw_data/
# File 2019030416.json already in dir raw_data/
# File 2020020001.json already in dir raw_data/
# File 2020020006.json already in dir raw_data/
# File 2020020017.json already in dir raw_data/
# File 2020020023.json already in dir raw_data/
# File 2020020035.json already in dir raw_data/
# File 2020020038.json already in dir raw_data/
# File 2020020046.json already in dir raw_data/
# File 2020020056.json already in dir raw_data/
# File 2020020060.json already in dir raw_data/
# File 2020020067.json already in dir raw_data/
# File 2020020077.json already in dir raw_data/
# File 2020020084.json already in dir raw_data/
# File 2020020092.json already in dir raw_data/
# File 2020020093.json already in dir raw_data/
# File 2020020107.json already in dir raw_data/
# File 2020020109.json already in dir raw_data/
# File 2020020123.json already in dir raw_data/
# File 2020020124.json already in dir raw_data/
# File 2020020136.json already in dir raw_data/
# File 2020020144.json already in dir raw_data/
# File 2020020152.json already in dir raw_data/
# File 2020020160.json already in dir raw_data/
# File 2020020164.json already in dir raw_data/
# File 2020020174.json already in dir raw_data/
# File 2020020183.json already in dir raw_data/
# File 2020020188.json already in dir raw_data/
# File 2020020196.json already in dir raw_data/
# File 2020020203.json already in dir raw_data/
# File 2020020212.json already in dir raw_data/
# File 2020020215.json already in dir raw_data/
# File 2020020228.json already in dir raw_data/
# File 2020020236.json already in dir raw_data/
# File 2020020242.json already in dir raw_data/
# File 2020020251.json already in dir raw_data/
# File 2020020253.json already in dir raw_data/
# File 2020020062.json already in dir raw_data/
# File 2020020265.json already in dir raw_data/
# File 2020020274.json already in dir raw_data/
# File 2020020278.json already in dir raw_data/
# File 2020020392.json already in dir raw_data/
# File 2020020009.json already in dir raw_data/
# File 2020020295.json already in dir raw_data/
# File 2020020296.json already in dir raw_data/
# File 2020020312.json already in dir raw_data/
# File 2020020323.json already in dir raw_data/
# File 2020020322.json already in dir raw_data/
# File 2020020342.json already in dir raw_data/
# File 2020020348.json already in dir raw_data/
# File 2020020301.json already in dir raw_data/
# File 2020020359.json already in dir raw_data/
# File 2020020163.json already in dir raw_data/
# File 2020020373.json already in dir raw_data/
# File 2020020374.json already in dir raw_data/
# File 2020020391.json already in dir raw_data/
# File 2020020398.json already in dir raw_data/
# File 2020020405.json already in dir raw_data/
# File 2020020412.json already in dir raw_data/
# File 2020020415.json already in dir raw_data/
# File 2020020425.json already in dir raw_data/
# File 2020020430.json already in dir raw_data/
# File 2020020444.json already in dir raw_data/
# File 2020020448.json already in dir raw_data/
# File 2020020457.json already in dir raw_data/
# File 2020020463.json already in dir raw_data/
# File 2020020201.json already in dir raw_data/
# File 2020020478.json already in dir raw_data/
# File 2020020477.json already in dir raw_data/
# File 2020020151.json already in dir raw_data/
# File 2020020496.json already in dir raw_data/
# File 2020020504.json already in dir raw_data/
# File 2020020511.json already in dir raw_data/
# File 2020020515.json already in dir raw_data/
# File 2020020524.json already in dir raw_data/
# File 2020020179.json already in dir raw_data/
# File 2020020542.json already in dir raw_data/
# File 2020020548.json already in dir raw_data/
# File 2020020498.json already in dir raw_data/
# File 2020020557.json already in dir raw_data/
# File 2020020571.json already in dir raw_data/
# File 2020020580.json already in dir raw_data/
# File 2020020585.json already in dir raw_data/
# File 2020020599.json already in dir raw_data/
# File 2020020390.json already in dir raw_data/
# File 2020020611.json already in dir raw_data/
# File 2020020621.json already in dir raw_data/
# File 2020020625.json already in dir raw_data/
# File 2020020229.json already in dir raw_data/
# File 2020020605.json already in dir raw_data/
# File 2020020652.json already in dir raw_data/
# File 2020020657.json already in dir raw_data/
# File 2020020195.json already in dir raw_data/
# File 2020020192.json already in dir raw_data/
# File 2020020665.json already in dir raw_data/
# File 2020020686.json already in dir raw_data/
# File 2020020691.json already in dir raw_data/
# File 2020020701.json already in dir raw_data/
# File 2020020706.json already in dir raw_data/
# File 2020020483.json already in dir raw_data/
# File 2020020725.json already in dir raw_data/
# File 2020020254.json already in dir raw_data/
# File 2020020738.json already in dir raw_data/
# File 2020020746.json already in dir raw_data/
# File 2020020757.json already in dir raw_data/
# File 2020020761.json already in dir raw_data/
# File 2020020447.json already in dir raw_data/
# File 2020020776.json already in dir raw_data/
# File 2020020347.json already in dir raw_data/
# File 2020020791.json already in dir raw_data/
# File 2020020796.json already in dir raw_data/
# File 2020020811.json already in dir raw_data/
# File 2020020020.json already in dir raw_data/
# File 2020020824.json already in dir raw_data/
# File 2020020033.json already in dir raw_data/
# File 2020020280.json already in dir raw_data/
# File 2020020048.json already in dir raw_data/
# File 2020020854.json already in dir raw_data/
# File 2020020843.json already in dir raw_data/
# File 2020020231.json already in dir raw_data/
# File 2020020653.json already in dir raw_data/
# File 2020020526.json already in dir raw_data/
# File 2020020803.json already in dir raw_data/
# File 2020020741.json already in dir raw_data/
# File 2020020673.json already in dir raw_data/
# File 2020030111.json already in dir raw_data/
# File 2020030122.json already in dir raw_data/
# File 2020020864.json already in dir raw_data/
# File 2020020634.json already in dir raw_data/
# File 2020030143.json already in dir raw_data/
# File 2020030124.json already in dir raw_data/
# File 2020030144.json already in dir raw_data/
# File 2020030134.json already in dir raw_data/
# File 2020030115.json already in dir raw_data/
# File 2020030174.json already in dir raw_data/
# File 2020030116.json already in dir raw_data/
# File 2020030175.json already in dir raw_data/
# File 2020030167.json already in dir raw_data/
# File 2020030176.json already in dir raw_data/
# File 2020030221.json already in dir raw_data/
# File 2020030177.json already in dir raw_data/
# File 2020030222.json already in dir raw_data/
# File 2020030241.json already in dir raw_data/
# File 2020030213.json already in dir raw_data/
# File 2020030242.json already in dir raw_data/
# File 2020030224.json already in dir raw_data/
# File 2020030243.json already in dir raw_data/
# File 2020030215.json already in dir raw_data/
# File 2020030225.json already in dir raw_data/
# File 2020030216.json already in dir raw_data/
# File 2020030236.json already in dir raw_data/
# File 2020030321.json already in dir raw_data/
# File 2020030311.json already in dir raw_data/
# File 2020030322.json already in dir raw_data/
# File 2020030312.json already in dir raw_data/
# File 2020030323.json already in dir raw_data/
# File 2020030313.json already in dir raw_data/
# File 2020030324.json already in dir raw_data/
# File 2020030314.json already in dir raw_data/
# File 2020030325.json already in dir raw_data/
# File 2020030315.json already in dir raw_data/
# File 2020030326.json already in dir raw_data/
# File 2020030316.json already in dir raw_data/
# File 2020030327.json already in dir raw_data/
# File 2020030411.json already in dir raw_data/
# File 2020030412.json already in dir raw_data/
# File 2020030413.json already in dir raw_data/
# File 2020030414.json already in dir raw_data/
# File 2020030415.json already in dir raw_data/
