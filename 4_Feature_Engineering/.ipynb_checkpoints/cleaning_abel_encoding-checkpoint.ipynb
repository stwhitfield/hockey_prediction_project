# %% [markdown]
# Author: Rajesh Raju <br>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Read in data and assign X and y
data = pd.read_csv('../data/train_old.csv', index_col=0)
data
# Out:
#             time  period  coordinateX  coordinateY  shotDistance  shotAngle  \
# gameId
# 2015020001    51       1        -55.0          6.0       34.5254    10.0080
# 2015020001    65       1        -79.0          0.0       10.0000     0.0000
# 2015020001    66       1        -75.0         -1.0       14.0357    -4.0856
# 2015020001   113       1        -55.0        -36.0       49.5177   -46.6366
# 2015020001   157       1        -61.0         -1.0       28.0179    -2.0454
# ...          ...     ...          ...          ...           ...        ...
# 2018021271  3337       3         67.0        -19.0       29.0689   -40.8151
# 2018021271  3393       3        -78.0          1.0       11.0454     5.1944
# 2018021271  3519       3        -82.0         10.0       12.2066    55.0080
# 2018021271  3520       3        -81.0          1.0        8.0623     7.1250
# 2018021271  3555       3         74.0          4.0       15.5242    14.9314
#
#               shotType  emptyNet lastEventType  lastCoordinateX  \
# gameId
# 2015020001  Wrist Shot         0           Hit             94.0
# 2015020001   Snap Shot         0      Giveaway            -37.0
# 2015020001   Snap Shot         0          Shot            -79.0
# 2015020001  Wrist Shot         0           Hit            -91.0
# 2015020001      Tip-In         0       Faceoff            -69.0
# ...                ...       ...           ...              ...
# 2018021271   Slap Shot         0      Giveaway             29.0
# 2018021271  Wrist Shot         0       Faceoff            -69.0
# 2018021271  Wrist Shot         0   Missed Shot            -71.0
# 2018021271  Wrist Shot         0          Shot            -82.0
# 2018021271  Wrist Shot         1      Takeaway            -65.0
#
#             lastCoordinateY  lastTime  lastShotDistance  rebound  \
# gameId
# 2015020001            -34.0        11          154.2757    False
# 2015020001            -28.0         7           50.4777    False
# 2015020001              0.0         1            4.1231     True
# 2015020001             35.0        18           79.6053    False
# 2015020001            -22.0         5           22.4722    False
# ...                     ...       ...               ...      ...
# 2018021271             35.0        33           66.0303    False
# 2018021271            -22.0        29           24.6982    False
# 2018021271              4.0        19           12.5300    False
# 2018021271             10.0         1            9.0554     True
# 2018021271            -34.0         3          144.1007    False
#
#             changeShotAngle    speed  friendlyPlayersOnIce  \
# gameId
# 2015020001           0.0000  14.0251                     5
# 2015020001           0.0000   7.2111                     5
# 2015020001          -4.0856   4.1231                     5
# 2015020001           0.0000   4.4225                     5
# 2015020001           0.0000   4.4944                     5
# ...                     ...      ...                   ...
# 2018021271           0.0000   2.0009                     5
# 2018021271           0.0000   0.8517                     5
# 2018021271           0.0000   0.6595                     5
# 2018021271         -47.8830   9.0554                     5
# 2018021271           0.0000  48.0336                     5
#
#             opposingPlayersOnIce  timeSincePP  isGoal
# gameId
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# ...                          ...          ...     ...
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       1
#
# [315578 rows x 20 columns]

# %%
data.isnull().sum(axis = 0)
# Out:
# time                     0
# period                   0
# coordinateX              0
# coordinateY              0
# shotDistance             0
# shotAngle                0
# shotType                46
# emptyNet                 0
# lastEventType            0
# lastCoordinateX          0
# lastCoordinateY          0
# lastTime                 0
# lastShotDistance         0
# rebound                  0
# changeShotAngle          0
# speed                    0
# friendlyPlayersOnIce     0
# opposingPlayersOnIce     0
# timeSincePP              0
# isGoal                   0
# dtype: int64

# %%
data.dropna(inplace=True)
data
# Out:
#             time  period  coordinateX  coordinateY  shotDistance  shotAngle  \
# gameId
# 2015020001    51       1        -55.0          6.0       34.5254    10.0080
# 2015020001    65       1        -79.0          0.0       10.0000     0.0000
# 2015020001    66       1        -75.0         -1.0       14.0357    -4.0856
# 2015020001   113       1        -55.0        -36.0       49.5177   -46.6366
# 2015020001   157       1        -61.0         -1.0       28.0179    -2.0454
# ...          ...     ...          ...          ...           ...        ...
# 2018021271  3337       3         67.0        -19.0       29.0689   -40.8151
# 2018021271  3393       3        -78.0          1.0       11.0454     5.1944
# 2018021271  3519       3        -82.0         10.0       12.2066    55.0080
# 2018021271  3520       3        -81.0          1.0        8.0623     7.1250
# 2018021271  3555       3         74.0          4.0       15.5242    14.9314
#
#               shotType  emptyNet lastEventType  lastCoordinateX  \
# gameId
# 2015020001  Wrist Shot         0           Hit             94.0
# 2015020001   Snap Shot         0      Giveaway            -37.0
# 2015020001   Snap Shot         0          Shot            -79.0
# 2015020001  Wrist Shot         0           Hit            -91.0
# 2015020001      Tip-In         0       Faceoff            -69.0
# ...                ...       ...           ...              ...
# 2018021271   Slap Shot         0      Giveaway             29.0
# 2018021271  Wrist Shot         0       Faceoff            -69.0
# 2018021271  Wrist Shot         0   Missed Shot            -71.0
# 2018021271  Wrist Shot         0          Shot            -82.0
# 2018021271  Wrist Shot         1      Takeaway            -65.0
#
#             lastCoordinateY  lastTime  lastShotDistance  rebound  \
# gameId
# 2015020001            -34.0        11          154.2757    False
# 2015020001            -28.0         7           50.4777    False
# 2015020001              0.0         1            4.1231     True
# 2015020001             35.0        18           79.6053    False
# 2015020001            -22.0         5           22.4722    False
# ...                     ...       ...               ...      ...
# 2018021271             35.0        33           66.0303    False
# 2018021271            -22.0        29           24.6982    False
# 2018021271              4.0        19           12.5300    False
# 2018021271             10.0         1            9.0554     True
# 2018021271            -34.0         3          144.1007    False
#
#             changeShotAngle    speed  friendlyPlayersOnIce  \
# gameId
# 2015020001           0.0000  14.0251                     5
# 2015020001           0.0000   7.2111                     5
# 2015020001          -4.0856   4.1231                     5
# 2015020001           0.0000   4.4225                     5
# 2015020001           0.0000   4.4944                     5
# ...                     ...      ...                   ...
# 2018021271           0.0000   2.0009                     5
# 2018021271           0.0000   0.8517                     5
# 2018021271           0.0000   0.6595                     5
# 2018021271         -47.8830   9.0554                     5
# 2018021271           0.0000  48.0336                     5
#
#             opposingPlayersOnIce  timeSincePP  isGoal
# gameId
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# ...                          ...          ...     ...
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       1
#
# [315532 rows x 20 columns]

# %%
print(data['shotType'].unique())
print(data['shotType'].value_counts())
print(data['lastEventType'].unique())
print(data['lastEventType'].value_counts())
# Out:
# ['Wrist Shot' 'Snap Shot' 'Tip-In' 'Backhand' 'Slap Shot' 'Deflected'
#  'Wrap-around']
# Wrist Shot     167335
# Slap Shot       50695
# Snap Shot       47127
# Backhand        27015
# Tip-In          15553
# Deflected        4625
# Wrap-around      3182
# Name: shotType, dtype: int64
# ['Hit' 'Giveaway' 'Shot' 'Faceoff' 'Takeaway' 'Missed Shot' 'Penalty'
#  'Blocked Shot' 'Stoppage' 'Period Start' 'Goal' 'Official Challenge'
#  'Period End' 'Period Ready' 'Period Official' 'Game Official'
#  'Shootout Complete']
# Faceoff               75824
# Shot                  64266
# Hit                   53928
# Blocked Shot          33531
# Missed Shot           30334
# Giveaway              28787
# Takeaway              20570
# Stoppage               4607
# Goal                   2212
# Period Start           1077
# Penalty                 348
# Official Challenge       20
# Period End               10
# Period Ready              8
# Shootout Complete         6
# Game Official             3
# Period Official           1
# Name: lastEventType, dtype: int64

# %%
# creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing in another column
data['shotType'] = labelencoder.fit_transform(data['shotType'])
data['lastEventType'] = labelencoder.fit_transform(data['lastEventType'])
data
# Out:
#             time  period  coordinateX  coordinateY  shotDistance  shotAngle  \
# gameId
# 2015020001    51       1        -55.0          6.0       34.5254    10.0080
# 2015020001    65       1        -79.0          0.0       10.0000     0.0000
# 2015020001    66       1        -75.0         -1.0       14.0357    -4.0856
# 2015020001   113       1        -55.0        -36.0       49.5177   -46.6366
# 2015020001   157       1        -61.0         -1.0       28.0179    -2.0454
# ...          ...     ...          ...          ...           ...        ...
# 2018021271  3337       3         67.0        -19.0       29.0689   -40.8151
# 2018021271  3393       3        -78.0          1.0       11.0454     5.1944
# 2018021271  3519       3        -82.0         10.0       12.2066    55.0080
# 2018021271  3520       3        -81.0          1.0        8.0623     7.1250
# 2018021271  3555       3         74.0          4.0       15.5242    14.9314
#
#             shotType  emptyNet  lastEventType  lastCoordinateX  \
# gameId
# 2015020001         6         0              5             94.0
# 2015020001         3         0              3            -37.0
# 2015020001         3         0             14            -79.0
# 2015020001         6         0              5            -91.0
# 2015020001         4         0              1            -69.0
# ...              ...       ...            ...              ...
# 2018021271         2         0              3             29.0
# 2018021271         6         0              1            -69.0
# 2018021271         6         0              6            -71.0
# 2018021271         6         0             14            -82.0
# 2018021271         6         1             16            -65.0
#
#             lastCoordinateY  lastTime  lastShotDistance  rebound  \
# gameId
# 2015020001            -34.0        11          154.2757    False
# 2015020001            -28.0         7           50.4777    False
# 2015020001              0.0         1            4.1231     True
# 2015020001             35.0        18           79.6053    False
# 2015020001            -22.0         5           22.4722    False
# ...                     ...       ...               ...      ...
# 2018021271             35.0        33           66.0303    False
# 2018021271            -22.0        29           24.6982    False
# 2018021271              4.0        19           12.5300    False
# 2018021271             10.0         1            9.0554     True
# 2018021271            -34.0         3          144.1007    False
#
#             changeShotAngle    speed  friendlyPlayersOnIce  \
# gameId
# 2015020001           0.0000  14.0251                     5
# 2015020001           0.0000   7.2111                     5
# 2015020001          -4.0856   4.1231                     5
# 2015020001           0.0000   4.4225                     5
# 2015020001           0.0000   4.4944                     5
# ...                     ...      ...                   ...
# 2018021271           0.0000   2.0009                     5
# 2018021271           0.0000   0.8517                     5
# 2018021271           0.0000   0.6595                     5
# 2018021271         -47.8830   9.0554                     5
# 2018021271           0.0000  48.0336                     5
#
#             opposingPlayersOnIce  timeSincePP  isGoal
# gameId
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# ...                          ...          ...     ...
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       1
#
# [315532 rows x 20 columns]

# %%
print(data['shotType'].unique())
print(data['shotType'].value_counts())
print(data['lastEventType'].unique())
print(data['lastEventType'].value_counts())
# Out:
# [6 3 4 0 2 1 5]
# 6    167335
# 2     50695
# 3     47127
# 0     27015
# 4     15553
# 1      4625
# 5      3182
# Name: shotType, dtype: int64
# [ 5  3 14  1 16  6  8  0 15 12  4  7  9 11 10  2 13]
# 1     75824
# 14    64266
# 5     53928
# 0     33531
# 6     30334
# 3     28787
# 16    20570
# 15     4607
# 4      2212
# 12     1077
# 8       348
# 7        20
# 9        10
# 11        8
# 13        6
# 2         3
# 10        1
# Name: lastEventType, dtype: int64

# %%
data["rebound"] = data["rebound"].astype(int)
data
# Out:
#             time  period  coordinateX  coordinateY  shotDistance  shotAngle  \
# gameId
# 2015020001    51       1        -55.0          6.0       34.5254    10.0080
# 2015020001    65       1        -79.0          0.0       10.0000     0.0000
# 2015020001    66       1        -75.0         -1.0       14.0357    -4.0856
# 2015020001   113       1        -55.0        -36.0       49.5177   -46.6366
# 2015020001   157       1        -61.0         -1.0       28.0179    -2.0454
# ...          ...     ...          ...          ...           ...        ...
# 2018021271  3337       3         67.0        -19.0       29.0689   -40.8151
# 2018021271  3393       3        -78.0          1.0       11.0454     5.1944
# 2018021271  3519       3        -82.0         10.0       12.2066    55.0080
# 2018021271  3520       3        -81.0          1.0        8.0623     7.1250
# 2018021271  3555       3         74.0          4.0       15.5242    14.9314
#
#             shotType  emptyNet  lastEventType  lastCoordinateX  \
# gameId
# 2015020001         6         0              5             94.0
# 2015020001         3         0              3            -37.0
# 2015020001         3         0             14            -79.0
# 2015020001         6         0              5            -91.0
# 2015020001         4         0              1            -69.0
# ...              ...       ...            ...              ...
# 2018021271         2         0              3             29.0
# 2018021271         6         0              1            -69.0
# 2018021271         6         0              6            -71.0
# 2018021271         6         0             14            -82.0
# 2018021271         6         1             16            -65.0
#
#             lastCoordinateY  lastTime  lastShotDistance  rebound  \
# gameId
# 2015020001            -34.0        11          154.2757        0
# 2015020001            -28.0         7           50.4777        0
# 2015020001              0.0         1            4.1231        1
# 2015020001             35.0        18           79.6053        0
# 2015020001            -22.0         5           22.4722        0
# ...                     ...       ...               ...      ...
# 2018021271             35.0        33           66.0303        0
# 2018021271            -22.0        29           24.6982        0
# 2018021271              4.0        19           12.5300        0
# 2018021271             10.0         1            9.0554        1
# 2018021271            -34.0         3          144.1007        0
#
#             changeShotAngle    speed  friendlyPlayersOnIce  \
# gameId
# 2015020001           0.0000  14.0251                     5
# 2015020001           0.0000   7.2111                     5
# 2015020001          -4.0856   4.1231                     5
# 2015020001           0.0000   4.4225                     5
# 2015020001           0.0000   4.4944                     5
# ...                     ...      ...                   ...
# 2018021271           0.0000   2.0009                     5
# 2018021271           0.0000   0.8517                     5
# 2018021271           0.0000   0.6595                     5
# 2018021271         -47.8830   9.0554                     5
# 2018021271           0.0000  48.0336                     5
#
#             opposingPlayersOnIce  timeSincePP  isGoal
# gameId
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# 2015020001                     5            0       0
# ...                          ...          ...     ...
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       0
# 2018021271                     5            0       1
#
# [315532 rows x 20 columns]

# %%
data.describe()
# Out:
#                 time         period    coordinateX    coordinateY  \
# count  315532.000000  315532.000000  315532.000000  315532.000000
# mean     1909.948446       2.110344       0.072928      -0.279873
# std      1148.686975       0.965546      63.951709      18.741838
# min         0.000000       1.000000     -99.000000     -42.000000
# 25%       953.000000       1.000000     -64.000000     -14.000000
# 50%      1861.000000       2.000000      -1.000000       0.000000
# 75%      2797.000000       3.000000      65.000000      13.000000
# max      4800.000000       5.000000      99.000000      42.000000
#
#         shotDistance      shotAngle       shotType       emptyNet  \
# count  315532.000000  315532.000000  315532.000000  315532.000000
# mean       40.158182      -0.782216       4.213607       0.004364
# std        33.381142      35.975666       2.092747       0.065917
# min         1.000000    -171.869900       0.000000       0.000000
# 25%        17.204700     -27.758500       2.000000       0.000000
# 50%        34.014700       0.000000       6.000000       0.000000
# 75%        51.088200      26.565100       6.000000       0.000000
# max       189.654900     180.000000       6.000000       1.000000
#
#        lastEventType  lastCoordinateX  lastCoordinateY       lastTime  \
# count  315532.000000    315532.000000    315532.000000  315532.000000
# mean        6.138034         0.208213        -0.057107      14.709224
# std         5.630347        65.077942        22.656326      14.856738
# min         0.000000       -99.000000       -42.000000       0.000000
# 25%         1.000000       -69.000000       -22.000000       4.000000
# 50%         5.000000         0.000000         0.000000      10.000000
# 75%        14.000000        69.000000        22.000000      20.000000
# max        16.000000        99.000000        42.000000     194.000000
#
#        lastShotDistance        rebound  changeShotAngle          speed  \
# count     315532.000000  315532.000000    315532.000000  315532.000000
# mean          62.413145       0.203675         0.061889       7.490760
# std           47.890870       0.402731        20.608919       9.948171
# min            0.000000       0.000000      -195.321600       0.000000
# 25%           25.079900       0.000000         0.000000       1.727600
# 50%           46.529600       0.000000         0.000000       4.268700
# 75%           97.082400       0.000000         0.000000       9.501875
# max          200.000000       1.000000       209.528700     186.625300
#
#        friendlyPlayersOnIce  opposingPlayersOnIce    timeSincePP  \
# count         315532.000000         315532.000000  315532.000000
# mean               4.832936              4.730744      11.169453
# std                0.702849              0.753367      38.134592
# min               -2.000000             -2.000000       0.000000
# 25%                5.000000              5.000000       0.000000
# 50%                5.000000              5.000000       0.000000
# 75%                5.000000              5.000000       0.000000
# max                5.000000              5.000000     600.000000
#
#               isGoal
# count  315532.000000
# mean        0.100022
# std         0.300029
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
data.dtypes
# Out:
# time                      int64
# period                    int64
# coordinateX             float64
# coordinateY             float64
# shotDistance            float64
# shotAngle               float64
# shotType                  int32
# emptyNet                  int64
# lastEventType             int32
# lastCoordinateX         float64
# lastCoordinateY         float64
# lastTime                  int64
# lastShotDistance        float64
# rebound                   int32
# changeShotAngle         float64
# speed                   float64
# friendlyPlayersOnIce      int64
# opposingPlayersOnIce      int64
# timeSincePP               int64
# isGoal                    int64
# dtype: object

# %%
data.to
